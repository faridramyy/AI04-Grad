# %%
import os
import json
import random
import gym
import numpy as np
import requests
import re
from gym import spaces
from stable_baselines3 import PPO
from dotenv import load_dotenv

# === Load Gemini API Key ===
def load_api_key():
    env_path = "../models/key.env"
    load_dotenv(env_path)
    api_key = os.getenv("GEMINI_API_KEY") or "AIzaSyA2rRBLcJx_e5g4d_fVOgG4q2Pf8ewPI70"
    if not api_key:
        raise ValueError("❌ Gemini API Key not found.")
    print("✅ Gemini API Key loaded successfully!")
    return api_key

# === Clean JSON from Gemini ===
def clean_json_text(text):
    return re.sub(r"^```(?:json)?|```$", "", text.strip(), flags=re.MULTILINE).strip()

# === Generate Scenario with Difficulty and Best Choice ===
GEMINI_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?key=" + load_api_key()

def generate_scenario_with_feedback(emotion="stress", tag="generated"):
    prompt = (
        f"The user is experiencing the emotion '{emotion}'.\n"
        "Generate a valid JSON object containing:\n"
        "- A stressful 'scenario' (1-2 sentences)\n"
        "- 4 unique 'responses' with an 'option' and a 'reward' (-3 to 3)\n"
        "- The index (0-3) of the option the user chose called 'chosen_action'\n"
        "- A 'difficulty' level: easy, medium, or hard\n"
        "Return JSON in this structure:\n"
        "{\n"
        "  'tag': 'stress_situation',\n"
        "  'emotion': 'stress',\n"
        "  'scenario': '...',\n"
        "  'difficulty': 'medium',\n"
        "  'responses': [\n"
        "    {'option': '...', 'reward': 2},\n"
        "    {'option': '...', 'reward': -1},\n"
        "    {'option': '...', 'reward': 3},\n"
        "    {'option': '...', 'reward': -2}\n"
        "  ],\n"
        "  'chosen_action': 2\n"
        "}"
    )
    headers = {"Content-Type": "application/json"}
    data = {"contents": [{"parts": [{"text": prompt}]}]}

    try:
        response = requests.post(GEMINI_URL, headers=headers, json=data)
        if response.ok:
            raw = response.json()["candidates"][0]["content"]["parts"][0]["text"]
            try:
                cleaned = clean_json_text(raw)
                parsed = json.loads(cleaned.replace("'", '"'))  # Convert single to double quotes
                parsed["emotion"] = emotion
                parsed["tag"] = tag
                return parsed
            except json.JSONDecodeError:
                print("⚠️ Gemini returned invalid JSON:\n", raw)
                return None
        else:
            print("❌ Gemini API Error:", response.status_code)
            return None
    except Exception as e:
        print("❌ Request failed:", str(e))
        return None

# === Main ===
def main():
    print("🚀 Starting Stress Management Game with Gemini REST API...\n")
    load_api_key()

    # 🧠 Generate one scenario before starting
    generated = generate_scenario_with_feedback()
    if generated:
        print("\n🎯 Generated Scenario with Feedback:")
        print(json.dumps(generated, indent=2))

    env = EmotionGameEnv()
    model = train_rl_model(env)
    evaluate_model(env)

if __name__ == "__main__":
    main()
# Out:
# ✅ Gemini API Key loaded successfully!
# 🚀 Starting Stress Management Game with Gemini REST API...
#
# ✅ Gemini API Key loaded successfully!
# ⚠️ Gemini returned invalid JSON:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're running late for a crucial presentation at work.  Your laptop is malfunctioning, and you've misplaced your presentation notes.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and rush through the presentation, hoping for the best.", "reward": -2},
#     {"option": "Take a few deep breaths, calmly assess the situation, and improvise using your memory.", "reward": 2},
#     {"option": "Contact your supervisor immediately to inform them of the issue and request a brief delay.", "reward": 3},
#     {"option": "Ignore the problem, hoping it will resolve itself before the presentation.", "reward": -3}
#   ],
#   "chosen_action": 2
# }
# ```
#
# ✅ Dataset loaded successfully!
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# 🎯 Training PPO model...
#
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | 4.14     |
# | time/              |          |
# |    fps             | 261      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019376408 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0499     |
# |    value_loss           | 46.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 27.5        |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 3           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.023871016 |
# |    clip_fraction        | 0.393       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.17       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 4           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.022129457 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.05        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 42.1        |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 5           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020509277 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 77.1        |
# -----------------------------------------
# ✅ Model saved as 'emotional_rl_agent'.
#
# 📥 Loading model...
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 1
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter. ✅
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: 3
# 💢 Stress Level: 65/100
# 💬 Gemini Advice:
# Take five deep, slow breaths before you begin.  Focus on inhaling deeply and exhaling slowly. This will help center you and reduce some of the immediate anxiety.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 2
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter. ✅
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: 3
# 💢 Stress Level: 62/100
# 💬 Gemini Advice:
# Even though you've chosen to work on the presentation immediately,  try the **Pomodoro Technique**.  Work in focused bursts of 25 minutes, followed by a 5-minute break. This structured approach can help prevent burnout and make the overwhelming task feel less daunting, reducing your stress level in the long run, even if you're working late into the night.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 3
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter.
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation. ✅
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: -1
# 💢 Stress Level: 63/100
# 💬 Gemini Advice:
# The chosen option (calling a friend to vent) provides temporary emotional relief but doesn't address the root problem: the impending deadline and lack of preparation.  While talking to a friend can be helpful, it shouldn't replace proactive problem-solving.
#
# A better coping strategy would be a combination of options 0 and 3.  **The Pomodoro Technique**, combined with **Option 3 (creating a detailed outline)**, offers a structured approach:
#
# * **Break the overwhelming task into smaller, manageable chunks (Option 3):**  Instead of thinking "I have a presentation to do," think "I need to create an outline (25 minutes)," "I need to research point 1 (25 minutes)," "I need to write the introduction (25 minutes)," etc.
#
# * **Use the Pomodoro Technique:** Work in focused 25-minute intervals, followed by a 5-minute break.  After four Pomodoros, take a longer break (15-20 minutes). This structured approach prevents burnout and maintains focus.  Even if you pull an all-nighter (Option 0),  this method will make it significantly more productive and less overwhelming.
#
# * **After each Pomodoro, acknowledge your progress:**  This positive reinforcement helps build momentum and combat feelings of being overwhelmed.
#
# * **Prioritize the most crucial elements:** Focus on the core message and key points first.  Perfectionism is the enemy of progress in this situation.  Aim for "good enough" for now; you can always refine it later.
#
# This combined approach addresses both the emotional (reducing stress through manageable tasks) and practical (getting the presentation done) aspects of the problem, leading to a more effective and less stressful experience.  Calling a friend for support *can* still be part of the process, but it shouldn't be the primary coping mechanism.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 4
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter.
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation. ✅
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: -1
# 💢 Stress Level: 64/100
# 💬 Gemini Advice:
# The chosen action (venting to a friend) offers temporary emotional relief but doesn't address the root problem: the impending deadline and lack of preparation.  A professional stress management technique applicable here is **time management and task breakdown**.
#
# Instead of venting and procrastinating, the individual should immediately implement a structured approach:
#
# 1. **Prioritize and Break Down the Task:**  Instead of feeling overwhelmed by the entire presentation, the person should break it down into smaller, manageable chunks.  This could involve creating a detailed outline (as option 3 suggested), defining specific sections (introduction, body points, conclusion), and allocating a realistic timeframe for completing each section.
#
# 2. **Timeboxing:** Allocate specific time blocks for working on each section of the presentation.  This creates a structured approach and prevents feeling overwhelmed by the sheer volume of work.  Even small blocks of focused work (e.g., 30-minute intervals with short breaks) are more effective than long periods of avoidance.
#
# 3. **Pomodoro Technique:**  This is a specific time management technique that involves working in 25-minute intervals followed by a 5-minute break.  After four "pomodoros," take a longer break (15-20 minutes).  This structured approach can boost focus and productivity.
#
# 4. **Seek Clarification (If Necessary):**  If there's uncertainty about the presentation requirements,  immediately contact the instructor or relevant person for clarification to avoid wasting time on unnecessary details or pursuing the wrong direction.
#
# By implementing these time management and task breakdown techniques, the individual can transform the overwhelming feeling of a massive task into a series of manageable steps, significantly reducing stress and increasing the likelihood of completing the presentation successfully. Venting can be helpful, but it needs to be combined with proactive problem-solving strategies for effective stress management.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 5
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter. ✅
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: 3
# 💢 Stress Level: 61/100
# 💬 Gemini Advice:
# Okay, I understand you chose to immediately start working on the presentation, even if it means staying up all night.  While this demonstrates a proactive approach,  pulling an all-nighter is rarely a sustainable or effective solution for managing stress and completing high-quality work.  Let's create a recovery plan to address both the immediate crisis and prevent this from happening again.
#
# **Immediate Actions (Tonight):**
#
# * **Time Management (Modified Option 0):**  Instead of just diving in, break the next few hours into focused work sprints.  Set a timer for 50 minutes of intense work followed by a 10-minute break. During breaks, get up, stretch, walk around, or do something completely unrelated to the presentation to refresh your mind.  Prioritize the most crucial elements of the presentation first. Aim for progress, not perfection in this initial phase.  The goal isn't to finish everything tonight, but to make significant headway and reduce the overwhelming feeling.
#
# * **Prioritize Sleep (Crucial):**  Even if you don’t finish, aim for at least 4 hours of sleep.  Sleep deprivation exacerbates stress and impairs cognitive function, making tomorrow's presentation even harder.  Consider a sleep aid like melatonin if you struggle to fall asleep, but consult a doctor or pharmacist first.
#
# * **Mindfulness Exercise (5-10 minutes):** Before bed, practice some deep breathing exercises or a short guided meditation.  Apps like Calm or Headspace can be helpful. This will help calm your racing mind and prepare you for sleep.
#
#
# **Tomorrow's Actions:**
#
# * **Finish the Presentation (Early):** Continue working on the presentation first thing in the morning.  Stick to the same work sprint strategy.
#
# * **Healthy Lifestyle Choices:** Focus on nourishing your body. Eat nutritious meals and stay hydrated. Avoid excessive caffeine or sugar, as these can exacerbate stress and anxiety.
#
# * **Presentation Rehearsal:** Do a full run-through of your presentation aloud. This helps you identify any weak points and smooth out your delivery.
#
# * **Self-Compassion:**  Be kind to yourself.  You made a choice to tackle the problem directly, even if the execution wasn't perfect. Acknowledge your efforts and learn from this experience.
#
# * **Post-Presentation Review:** After the presentation, take some time to reflect on what went well and what could be improved for next time.  Celebrate your accomplishment!
#
#
# **Long-Term Strategies (Preventing Future Stress):**
#
# * **Time Management Techniques:** Learn and implement effective time management strategies like the Pomodoro Technique (as you started tonight) or time blocking. This will help you avoid last-minute cramming.
#
# * **Procrastination Management:** Identify your procrastination triggers and develop coping mechanisms.  This might involve breaking down large tasks into smaller, less daunting steps, setting realistic deadlines, or seeking accountability from a friend or mentor.
#
# * **Stress Management Techniques:** Explore various stress-reduction techniques such as exercise, yoga, meditation, or spending time in nature. Find what works best for you and incorporate it into your routine.
#
# * **Seek Professional Help:**  If you frequently experience overwhelming stress or anxiety, consider seeking professional help from a therapist or counselor.  They can provide you with personalized strategies and support.
#
#
# This recovery plan focuses on a balanced approach. While immediate action is necessary, long-term strategies are essential to prevent future episodes of overwhelming stress.  Remember, seeking help isn't a sign of weakness, but a sign of strength.  Prioritizing your mental and physical well-being is vital for success in all aspects of your life.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 5
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter.
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later. ✅
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: -2
# 💢 Stress Level: 63/100
# 💬 Gemini Advice:
# Okay, so you chose to watch a movie to de-stress before tackling your presentation. While short-term relaxation can be helpful, relying solely on this method when facing a significant deadline like yours isn't the most effective long-term strategy.  Let's create a plan to address both your immediate stress and the underlying procrastination.  The goal is to manage your stress levels while also ensuring you deliver a successful presentation.
#
# **Understanding the Choice:**  Choosing the movie demonstrates a need for immediate stress reduction.  It's a common coping mechanism, but it can backfire if it leads to further procrastination and increased anxiety later.  We need to address that underlying avoidance behavior.
#
# **Recovery Plan:**
#
# **Phase 1: Immediate Stress Reduction (Next 30 minutes):**
#
# * **Mindful Breathing Exercise (5 minutes):**  Find a quiet space. Sit comfortably, close your eyes, and focus on your breath. Inhale deeply through your nose, hold for a few seconds, and exhale slowly through your mouth. Repeat this 10 times, noticing the sensation of your breath entering and leaving your body.  This will help calm your nervous system.
# * **Short, Engaging Activity (15 minutes):**  Instead of a full movie, choose a short, engaging activity that doesn't require deep concentration.  This could be listening to upbeat music, a short walk outdoors, or even a quick tidy-up of your workspace. The goal is to shift your focus away from the overwhelming thought of the presentation without completely disconnecting from the task at hand.
# * **Gentle Stretching or Light Exercise (10 minutes):** Physical activity releases endorphins, which have mood-boosting effects.  A few simple stretches or a brisk walk will help to release tension and improve focus.
#
#
# **Phase 2: Task Breakdown and Planning (Next 60-90 minutes):**
#
# * **Detailed Outline (30 minutes):**  Now, it's time to face the presentation head-on, but in a manageable way.  Forget about creating the perfect slides immediately. Instead, focus on creating a detailed outline. Break down your presentation into its core components (introduction, body points, conclusion). List the key points you want to cover under each section.
# * **Prioritization (15 minutes):** Review your outline and prioritize the most crucial points.  Which sections are essential for conveying your message? Focus your initial efforts on these key areas.
# * **Resource Gathering (15-30 minutes):**  Gather all the necessary research materials, data, and visuals you'll need. This reduces the time spent searching later, making the actual writing process more efficient.
#
# **Phase 3: Focused Work Blocks (Rest of the Evening):**
#
# * **Pomodoro Technique:** Work in focused bursts of 25 minutes, followed by a 5-minute break. This technique helps maintain concentration and prevents burnout.
# * **Realistic Goals:** Don’t aim for perfection in one sitting. Focus on completing specific sections of your outline, even if it's just one slide at a time.
# * **Avoid Perfectionism:**  Remember, your goal is to deliver a solid presentation, not a masterpiece.  Focus on clarity and conveying your key message effectively.
#
# **Phase 4: Self-Compassion and Sleep:**
#
# * **Acknowledge your feelings:**  It's okay to feel stressed and overwhelmed.  Be kind to yourself and acknowledge that procrastination is a common issue.
# * **Prioritize sleep:** Aim for at least 6-7 hours of sleep. A well-rested mind is crucial for effective work and managing stress.  Even if you have to pull an all-nighter *partly*, prioritize sleep as much as possible.
#
#
# **Long-term strategies:**
#
# * **Time Management Techniques:**  Explore time management techniques like the Eisenhower Matrix (urgent/important) to prioritize tasks and prevent future procrastination.
# * **Procrastination Strategies:**  Identify your triggers for procrastination and develop strategies to counteract them.  This might involve breaking down large tasks into smaller ones, setting realistic deadlines, or seeking accountability from a friend or mentor.
#
# This plan acknowledges your need for immediate stress relief while providing a structured approach to tackle the presentation. Remember, addressing both the emotional and task-related aspects of your stress is key to success.  If you continue to struggle with stress or procrastination, consider seeking professional help from a therapist or counselor.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 5
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter. ✅
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: 3
# 💢 Stress Level: 60/100
# 💬 Gemini Advice:
# Okay, I understand you chose to immediately start working on the presentation, even if it means pulling an all-nighter.  While this demonstrates a proactive approach,  let's acknowledge that this isn't sustainable in the long run and likely contributed to a significant increase in your stress levels.  We need to address both the immediate crisis and the underlying issues that led to this situation.  Here’s a recovery plan:
#
# **Immediate Action (Tonight):**
#
# * **Prioritize & Chunk:** Even though you're starting late, resist the urge to just dive in randomly.  Spend the *first* 30 minutes creating a *very* basic structure.  Focus on the main points you absolutely *must* cover. Don't worry about perfecting slides or wording – just get the core argument down.  Then break it into smaller, manageable chunks (e.g., introduction, 3 main points, conclusion).  Tackle one chunk at a time.  Set realistic time goals for each chunk, rather than aiming for perfection immediately.
#
# * **Time Management:** Use the Pomodoro Technique (25 minutes work, 5 minutes break).  This structured approach can help you maintain focus and prevent burnout.  During breaks, step away from your computer – get some water, stretch, or do some quick light exercises.
#
# * **Limit Caffeine & Sugar:**  While tempting to stay awake with caffeine and sugary snacks, they’ll lead to a crash later, exacerbating your stress. Opt for water and healthy snacks.
#
# * **Get Some Sleep (even if it's limited):** Aim for at least 4-5 hours of sleep.  Sleep deprivation will severely impair your performance tomorrow.  Even a short period of rest is better than none.
#
# **Post-Presentation (Tomorrow & Beyond):**
#
# * **Self-Compassion:** Be kind to yourself.  You handled a stressful situation.  Acknowledge that you pulled through, even if it wasn’t ideal.  Avoid self-criticism; learn from this experience.
#
# * **Debrief & Analyze:** After the presentation, take some time to reflect on what worked well and what could be improved. This is crucial for future presentations. Did your rushed approach affect the quality? What could you have done differently to avoid this last-minute scramble?
#
# * **Long-Term Procrastination Strategies:**  The root cause of this stress was procrastination.  Let's address that.  Consider these strategies:
#
#     * **Time Blocking:** Schedule specific times for tasks in your calendar, treating them like appointments you can't miss.
#     * **Breaking Down Tasks:** Consistently break down large tasks into smaller, manageable steps.  This makes them less daunting.
#     * **The Two-Minute Rule:** If a task takes less than two minutes, do it immediately.  This prevents small tasks from piling up.
#     * **Reward System:**  Reward yourself for completing tasks. This positive reinforcement can help motivate you.
#     * **Identify Underlying Issues:**  Sometimes procrastination stems from deeper issues like fear of failure or perfectionism.  Consider journaling or talking to a therapist to explore these.
#
#
# * **Stress Management Techniques:**  Implement regular stress-reducing activities into your routine:
#
#     * **Exercise:** Regular physical activity is a powerful stress reliever.
#     * **Mindfulness/Meditation:**  Even 10 minutes a day can make a significant difference.
#     * **Deep Breathing Exercises:**  Practice these throughout the day to calm your nervous system.
#     * **Healthy Diet & Sleep Hygiene:** Prioritize regular sleep and a balanced diet.
#
# This is a comprehensive approach. It's okay to not implement everything at once. Prioritize what feels most manageable and build from there.  Remember,  seeking help is a sign of strength, not weakness. If you find yourself consistently struggling with procrastination or stress management, consider seeking professional help from a therapist or counselor. They can provide personalized strategies and support to help you develop healthier coping mechanisms.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 5
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter.
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps. ✅
# 🏆 Reward: 2
# 💢 Stress Level: 58/100
# 💬 Gemini Advice:
# Okay, choosing option 3 is a fantastic first step!  It shows you're recognizing the need for proactive, rather than avoidant, coping mechanisms.  Let's build on that and create a recovery plan to manage your stress and get this presentation done effectively. We'll address both the immediate crisis and long-term stress management.
#
# **Phase 1: Immediate Action (Next 2 Hours)**
#
# * **Deep Breathing Exercise (5 minutes):** Before you even touch your laptop, let's ground you. Find a quiet space and practice box breathing: inhale for 4 seconds, hold for 4, exhale for 4, hold for 4. Repeat 5-10 times. This will help calm your nervous system.
# * **Detailed Outline (30 minutes):**  Now, let's tackle that outline.  Break the presentation down into its core components: Introduction, Body (with clearly defined sections), Conclusion, and Q&A.  Within each section, list the key points you need to cover. Don't worry about perfect wording yet; focus on structure.
# * **Prioritize & Time-Block (30 minutes):** Look at your outline and assign estimated time to each section.  Be realistic!  It’s better to slightly overestimate than underestimate.  Schedule specific blocks of time for each section, including short breaks in between. This creates a manageable plan and reduces the feeling of being overwhelmed.
# * **Gather Resources (15 minutes):** Identify the specific resources you'll need (articles, data, images) for each section.  Gather them now; having them readily available will save you time later.
# * **Mini-Reward (15 minutes):** After completing these tasks, allow yourself a small, healthy reward. This could be a short walk, listening to your favorite song, or a healthy snack.  This reinforces positive behavior and prevents burnout.
#
#
# **Phase 2: Focused Work (Next 4-6 Hours)**
#
# * **Time-Blocked Work Sessions:** Stick to your schedule as closely as possible.  Work on one section at a time.  If you find yourself getting distracted or overwhelmed, take a 5-minute break to stretch, walk, or do another breathing exercise.  The Pomodoro Technique (25 minutes work, 5 minutes break) can be helpful.
# * **Avoid Perfectionism:** Your goal tonight isn't perfection; it's completion of a solid, presentable presentation. Aim for "good enough" for now. You can refine it later if you have time.
# * **Hydration & Nutrition:**  Drink plenty of water and eat healthy snacks throughout the night. Avoid excessive caffeine or sugar, as they can exacerbate anxiety.
#
# **Phase 3: Post-Work & Sleep (Remaining Time)**
#
# * **Review & Edit:** Once you've completed the main body, take some time to review and edit for clarity and flow.
# * **Prepare Visual Aids:** If you're using slides, spend some time on those now.  Keep them concise and visually appealing.
# * **Practice (Optional):** If time allows, practice your presentation out loud. This will build confidence and help identify any areas that need improvement.
# * **Wind-Down Routine:** An hour before bed, engage in relaxing activities like reading a book, listening to calming music, or taking a warm bath.  Avoid screens during this time.  Aim for 7-8 hours of sleep.
#
#
# **Long-Term Stress Management:**
#
# This situation highlights a need for better time management skills.  Consider these strategies:
#
# * **Procrastination Strategies:** Identify your procrastination triggers and develop coping mechanisms. This might involve breaking down large tasks into smaller chunks, using time management techniques (like the Pomodoro Technique), or seeking support from a friend or mentor.
# * **Mindfulness Practices:** Incorporate regular mindfulness techniques like meditation or yoga into your routine to manage stress and improve focus.
# * **Regular Exercise:** Physical activity is a great stress reliever.  Aim for at least 30 minutes of moderate-intensity exercise most days of the week.
# * **Healthy Lifestyle:** Maintain a healthy diet, get enough sleep, and limit your caffeine and alcohol intake.
# * **Seek Professional Help:** If you consistently struggle with stress and procrastination, consider seeking professional help from a therapist or counselor. They can provide personalized strategies to help you manage stress effectively.
#
#
# Remember, you've got this! By breaking the task down and using effective coping mechanisms, you can navigate this stressful situation and deliver a successful presentation.  Reach out if you need additional support or feel overwhelmed at any point during this process.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 5
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter.
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later. ✅
#   2. Call a friend and vent about your stress, procrastinating on the presentation.
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: -2
# 💢 Stress Level: 60/100
# 💬 Gemini Advice:
# Okay, so you've chosen to watch a movie to de-stress before tackling your presentation.  While a short break can be helpful to reset, relying solely on this approach at a stress level of 60/100 with a looming deadline isn't the most effective strategy.  Let's create a recovery plan that incorporates both stress reduction and productive action.
#
# **Understanding the Choice:**  Choosing the movie suggests you're feeling overwhelmed and are employing avoidance as a coping mechanism.  This is understandable given the pressure, but avoidance often exacerbates anxiety in the long run.  The hope for spontaneous inspiration is unlikely at this stage.
#
# **Recovery Plan:**
#
# **Phase 1: Immediate Stress Reduction (Next 30-60 minutes):**
#
# * **Mindful Movie Watching (with caveats):**  Instead of passively watching a movie, choose something light and calming, perhaps a comedy or nature documentary.  Actively focus on the present moment – the visuals, sounds, and emotions evoked.  Avoid anything intense or anxiety-inducing.
# * **Mindfulness Exercise (10 minutes):**  After 30 minutes of the movie, take a 10-minute break to practice a mindfulness technique. This could be deep breathing exercises, a guided meditation (plenty are available on apps like Calm or Headspace), or simply focusing on your senses (what you see, hear, feel, smell, taste).  This will help ground you in the present and reduce the racing thoughts.
# * **Hydration and Light Snack:** Dehydration and low blood sugar can amplify stress. Drink a glass of water and eat a healthy, light snack.
#
# **Phase 2: Task Breakdown & Action (Next 2-3 hours):**
#
# * **Realistic Outline (30 minutes):**  Now, it's time to tackle the presentation, but not by diving in headfirst.  Create a detailed, realistic outline. Break down the presentation into manageable chunks (e.g., introduction, main points 1, 2, 3, conclusion).  For each chunk, list the key information and evidence you need.  Don't worry about perfect wording yet, just focus on structure.
# * **Information Gathering (60 minutes):**  Based on your outline, start gathering the necessary information. This could involve reviewing notes, conducting research, or consulting relevant materials.  Set a timer to avoid getting bogged down in any one area.
# * **Short Break (15 minutes):**  Take a short break to stretch, walk around, or listen to some calming music.  This prevents burnout.
#
# **Phase 3:  Focused Work & Sleep (Remaining Time):**
#
# * **Drafting & Refining (2-3 hours):**  Begin drafting the content based on your outline and gathered information. Focus on one section at a time.  Don’t aim for perfection in this first draft; just get the ideas down.
# * **Review & Edit (30 minutes):**  Once you have a complete first draft, take a break and then review and edit your work.
# * **Prioritize Sleep (7-8 hours):**  Even if you haven't finished everything, get a good night's sleep. A well-rested mind is far more effective than a sleep-deprived one.  Finish any remaining work early tomorrow morning if needed.
#
#
# **Important Considerations:**
#
# * **Perfectionism:** Let go of the need for perfection. A good presentation is clear, concise, and well-organized, not necessarily flawlessly polished.
# * **Self-Compassion:** Be kind to yourself.  It’s okay to have procrastinated; the important thing is to take action now.
# * **Future Planning:** After this presentation, reflect on your work habits and develop strategies to avoid similar situations in the future.  Consider time management techniques like the Pomodoro Technique or breaking large tasks into smaller ones.
#
#
# This plan balances immediate stress reduction with productive work.  Remember, it's okay to ask for help if you need it.  Reaching out to a friend or professor for advice or support can be invaluable.
#
#
#
# 🎭 Emotion: stress
# 📜 Scenario: You're stressed because you have a major presentation due tomorrow and haven't even started preparing.  Your mind is racing and you feel overwhelmed.
# 📈 Difficulty: unknown
# 🎯 Difficulty Level: 5
# 🧠 Choices:
#   0. Start working on the presentation immediately, even if it means pulling an all-nighter.
#   1. Watch a movie to take your mind off things for a while, hoping inspiration will strike later.
#   2. Call a friend and vent about your stress, procrastinating on the presentation. ✅
#   3. Create a detailed outline and plan for the presentation to break the task into smaller, manageable steps.
# 🏆 Reward: -1
# 💢 Stress Level: 61/100
# 💬 Gemini Advice:
# Okay, I understand you're feeling overwhelmed and stressed about your presentation, and you chose to talk to a friend about it.  While venting can be a helpful way to release some initial tension, it's important to remember that it's not a solution in itself.  Procrastination only exacerbates stress in the long run. Let's create a plan to get you back on track and manage this stress effectively.
#
#
# **Phase 1: Immediate Stress Reduction (Next 30-60 minutes)**
#
# 1. **Deep Breathing Exercises:**  Let's start with some grounding techniques. Find a quiet space, sit comfortably, and practice deep, slow breaths. Inhale deeply through your nose, hold for a count of four, and exhale slowly through your mouth. Repeat this 10-15 times. This will help calm your nervous system.
#
# 2. **Mindfulness Meditation (Optional):**  If you're comfortable, try a short guided meditation focused on relaxation or stress reduction.  There are many free apps available (like Calm or Headspace) that can guide you through this. Even 5-10 minutes can make a difference.
#
# 3. **Gentle Movement:**  Light stretching or a short walk can help release physical tension.  Avoid strenuous exercise, as this could be counterproductive at this moment.
#
# **Phase 2:  Presentation Planning & Execution (Next 4-6 Hours)**
#
# 1. **Realistic Timeline:** Forget about perfection. The goal is to create a *presentable* presentation, not a masterpiece. Given the time constraint, we need to prioritize.  Let's break down the presentation into the absolute essentials.
#
# 2. **Prioritize Key Points:**  What are the 2-3 most important things you absolutely *must* communicate in your presentation? Focus your efforts on these.
#
# 3. **Simplified Structure:**  Create a simple outline:
#     * **Introduction:** Briefly state your topic and main points.
#     * **Body:**  Develop 2-3 sections based on your key points.  Each section should have a clear point and supporting evidence (even if it's just a few bullet points).
#     * **Conclusion:**  Summarize your key points and leave the audience with a clear takeaway.
#
# 4. **Visual Aids:** Keep it simple.  Use bullet points instead of paragraphs.  Choose visuals that are impactful and easy to understand. Avoid overwhelming your audience with too much information.
#
# 5. **Practice (Even a Little):**  Once you have a basic framework, practice delivering your presentation aloud.  This will help you identify any gaps in your logic or areas where you need more clarity.
#
# **Phase 3:  Self-Care & Prevention (Ongoing)**
#
# 1. **Healthy Diet & Hydration:**  Fuel your body with nutritious food and plenty of water.  Avoid excessive caffeine or sugar, which can exacerbate anxiety.
#
# 2. **Sleep Hygiene:**  Aim for at least 6-7 hours of sleep tonight, even if it means going to bed earlier than usual.
#
# 3. **Future Procrastination Strategies:**  This situation highlights a need to develop better time management skills.  Consider techniques like the Pomodoro Technique (working in focused bursts with short breaks) or time blocking to schedule specific times for tasks.
#
# 4. **Seek Professional Help (if needed):** If this level of stress is recurring or significantly impacting your daily life, consider talking to a therapist or counselor. They can provide additional strategies for stress management and coping mechanisms.
#
#
# Remember, you've got this!  It's okay to feel stressed, but don't let that stress paralyze you.  Focus on making progress, even if it's just small steps at a time.  The goal is to create a presentable presentation, not a perfect one.  Prioritize, simplify, and take it one step at a time.  You've already taken the first step by acknowledging your stress and reaching out for support. Now let's work together to get you through this.

# %%
import os
import json
import random
import gym
import numpy as np
import requests
import re
from gym import spaces
from stable_baselines3 import PPO
from dotenv import load_dotenv

# === Load Gemini API Key ===
def load_api_key():
    env_path = "../models/key.env"
    load_dotenv(env_path)
    api_key = os.getenv("GEMINI_API_KEY") or "AIzaSyA2rRBLcJx_e5g4d_fVOgG4q2Pf8ewPI70"
    if not api_key:
        raise ValueError("❌ Gemini API Key not found.")
    print("✅ Gemini API Key loaded successfully!")
    return api_key

# === Clean JSON from Gemini ===
def clean_json_text(text):
    cleaned = re.sub(r"^```(?:json)?|```$", "", text.strip(), flags=re.MULTILINE).strip()
    return cleaned.replace("‘", "'").replace("’", "'").replace("“", '"').replace("”", '"')

# === Generate Scenario with Difficulty and Best Choice ===
def generate_scenario_with_feedback(emotion="stress", tag="generated", difficulty="medium"):
    GEMINI_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?key=" + load_api_key()

    prompt = (
        "You are an expert game designer AI that only responds in valid JSON format. "
        "Do not include markdown or explanations.\n\n"
        f"The user is experiencing the emotion '{emotion}'.\n"
        f"The scenario should be '{difficulty}' in difficulty.\n"
        "Generate a valid JSON object containing:\n"
        "- A stressful 'scenario' (1-2 sentences)\n"
        "- 4 unique 'responses' with an 'option' and a 'reward' (-3 to 3)\n"
        "- The index (0-3) of the option the user chose called 'chosen_action'\n"
        "- A 'difficulty' level: easy, medium, or hard\n"
        "Return JSON in this structure ONLY:\n"
        "{\n"
        "  'tag': 'stress_situation',\n"
        "  'emotion': 'stress',\n"
        "  'scenario': '...',\n"
        "  'difficulty': 'medium',\n"
        "  'responses': [\n"
        "    {'option': '...', 'reward': 2},\n"
        "    {'option': '...', 'reward': -1},\n"
        "    {'option': '...', 'reward': 3},\n"
        "    {'option': '...', 'reward': -2}\n"
        "  ],\n"
        "  'chosen_action': 2\n"
        "}"
    )

    headers = {"Content-Type": "application/json"}
    data = {"contents": [{"parts": [{"text": prompt}]}]}

    try:
        response = requests.post(GEMINI_URL, headers=headers, json=data)
        if response.ok:
            raw = response.json()["candidates"][0]["content"]["parts"][0]["text"]
            cleaned = clean_json_text(raw).replace("'", '"')

            try:
                parsed = json.loads(cleaned)
                parsed["emotion"] = emotion
                parsed["tag"] = tag
                return parsed
            except json.JSONDecodeError as e:
                print("⚠️ Gemini returned invalid JSON.")
                print("🚫 Error:", e)
                print("📄 Raw response:\n", raw)
                print("📄 Cleaned response:\n", cleaned)
                return None
        else:
            print("❌ Gemini API Error:", response.status_code)
            return None
    except Exception as e:
        print("❌ Request failed:", str(e))
        return None

# === Difficulty Adjustment Logic ===
def adjust_difficulty(stress_score):
    if stress_score <= -5:
        return "easy"
    elif stress_score >= 5:
        return "hard"
    else:
        return "medium"

# === Main ===
def main():
    print("🚀 Starting Stress Scenario Generation with Adaptive Difficulty...\n")
    api_key = load_api_key()
    all_scenarios = []
    stress_score = 0

    for i in range(5):
        difficulty = adjust_difficulty(stress_score)
        print(f"\n📘 Generating Scenario {i+1} (difficulty: {difficulty}, current stress score: {stress_score})...")
        scenario = generate_scenario_with_feedback(difficulty=difficulty)

        if scenario:
            reward = scenario["responses"][scenario["chosen_action"]]["reward"]
            stress_score += reward
            all_scenarios.append(scenario)
            print(f"✅ Scenario {i+1} - Reward: {reward} | Updated Stress Score: {stress_score}")
            print(json.dumps(scenario, indent=2))
        else:
            print(f"⚠️ Failed to generate scenario {i+1}")

    # Save all scenarios
    with open("generated_scenarios.json", "w") as f:
        json.dump(all_scenarios, f, indent=2)
    print("\n📁 All scenarios saved to 'generated_scenarios.json'")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting Stress Scenario Generation with Adaptive Difficulty...
#
# ✅ Gemini API Key loaded successfully!
#
# 📘 Generating Scenario 1 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# ⚠️ Gemini returned invalid JSON.
# 🚫 Error: Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, and your presentation files are corrupted.  Your phone is dead and you're stuck in heavy traffic.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to fix the files on your laptop, hoping you can fix them before you get there.", "reward": -3},
#     {"option": "Call the client and explain the situation, requesting a reschedule.", "reward": 2},
#     {"option": "Pull over, take a few deep breaths, and calmly assess the situation, then find a workaround.", "reward": 3},
#     {"option": "Drive recklessly to the presentation, potentially risking safety.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 📄 Cleaned response:
#  {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You"re late for a crucial presentation to a major client, and your presentation files are corrupted.  Your phone is dead and you"re stuck in heavy traffic.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to fix the files on your laptop, hoping you can fix them before you get there.", "reward": -3},
#     {"option": "Call the client and explain the situation, requesting a reschedule.", "reward": 2},
#     {"option": "Pull over, take a few deep breaths, and calmly assess the situation, then find a workaround.", "reward": 3},
#     {"option": "Drive recklessly to the presentation, potentially risking safety.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ⚠️ Failed to generate scenario 1
#
# 📘 Generating Scenario 2 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# ⚠️ Gemini returned invalid JSON.
# 🚫 Error: Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, and you've realized you left your presentation slides at home.  Your phone battery is also critically low.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Try to wing it without the slides, hoping your knowledge is sufficient.", "reward": -1},
#     {"option": "Panic and call your assistant to frantically try and locate your slides, potentially jeopardizing other tasks.", "reward": -3},
#     {"option": "Quickly summarize key points on a nearby whiteboard or notepad and explain your situation to the client, apologizing for the inconvenience.", "reward": 3},
#     {"option": "Suggest rescheduling the presentation after securing your slides and charging your phone, risking the client's patience.", "reward": 2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 📄 Cleaned response:
#  {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You"re late for a crucial presentation to a major client, and you"ve realized you left your presentation slides at home.  Your phone battery is also critically low.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Try to wing it without the slides, hoping your knowledge is sufficient.", "reward": -1},
#     {"option": "Panic and call your assistant to frantically try and locate your slides, potentially jeopardizing other tasks.", "reward": -3},
#     {"option": "Quickly summarize key points on a nearby whiteboard or notepad and explain your situation to the client, apologizing for the inconvenience.", "reward": 3},
#     {"option": "Suggest rescheduling the presentation after securing your slides and charging your phone, risking the client"s patience.", "reward": 2}
#   ],
#   "chosen_action": 2
# }
# ⚠️ Failed to generate scenario 2
#
# 📘 Generating Scenario 3 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# ⚠️ Gemini returned invalid JSON.
# 🚫 Error: Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, and you've just realized you left your presentation slides at home.  Your phone is nearly dead.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Call a colleague to see if they can quickly email the slides.", "reward": 2},
#     {"option": "Panic and try to improvise the presentation without slides.", "reward": -1},
#     {"option": "Quickly search for a nearby internet cafe to access and reprint the slides.", "reward": 3},
#     {"option": "Pretend to be ill and reschedule the presentation.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 📄 Cleaned response:
#  {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You"re late for a crucial presentation to a major client, and you"ve just realized you left your presentation slides at home.  Your phone is nearly dead.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Call a colleague to see if they can quickly email the slides.", "reward": 2},
#     {"option": "Panic and try to improvise the presentation without slides.", "reward": -1},
#     {"option": "Quickly search for a nearby internet cafe to access and reprint the slides.", "reward": 3},
#     {"option": "Pretend to be ill and reschedule the presentation.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ⚠️ Failed to generate scenario 3
#
# 📘 Generating Scenario 4 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# ⚠️ Gemini returned invalid JSON.
# 🚫 Error: Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, and your laptop battery is critically low; you're stuck in traffic with no cell service.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Pull over and attempt to fix the laptop issue.", "reward": -1},
#     {"option": "Try calling the client to explain and reschedule.", "reward": -2},
#     {"option": "Find the nearest coffee shop with Wi-Fi to charge your laptop and prepare for a condensed presentation.", "reward": 3},
#     {"option": "Continue driving while frantically preparing notes on your phone.", "reward": 2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 📄 Cleaned response:
#  {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You"re late for a crucial presentation to a major client, and your laptop battery is critically low; you"re stuck in traffic with no cell service.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Pull over and attempt to fix the laptop issue.", "reward": -1},
#     {"option": "Try calling the client to explain and reschedule.", "reward": -2},
#     {"option": "Find the nearest coffee shop with Wi-Fi to charge your laptop and prepare for a condensed presentation.", "reward": 3},
#     {"option": "Continue driving while frantically preparing notes on your phone.", "reward": 2}
#   ],
#   "chosen_action": 2
# }
# ⚠️ Failed to generate scenario 4
#
# 📘 Generating Scenario 5 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# ⚠️ Gemini returned invalid JSON.
# 🚫 Error: Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop is frozen, and you can't find your presentation notes.  Traffic is a standstill.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to reboot your laptop, hoping it will work quickly enough.", "reward": -1},
#     {"option": "Call the client and explain the situation, requesting a short delay.", "reward": 2},
#     {"option": "Quickly pull up a simplified version of the presentation on your phone and proceed.", "reward": 3},
#     {"option": "Ignore the client and rush to the presentation, hoping for the best.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 📄 Cleaned response:
#  {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You"re late for a crucial presentation to a major client, your laptop is frozen, and you can"t find your presentation notes.  Traffic is a standstill.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to reboot your laptop, hoping it will work quickly enough.", "reward": -1},
#     {"option": "Call the client and explain the situation, requesting a short delay.", "reward": 2},
#     {"option": "Quickly pull up a simplified version of the presentation on your phone and proceed.", "reward": 3},
#     {"option": "Ignore the client and rush to the presentation, hoping for the best.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ⚠️ Failed to generate scenario 5
#
# 📁 All scenarios saved to 'generated_scenarios.json'

# %%
import os
import json
import random
import gym
import numpy as np
import requests
from gym import spaces
from stable_baselines3 import PPO
from dotenv import load_dotenv

# Gemini API Configuration
GEMINI_API_KEY = "AIzaSyA2rRBLcJx_e5g4d_fVOgG4q2Pf8ewPI70"
GEMINI_API_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent"

# Generate scenario using Gemini API
def generate_gemini_scenario(emotion, difficulty="medium"):
    """Generates a scenario with choices and correct answer using Gemini API."""
    prompt = f"""
    Generate a therapeutic scenario about emotional management for someone feeling {emotion}.
    Difficulty: {difficulty}.
    Format exactly as this JSON structure:
    {{
        "scenario": "the scenario description",
        "choices": [
            {{"text": "choice 1", "correct": false, "explanation": "why this is wrong"}},
            {{"text": "choice 2", "correct": true, "explanation": "why this is right"}},
            {{"text": "choice 3", "correct": false, "explanation": "why this is wrong"}},
            {{"text": "choice 4", "correct": false, "explanation": "why this is wrong"}}
        ],
        "difficulty": "{difficulty}",
        "emotion": "{emotion}"
    }}
    Important rules:
    1. Make exactly 4 choices
    2. Only one choice should be correct
    3. Provide concrete explanations
    4. Keep scenario realistic and therapeutic
    """
    
    headers = {"Content-Type": "application/json"}
    data = {
        "contents": [{
            "parts": [{
                "text": prompt
            }]
        }],
        "generationConfig": {
            "temperature": 0.7
        }
    }
    
    try:
        response = requests.post(
            f"{GEMINI_API_URL}?key={GEMINI_API_KEY}",
            headers=headers,
            json=data
        )
        response.raise_for_status()
        generated_text = response.json()["candidates"][0]["content"]["parts"][0]["text"]
        
        # Extract JSON from response
        json_start = generated_text.find('{')
        json_end = generated_text.rfind('}') + 1
        json_str = generated_text[json_start:json_end]
        
        scenario = json.loads(json_str)
        
        # Validate scenario structure
        if not all(k in scenario for k in ["scenario", "choices", "difficulty"]):
            raise ValueError("Invalid scenario format")
        if len(scenario["choices"]) != 4:
            raise ValueError("Scenario must have exactly 4 choices")
            
        return scenario
    except Exception as e:
        print(f"Error generating scenario: {str(e)}")
        # Return fallback scenario
        return {
            "scenario": f"You're feeling {emotion} after a long day. How do you cope?",
            "choices": [
                {"text": "Bottle up your emotions", "correct": False, "explanation": "Suppressing emotions can lead to increased stress"},
                {"text": "Talk to a trusted friend", "correct": True, "explanation": "Social support helps process emotions effectively"},
                {"text": "Yell at someone nearby", "correct": False, "explanation": "This harms relationships and increases tension"},
                {"text": "Ignore the feeling completely", "correct": False, "explanation": "Avoidance prevents emotional processing"}
            ],
            "difficulty": difficulty,
            "emotion": emotion
        }

# Define the Emotion-Based RL Environment
class EmotionGameEnv(gym.Env):
    """Custom Gym environment for Emotion-Based RL."""
    
    def __init__(self):
        super(EmotionGameEnv, self).__init__()
        
        # Define state and action spaces
        self.emotions = ["sad", "angry", "happy", "stress", "neutral", "fear"]
        self.difficulties = ["easy", "medium", "hard"]
        self.action_space = spaces.Discrete(4)  # 4 choices per scenario
        self.observation_space = spaces.Dict({
            "emotion": spaces.Discrete(len(self.emotions)),
            "difficulty": spaces.Discrete(len(self.difficulties))
        })

        self.state = None
        self.current_scenario = None
        self.stats = {
            "correct": 0,
            "total": 0,
            "difficulty_stats": {d: {"correct": 0, "total": 0} for d in self.difficulties}
        }

    def reset(self):
        """Resets the environment for a new episode."""
        emotion = random.choice(self.emotions)
        difficulty = random.choice(self.difficulties)
        self.state = {
            "emotion": emotion,
            "difficulty": difficulty
        }
        
        # Generate new scenario
        self.current_scenario = generate_gemini_scenario(emotion, difficulty)
        
        return {
            "emotion": self.emotions.index(self.state["emotion"]),
            "difficulty": self.difficulties.index(self.state["difficulty"])
        }

    def step(self, action):
        """Takes an action and returns (obs, reward, done, info)."""
        if not self.current_scenario:
            raise ValueError("No scenario loaded")
            
        try:
            chosen_choice = self.current_scenario["choices"][action]
            is_correct = chosen_choice["correct"]
            
            # Calculate base reward
            if is_correct:
                reward = 10
                self.stats["correct"] += 1
                self.stats["difficulty_stats"][self.current_scenario["difficulty"]]["correct"] += 1
            else:
                reward = -3
            self.stats["total"] += 1
            self.stats["difficulty_stats"][self.current_scenario["difficulty"]]["total"] += 1
            
            # Apply difficulty multiplier
            difficulty = self.current_scenario["difficulty"]
            if difficulty == "medium":
                reward *= 1.5
            elif difficulty == "hard":
                reward *= 2
                
        except (IndexError, KeyError):
            reward = -5  # Penalty for invalid action
            
        done = True  # One step per episode
        info = {
            "scenario": self.current_scenario["scenario"],
            "choices": [c["text"] for c in self.current_scenario["choices"]],
            "chosen": self.current_scenario["choices"][action]["text"],
            "correct": is_correct,
            "explanation": chosen_choice["explanation"],
            "difficulty": self.current_scenario["difficulty"],
            "emotion": self.current_scenario["emotion"],
            "stats": self.stats
        }
        
        return self._get_obs(), reward, done, info
    
    def _get_obs(self):
        """Convert state to observation space format."""
        return {
            "emotion": self.emotions.index(self.state["emotion"]),
            "difficulty": self.difficulties.index(self.state["difficulty"])
        }

def train_rl_model(env, total_timesteps=10000):
    """Trains the RL model using Proximal Policy Optimization (PPO)."""
    model = PPO(
        "MultiInputPolicy", 
        env, 
        verbose=1,
        learning_rate=0.0003,
        n_steps=2048,
        batch_size=64,
        n_epochs=10
    )

    try:
        print("\n🎯 Training PPO model...\n")
        model.learn(total_timesteps=total_timesteps)
        model.save("emotional_rl_agent")
        print("\n✅ Model training completed and saved as 'emotional_rl_agent'.")
        return model
    except KeyboardInterrupt:
        print("\n⏸ Training interrupted. Saving model...")
        model.save("emotional_rl_agent")
        return model

def evaluate_model(env, model=None, model_path="emotional_rl_agent", num_tests=5):
    """Evaluates the model with detailed output."""
    if model is None:
        print("\n📥 Loading trained model...")
        model = PPO.load(model_path)

    print("\n🔍 Starting Evaluation...")
    for i in range(num_tests):
        obs = env.reset()
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)

        # Display results
        print(f"\n{'='*50}")
        print(f"🏷️  Test Case {i+1}/{num_tests}")
        print(f"🎭 Emotion: {info['emotion'].upper()}")
        print(f"📊 Difficulty: {info['difficulty'].upper()}")
        print(f"\n📜 Scenario: {info['scenario']}")
        
        print("\n💡 Choices:")
        for idx, choice in enumerate(info['choices']):
            marker = "✓" if idx == action else " "
            correctness = "(CORRECT)" if info['choices'][idx] == info['chosen'] and info['correct'] else ""
            print(f" {marker} {idx}. {choice} {correctness}")
        
        print(f"\n🤖 AI Chose: {action}. {info['chosen']}")
        print(f"✅ Correct: {'Yes' if info['correct'] else 'No'}")
        print(f"💡 Explanation: {info['explanation']}")
        print(f"🏆 Reward: {reward:.1f}")
        print(f"{'='*50}")

    # Print summary statistics
    stats = info['stats']
    accuracy = (stats["correct"] / stats["total"]) * 100 if stats["total"] > 0 else 0
    print(f"\n📊 Overall Accuracy: {accuracy:.1f}% ({stats['correct']}/{stats['total']})")
    
    print("\n📈 Difficulty Breakdown:")
    for diff in env.difficulties:
        diff_stats = stats["difficulty_stats"][diff]
        if diff_stats["total"] > 0:
            acc = (diff_stats["correct"] / diff_stats["total"]) * 100
            print(f"  {diff.upper()}: {acc:.1f}% ({diff_stats['correct']}/{diff_stats['total']})")

# Main Execution
def main():
    print("🚀 Starting Emotion-Based RL & AI Therapy System...")
    print(f"🔑 Using Gemini API Key: {GEMINI_API_KEY[:5]}...{GEMINI_API_KEY[-5:]}\n")
    
    # Initialize environment
    env = EmotionGameEnv()
    
    # Train or load model
    train_new = input("Train new model? (y/n): ").lower() == 'y'
    if train_new:
        timesteps = int(input("Enter training timesteps (default 10000): ") or 10000)
        model = train_rl_model(env, total_timesteps=timesteps)
    else:
        model = None
    
    # Evaluate model
    num_tests = int(input("Enter number of test scenarios (default 5): ") or 5)
    evaluate_model(env, model=model, num_tests=num_tests)

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting Emotion-Based RL & AI Therapy System...
# 🔑 Using Gemini API Key: AIzaS...wPI70
#
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\dell\anaconda3\envs\fer_pytorch\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# 🎯 Training PPO model...
#
#
# ⏸ Training interrupted. Saving model...
#
# 🔍 Starting Evaluation...
#
# ==================================================
# 🏷️  Test Case 1/5
# 🎭 Emotion: NEUTRAL
# 📊 Difficulty: EASY
#
# 📜 Scenario: You're feeling quite neutral today – not particularly happy or sad, just...blah.  You're sitting at home, scrolling through social media, and notice a friend posted a picture of them having a fantastic time at a concert. You feel… nothing.  A slight shrug, perhaps. How do you best respond to this feeling of neutrality and potentially engage with your emotions?
#
# 💡 Choices:
#    0. Ignore it and keep scrolling.  Neutrality is fine; there's nothing to address.
#  ✓ 1. Engage in a relaxing activity like reading a book or listening to music to distract yourself from the feeling. (CORRECT)
#    2. Force yourself to feel something – try to conjure up feelings of excitement or happiness to counteract the neutrality.
#    3. Immediately call your friend and express your envy of their fun night out.
#
# 🤖 AI Chose: 1. Engage in a relaxing activity like reading a book or listening to music to distract yourself from the feeling.
# ✅ Correct: Yes
# 💡 Explanation: This is a healthy way to address neutrality.  Sometimes, gentle self-soothing activities can help you notice and acknowledge a lack of strong feelings, allowing you to gently shift towards a more positive emotional state. It's a proactive approach to well-being.
# 🏆 Reward: 10.0
# ==================================================

# %%
import os
import json
import random
import gym
import numpy as np
import requests
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from collections import deque
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Gemini API Configuration
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY", "AIzaSyA2rRBLcJx_e5g4d_fVOgG4q2Pf8ewPI70")
GEMINI_API_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent"

# Constants
DEFAULT_MODEL_PARAMS = {
    "policy": "MultiInputPolicy",
    "learning_rate": 0.0003,
    "n_steps": 2048,
    "batch_size": 64,
    "n_epochs": 10,
    "gamma": 0.99,
    "gae_lambda": 0.95,
    "clip_range": 0.2,
    "ent_coef": 0.01,
    "verbose": 1
}

class DifficultyAdjuster:
    """Handles dynamic difficulty adjustment based on performance."""
    
    def __init__(self):
        self.performance_window = deque(maxlen=10)  # Tracks last 10 performances
        self.difficulty_levels = ["easy", "medium", "hard"]
        self.current_difficulty_idx = 1  # Start with medium
        
    def update_difficulty(self, is_correct):
        """Adjust difficulty based on recent performance."""
        self.performance_window.append(1 if is_correct else 0)
        
        if len(self.performance_window) == self.performance_window.maxlen:
            success_rate = sum(self.performance_window) / len(self.performance_window)
            
            if success_rate > 0.7:  # Doing well, increase difficulty
                self.current_difficulty_idx = min(self.current_difficulty_idx + 1, len(self.difficulty_levels) - 1)
            elif success_rate < 0.4:  # Struggling, decrease difficulty
                self.current_difficulty_idx = max(self.current_difficulty_idx - 1, 0)
                
        return self.get_current_difficulty()
    
    def get_current_difficulty(self):
        return self.difficulty_levels[self.current_difficulty_idx]

class TrainingCallback(BaseCallback):
    """Custom callback for tracking training progress and adjusting parameters."""
    
    def __init__(self, verbose=0):
        super(TrainingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        
    def _on_step(self) -> bool:
        return True
    
    def _on_rollout_end(self) -> None:
        # Track episode rewards and lengths
        if len(self.model.ep_info_buffer) > 0:
            self.episode_rewards.extend([ep_info["r"] for ep_info in self.model.ep_info_buffer if "r" in ep_info])
            self.episode_lengths.extend([ep_info["l"] for ep_info in self.model.ep_info_buffer if "l" in ep_info])
            
    def get_mean_reward(self):
        return np.mean(self.episode_rewards) if self.episode_rewards else 0

def generate_gemini_scenario(emotion, difficulty="medium"):
    """Generates a scenario with choices and correct answer using Gemini API."""
    prompt = f"""
    Generate a therapeutic scenario about emotional management for someone feeling {emotion}.
    Difficulty: {difficulty}.
    Format exactly as this JSON structure:
    {{
        "scenario": "the scenario description",
        "choices": [
            {{"text": "choice 1", "correct": false, "explanation": "why this is wrong"}},
            {{"text": "choice 2", "correct": true, "explanation": "why this is right"}},
            {{"text": "choice 3", "correct": false, "explanation": "why this is wrong"}},
            {{"text": "choice 4", "correct": false, "explanation": "why this is wrong"}}
        ],
        "difficulty": "{difficulty}",
        "emotion": "{emotion}"
    }}
    Important rules:
    1. Make exactly 4 choices
    2. Only one choice should be correct
    3. Provide concrete explanations
    4. Keep scenario realistic and therapeutic
    5. Ensure explanations are psychologically valid
    6. Make the correct choice non-obvious for harder difficulties
    """
    
    headers = {"Content-Type": "application/json"}
    data = {
        "contents": [{
            "parts": [{
                "text": prompt
            }]
        }],
        "generationConfig": {
            "temperature": 0.7 + (0.1 * ["easy", "medium", "hard"].index(difficulty))
        }
    }
    
    try:
        response = requests.post(
            f"{GEMINI_API_URL}?key={GEMINI_API_KEY}",
            headers=headers,
            json=data
        )
        response.raise_for_status()
        generated_text = response.json()["candidates"][0]["content"]["parts"][0]["text"]
        
        # Extract JSON from response
        json_start = generated_text.find('{')
        json_end = generated_text.rfind('}') + 1
        json_str = generated_text[json_start:json_end]
        
        scenario = json.loads(json_str)
        
        # Validate scenario structure
        if not all(k in scenario for k in ["scenario", "choices", "difficulty"]):
            raise ValueError("Invalid scenario format")
        if len(scenario["choices"]) != 4:
            raise ValueError("Scenario must have exactly 4 choices")
            
        return scenario
    except Exception as e:
        print(f"Error generating scenario: {str(e)}")
        # Return fallback scenario
        return {
            "scenario": f"You're feeling {emotion} after a long day. How do you cope?",
            "choices": [
                {"text": "Bottle up your emotions", "correct": False, "explanation": "Suppressing emotions can lead to increased stress"},
                {"text": "Talk to a trusted friend", "correct": True, "explanation": "Social support helps process emotions effectively"},
                {"text": "Yell at someone nearby", "correct": False, "explanation": "This harms relationships and increases tension"},
                {"text": "Ignore the feeling completely", "correct": False, "explanation": "Avoidance prevents emotional processing"}
            ],
            "difficulty": difficulty,
            "emotion": emotion
        }

class EmotionGameEnv(gym.Env):
    """Custom Gym environment for Emotion-Based RL with adaptive difficulty."""
    
    def __init__(self):
        super(EmotionGameEnv, self).__init__()
        
        # Define state and action spaces
        self.emotions = ["sad", "angry", "happy", "stress", "neutral", "fear", "anxious", "overwhelmed"]
        self.difficulty_adjuster = DifficultyAdjuster()
        self.action_space = spaces.Discrete(4)  # 4 choices per scenario
        self.observation_space = spaces.Dict({
            "emotion": spaces.Discrete(len(self.emotions)),
            "difficulty": spaces.Discrete(len(self.difficulty_adjuster.difficulty_levels)),
            "history": spaces.Box(low=0, high=1, shape=(5,), dtype=np.float32)  # Last 5 performances
        })

        self.state = None
        self.current_scenario = None
        self.performance_history = deque(maxlen=5)  # Tracks last 5 performances
        self.stats = {
            "correct": 0,
            "total": 0,
            "difficulty_stats": {d: {"correct": 0, "total": 0} for d in self.difficulty_adjuster.difficulty_levels},
            "emotion_stats": {e: {"correct": 0, "total": 0} for e in self.emotions}
        }

    def reset(self):
        """Resets the environment for a new episode."""
        emotion = random.choice(self.emotions)
        difficulty = self.difficulty_adjuster.get_current_difficulty()
        
        self.state = {
            "emotion": emotion,
            "difficulty": difficulty,
            "history": np.array(list(self.performance_history) + [0] * (5 - len(self.performance_history)), dtype=np.float32)
        }
        
        # Generate new scenario
        self.current_scenario = generate_gemini_scenario(emotion, difficulty)
        
        return self._get_obs()

    def step(self, action):
        """Takes an action and returns (obs, reward, done, info)."""
        if not self.current_scenario:
            raise ValueError("No scenario loaded")
            
        try:
            chosen_choice = self.current_scenario["choices"][action]
            is_correct = chosen_choice["correct"]
            self.performance_history.append(1 if is_correct else 0)
            
            # Update difficulty based on performance
            new_difficulty = self.difficulty_adjuster.update_difficulty(is_correct)
            
            # Calculate base reward
            if is_correct:
                reward = 10
                self.stats["correct"] += 1
                self.stats["difficulty_stats"][self.current_scenario["difficulty"]]["correct"] += 1
                self.stats["emotion_stats"][self.current_scenario["emotion"]]["correct"] += 1
            else:
                reward = -3
                
            self.stats["total"] += 1
            self.stats["difficulty_stats"][self.current_scenario["difficulty"]]["total"] += 1
            self.stats["emotion_stats"][self.current_scenario["emotion"]]["total"] += 1
            
            # Apply difficulty multiplier
            difficulty = self.current_scenario["difficulty"]
            if difficulty == "medium":
                reward *= 1.5
            elif difficulty == "hard":
                reward *= 2
                
            # Add small reward for attempting harder difficulties
            reward += ["easy", "medium", "hard"].index(difficulty) * 0.5
                
        except (IndexError, KeyError):
            reward = -5  # Penalty for invalid action
            is_correct = False
            
        done = True  # One step per episode
        info = {
            "scenario": self.current_scenario["scenario"],
            "choices": [c["text"] for c in self.current_scenario["choices"]],
            "chosen": self.current_scenario["choices"][action]["text"],
            "correct": is_correct,
            "explanation": chosen_choice["explanation"],
            "difficulty": self.current_scenario["difficulty"],
            "emotion": self.current_scenario["emotion"],
            "stats": self.stats,
            "new_difficulty": new_difficulty
        }
        
        return self._get_obs(), reward, done, info
    
    def _get_obs(self):
        """Convert state to observation space format."""
        return {
            "emotion": self.emotions.index(self.state["emotion"]),
            "difficulty": self.difficulty_adjuster.difficulty_levels.index(self.state["difficulty"]),
            "history": self.state["history"]
        }

def train_rl_model(env, total_timesteps=10000, model_params=None):
    """Trains the RL model using Proximal Policy Optimization (PPO)."""
    params = DEFAULT_MODEL_PARAMS.copy()
    if model_params:
        params.update(model_params)
    
    callback = TrainingCallback()
    model = PPO(**params, env=env)
    
    try:
        print("\n🎯 Training PPO model with adaptive difficulty...\n")
        model.learn(total_timesteps=total_timesteps, callback=callback)
        model.save("emotional_rl_agent_adaptive")
        print(f"\n✅ Model training completed (Mean Reward: {callback.get_mean_reward():.2f})")
        print(f"Saved as 'emotional_rl_agent_adaptive'")
        return model
    except KeyboardInterrupt:
        print("\n⏸ Training interrupted. Saving model...")
        model.save("emotional_rl_agent_adaptive_interrupted")
        return model

def evaluate_model(env, model=None, model_path="emotional_rl_agent_adaptive", num_tests=10):
    """Evaluates the model with detailed output and adaptive difficulty."""
    if model is None:
        print("\n📥 Loading trained model...")
        model = PPO.load(model_path, env=env)

    print("\n🔍 Starting Evaluation with Adaptive Difficulty...")
    for i in range(num_tests):
        obs = env.reset()
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)

        # Display results
        print(f"\n{'='*50}")
        print(f"🏷️  Test Case {i+1}/{num_tests}")
        print(f"🎭 Emotion: {info['emotion'].upper()}")
        print(f"📊 Difficulty: {info['difficulty'].upper()} → New: {info['new_difficulty'].upper()}")
        print(f"\n📜 Scenario: {info['scenario']}")
        
        print("\n💡 Choices:")
        for idx, choice in enumerate(info['choices']):
            marker = "✓" if idx == action else " "
            correctness = "(CORRECT)" if info['choices'][idx] == info['chosen'] and info['correct'] else ""
            print(f" {marker} {idx}. {choice} {correctness}")
        
        print(f"\n🤖 AI Chose: {action}. {info['chosen']}")
        print(f"✅ Correct: {'Yes' if info['correct'] else 'No'}")
        print(f"💡 Explanation: {info['explanation']}")
        print(f"🏆 Reward: {reward:.1f}")
        print(f"{'='*50}")

    # Print summary statistics
    stats = info['stats']
    accuracy = (stats["correct"] / stats["total"]) * 100 if stats["total"] > 0 else 0
    print(f"\n📊 Overall Accuracy: {accuracy:.1f}% ({stats['correct']}/{stats['total']})")
    
    print("\n📈 Difficulty Breakdown:")
    for diff in env.difficulty_adjuster.difficulty_levels:
        diff_stats = stats["difficulty_stats"][diff]
        if diff_stats["total"] > 0:
            acc = (diff_stats["correct"] / diff_stats["total"]) * 100
            print(f"  {diff.upper()}: {acc:.1f}% ({diff_stats['correct']}/{diff_stats['total']})")
    
    print("\n🎭 Emotion Performance:")
    for emotion in sorted(env.emotions):
        emo_stats = stats["emotion_stats"][emotion]
        if emo_stats["total"] > 0:
            acc = (emo_stats["correct"] / emo_stats["total"]) * 100
            print(f"  {emotion.upper()}: {acc:.1f}% ({emo_stats['correct']}/{emo_stats['total']})")

def interactive_demo(env, model=None, model_path="emotional_rl_agent_adaptive"):
    """Interactive demo where human can play against the AI."""
    if model is None:
        print("\n📥 Loading trained model...")
        model = PPO.load(model_path, env=env)

    print("\n🎮 Interactive Mode - Compete against the AI!")
    print("You'll see the same scenarios and choices as the AI.")
    print("Try to get more correct answers than the AI!\n")
    
    human_score = 0
    ai_score = 0
    num_rounds = int(input("Enter number of rounds (default 5): ") or 5
    
    for round_num in range(1, num_rounds + 1):
        obs = env.reset()
        scenario = env.current_scenario
        
        print(f"\n{'='*50}")
        print(f"🔔 Round {round_num}/{num_rounds}")
        print(f"🎭 Emotion: {scenario['emotion'].upper()}")
        print(f"📊 Difficulty: {scenario['difficulty'].upper()}")
        print(f"\n📜 Scenario: {scenario['scenario']}")
        
        print("\n💡 Choices:")
        for idx, choice in enumerate(scenario['choices']):
            print(f" {idx}. {choice['text']}")
        
        # Human choice
        while True:
            try:
                human_action = int(input("\nYour choice (0-3): "))
                if 0 <= human_action <= 3:
                    break
                print("Please enter a number between 0 and 3")
            except ValueError:
                print("Please enter a valid number")
        
        # AI choice
        ai_action, _ = model.predict(obs)
        
        # Evaluate both
        _, human_reward, _, human_info = env.step(human_action)
        _, ai_reward, _, ai_info = env.step(ai_action)
        
        # Display results
        print(f"\n🤖 AI chose: {ai_action}. {ai_info['chosen']}")
        print(f"🧑 You chose: {human_action}. {human_info['chosen']}")
        
        print(f"\n💡 Correct answer: {[c['text'] for c in scenario['choices'] if c['correct']][0]}")
        
        if human_info['correct']:
            human_score += 1
            print("✅ You got it right!")
        else:
            print(f"❌ Your explanation: {human_info['explanation']}")
        
        if ai_info['correct']:
            ai_score += 1
            print("✅ AI got it right!")
        else:
            print(f"❌ AI explanation: {ai_info['explanation']}")
        
        print(f"\n📊 Score: You {human_score} - {ai_score} AI")
        print(f"{'='*50}")
    
    print("\n🏆 Final Results:")
    print(f"You: {human_score} correct answers")
    print(f"AI: {ai_score} correct answers")
    
    if human_score > ai_score:
        print("\n🎉 You beat the AI! Great job!")
    elif human_score == ai_score:
        print("\n🤝 It's a tie! Good match!")
    else:
        print("\n🤖 The AI won this time. Try again!")

def main():
    print("🚀 Enhanced Emotion-Based RL & AI Therapy System")
    print(f"🔑 Using Gemini API Key: {GEMINI_API_KEY[:5]}...{GEMINI_API_KEY[-5:]}\n")
    
    # Initialize environment
    env = EmotionGameEnv()
    
    # Main menu
    while True:
        print("\nMain Menu:")
        print("1. Train new model")
        print("2. Evaluate trained model")
        print("3. Interactive demo (vs AI)")
        print("4. Exit")
        
        choice = input("Select an option (1-4): ")
        
        if choice == "1":
            # Training options
            timesteps = int(input("Enter training timesteps (default 10000): ") or 10000)
            print("\nUsing default model parameters:")
            for k, v in DEFAULT_MODEL_PARAMS.items():
                print(f"  {k}: {v}")
                
            if input("Modify parameters? (y/n): ").lower() == 'y':
                custom_params = {}
                for param in DEFAULT_MODEL_PARAMS.keys():
                    val = input(f"Enter new value for {param} (or press Enter to keep default): ")
                    if val:
                        try:
                            # Try to convert to appropriate type
                            custom_params[param] = eval(val) if val.lower() not in ['true', 'false'] else val.lower() == 'true'
                        except:
                            custom_params[param] = val
                model = train_rl_model(env, total_timesteps=timesteps, model_params=custom_params)
            else:
                model = train_rl_model(env, total_timesteps=timesteps)
                
        elif choice == "2":
            # Evaluation
            num_tests = int(input("Enter number of test scenarios (default 10): ") or 10)
            model_path = input("Enter model path (default 'emotional_rl_agent_adaptive'): ") or "emotional_rl_agent_adaptive"
            evaluate_model(env, model_path=model_path, num_tests=num_tests)
            
        elif choice == "3":
            # Interactive demo
            model_path = input("Enter model path (default 'emotional_rl_agent_adaptive'): ") or "emotional_rl_agent_adaptive"
            interactive_demo(env, model_path=model_path)
            
        elif choice == "4":
            print("Exiting...")
            break
            
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
#   Cell In[2], line 345
#     for round_num in range(1, num_rounds + 1):
#                                              ^
# SyntaxError: invalid syntax

# %%
import os
import json
import re
import requests
from dotenv import load_dotenv

# === Load Gemini API Key ===
def load_api_key():
    env_path = "../models/key.env"
    load_dotenv(env_path)
    api_key = os.getenv("GEMINI_API_KEY") or "AIzaSyA2rRBLcJx_e5g4d_fVOgG4q2Pf8ewPI70"
    if not api_key:
        raise ValueError("❌ Gemini API Key not found.")
    print("✅ Gemini API Key loaded successfully!")
    return api_key

# === Extract clean JSON from Gemini response ===
def extract_json_block(text):
    # Remove markdown code block notation if present
    text = text.replace('```json', '').replace('```', '').strip()
    match = re.search(r'\{[\s\S]*?\}', text)
    return match.group(0) if match else None

# === Generate Scenario with Difficulty and Best Choice ===
def generate_scenario_with_feedback(emotion="stress", tag="generated", difficulty="medium", retries=1):
    GEMINI_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?key=" + load_api_key()

    prompt = (
        "You are an expert game designer AI that only responds in valid JSON format. "
        "Do not include markdown or explanations.\n\n"
        f"The user is experiencing the emotion '{emotion}'.\n"
        f"The scenario should be '{difficulty}' in difficulty.\n"
        "Generate a valid JSON object containing:\n"
        "- A stressful 'scenario' (1-2 sentences)\n"
        "- 4 unique 'responses' with an 'option' and a 'reward' (-3 to 3)\n"
        "- The index (0-3) of the option the user chose called 'chosen_action'\n"
        "- A 'difficulty' level: easy, medium, or hard\n"
        "Return JSON in this structure ONLY:\n"
        "{\n"
        "  'tag': 'stress_situation',\n"
        "  'emotion': 'stress',\n"
        "  'scenario': '...',\n"
        "  'difficulty': 'medium',\n"
        "  'responses': [\n"
        "    {'option': '...', 'reward': 2},\n"
        "    {'option': '...', 'reward': -1},\n"
        "    {'option': '...', 'reward': 3},\n"
        "    {'option': '...', 'reward': -2}\n"
        "  ],\n"
        "  'chosen_action': 2\n"
        "}"
    )

    headers = {"Content-Type": "application/json"}
    data = {"contents": [{"parts": [{"text": prompt}]}]}

    for attempt in range(retries + 1):
        try:
            response = requests.post(GEMINI_URL, headers=headers, json=data)
            if response.ok:
                raw = response.json()["candidates"][0]["content"]["parts"][0]["text"]
                json_block = extract_json_block(raw)
                if json_block:
                    try:
                        cleaned = json_block.replace("'", '"')
                        parsed = json.loads(cleaned)
                        parsed["emotion"] = emotion
                        parsed["tag"] = tag
                        return parsed
                    except json.JSONDecodeError as e:
                        print(f"🚫 JSONDecodeError (Attempt {attempt+1}):", e)
                        print("📄 Raw response:\n", raw)
                else:
                    print(f"⚠️ No JSON object found in response (Attempt {attempt+1}).\n📄 Raw response:\n", raw)
            else:
                print("❌ Gemini API Error:", response.status_code)
        except Exception as e:
            print("❌ Request failed:", str(e))
    return None

# === Difficulty Adjustment Logic ===
def adjust_difficulty(stress_score):
    if stress_score <= -5:
        return "easy"
    elif stress_score >= 5:
        return "hard"
    else:
        return "medium"

# === Main ===
def main():
    print("🚀 Starting Stress Scenario Generation with Adaptive Difficulty...\n")
    load_api_key()
    all_scenarios = []
    stress_score = 0

    for i in range(5):
        difficulty = adjust_difficulty(stress_score)
        print(f"\n📘 Generating Scenario {i+1} (difficulty: {difficulty}, current stress score: {stress_score})...")
        scenario = generate_scenario_with_feedback(difficulty=difficulty, retries=1)

        if scenario:
            reward = scenario["responses"][scenario["chosen_action"]]["reward"]
            stress_score += reward
            all_scenarios.append(scenario)

            # ✅ Friendly summary print
            print(f"\n✅ Scenario {i+1} Summary:")
            print(f"📖 Scenario       : {scenario['scenario']}")
            print(f"🎯 Chosen Action  : {scenario['responses'][scenario['chosen_action']]['option']}")
            print(f"🎁 Reward         : {reward}")
            print(f"⚙️  Difficulty     : {scenario['difficulty']}")
            print(f"📊 Stress Score   : {stress_score}")
            print("-" * 60)
        else:
            print(f"⚠️ Failed to generate scenario {i+1}")

    # Save all scenarios
    if all_scenarios:  # Only save if we have scenarios
        with open("generated_scenarios.json", "w") as f:
            json.dump(all_scenarios, f, indent=2)
        print("\n📁 All scenarios saved to 'generated_scenarios.json'")
    else:
        print("\n❌ No scenarios were generated to save.")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting Stress Scenario Generation with Adaptive Difficulty...
#
# ✅ Gemini API Key loaded successfully!
#
# 📘 Generating Scenario 1 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# 🚫 JSONDecodeError (Attempt 1): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop is malfunctioning, and you've misplaced your presentation notes.  Traffic is unusually heavy.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and rush through the presentation, hoping for the best.", "reward": -3},
#     {"option": "Call the client and explain the situation, requesting a reschedule.", "reward": 1},
#     {"option": "Quickly reboot your laptop, use your phone as a backup, and improvise a simplified presentation.", "reward": 3},
#     {"option": "Pull over to the side of the road to regain composure and gather your thoughts before continuing.", "reward": -1}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 🚫 JSONDecodeError (Attempt 2): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop has crashed, and you've misplaced your presentation notes.  You only have five minutes until your scheduled meeting time.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and attempt a frantic recovery of your laptop and notes, hoping for the best.", "reward": -2},
#     {"option": "Call the client, explain the situation, and propose rescheduling.", "reward": 1},
#     {"option": "Quickly summarize key points from memory and deliver a concise, though incomplete presentation, emphasizing your ability to adapt.", "reward": 3},
#     {"option": "Pretend everything is fine, deliver the presentation as planned (or as best as you can), and hope they don't notice the missing information.", "reward": -3}
#   ],
#   "chosen_action": 2
# }
# ```
#
# ⚠️ Failed to generate scenario 1
#
# 📘 Generating Scenario 2 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# 🚫 JSONDecodeError (Attempt 1): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, and your carefully prepared presentation files are corrupted. Your phone battery is also dead.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to fix the files, hoping to make it on time.", "reward": -1},
#     {"option": "Call the client to inform them of the situation and reschedule.", "reward": 2},
#     {"option": "Use a nearby computer to present a condensed version from memory, focusing on key points.", "reward": 3},
#     {"option": "Leave and abandon the presentation altogether.", "reward": -3}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 🚫 JSONDecodeError (Attempt 2): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop is malfunctioning, and you've misplaced your presentation notes.  Traffic is unexpectedly heavy.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and rush through the presentation, hoping for the best.", "reward": -2},
#     {"option": "Pull over, take a few deep breaths to calm down, and try to troubleshoot your laptop.", "reward": 1},
#     {"option": "Call the client and explain the situation, proposing to reschedule or deliver the presentation remotely.", "reward": 3},
#     {"option": "Attempt to wing the presentation without your notes, relying on your memory.", "reward": -1}
#   ],
#   "chosen_action": 2
# }
# ```
#
# ⚠️ Failed to generate scenario 2
#
# 📘 Generating Scenario 3 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# 🚫 JSONDecodeError (Attempt 1): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, and your laptop battery is critically low.  Traffic is unexpectedly heavy.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Attempt the presentation with the failing laptop, hoping it lasts.", "reward": -1},
#     {"option": "Pull over and try to find a coffee shop with a reliable internet connection to remotely present.", "reward": 2},
#     {"option": "Call the client and reschedule, explaining the situation honestly.", "reward": 3},
#     {"option": "Panic and drive recklessly, risking an accident to make it on time.", "reward": -3}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 🚫 JSONDecodeError (Attempt 2): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop is malfunctioning, and you've misplaced your presentation notes.  The elevator is broken, and you must now take the stairs.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and rush up the stairs, potentially making more mistakes.", "reward": -3},
#     {"option": "Take deep breaths and calmly assess the situation, prioritizing finding your notes.", "reward": 1},
#     {"option": "Improvise a shortened, key-points-only presentation using your phone's notes.", "reward": 3},
#     {"option": "Call the client and explain the situation, requesting a short delay.", "reward": -1}
#   ],
#   "chosen_action": 2
# }
# ```
#
# ⚠️ Failed to generate scenario 3
#
# 📘 Generating Scenario 4 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# 🚫 JSONDecodeError (Attempt 1): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client,  your laptop is frozen, and you can't find your presentation slides.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to reboot your laptop, hoping it works quickly.", "reward": -2},
#     {"option": "Quickly pull up a summarized version of your presentation on your phone.", "reward": 1},
#     {"option": "Improvise a short, engaging presentation focusing on key points, apologizing for the technical difficulties.", "reward": 3},
#     {"option": "Inform the client of the issue and reschedule the presentation.", "reward": -1}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 🚫 JSONDecodeError (Attempt 2): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop is malfunctioning, and you've misplaced your presentation notes.  Traffic is jammed, and you're running out of time.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and rush, hoping for the best.", "reward": -3},
#     {"option": "Pull over, take deep breaths, and try to troubleshoot your laptop.", "reward": 1},
#     {"option": "Call the client, explain the situation, and request a short delay while finding a solution.", "reward": 3},
#     {"option": "Try to wing the presentation without notes, relying on your memory.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# ⚠️ Failed to generate scenario 4
#
# 📘 Generating Scenario 5 (difficulty: medium, current stress score: 0)...
# ✅ Gemini API Key loaded successfully!
# 🚫 JSONDecodeError (Attempt 1): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop is dead, and you've misplaced your presentation slides.  Traffic is at a standstill.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and try to improvise without the slides.", "reward": -1},
#     {"option": "Call the client and explain the situation, requesting a short delay.", "reward": 2},
#     {"option": "Quickly find a nearby coffee shop with Wi-Fi to access your cloud-saved presentation and charge your laptop.", "reward": 3},
#     {"option": "Try to find a print shop to print out your slides, potentially further delaying the presentation.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# 🚫 JSONDecodeError (Attempt 2): Expecting ',' delimiter: line 4 column 20 (char 73)
# 📄 Raw response:
#  ```json
# {
#   "tag": "stress_situation",
#   "emotion": "stress",
#   "scenario": "You're late for a crucial presentation to a major client, your laptop has frozen, and you've spilled coffee all over your notes.",
#   "difficulty": "medium",
#   "responses": [
#     {"option": "Panic and attempt to restart your laptop, hoping it'll reboot quickly enough.", "reward": -1},
#     {"option": "Improvise a brief presentation from memory, focusing on the key points.", "reward": 2},
#     {"option": "Admit the technical difficulties to the client, calmly offer a rescheduled presentation, and send them the presentation slides immediately.", "reward": 3},
#     {"option": "Ignore the problem and rush through a disjointed, confusing presentation.", "reward": -2}
#   ],
#   "chosen_action": 2
# }
# ```
#
# ⚠️ Failed to generate scenario 5
#
# ❌ No scenarios were generated to save.
