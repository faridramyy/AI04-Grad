# %%
import os
import subprocess

input_dir = r"D:\graduation project folder farid version\C-crema video dataset"
output_dir = r"D:\graduation project folder farid version\converted"

os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.endswith(".flv"):
        input_path = os.path.join(input_dir, file)
        output_path = os.path.join(output_dir, file.replace(".flv", ".mp4"))
        
        cmd = f'ffmpeg -i "{input_path}" "{output_path}"'
        subprocess.call(cmd, shell=True)

# %%
import os
import cv2

# Paths
video_dir = r"D:\graduation project folder farid version\converted"
frame_dir = r"D:\graduation project folder farid version\video dataset_frames"

# Extract frames
def extract_frames(video_dir, frame_dir):
    os.makedirs(frame_dir, exist_ok=True)
    
    for video_file in os.listdir(video_dir):
        if video_file.endswith(".mp4"):
            video_path = os.path.join(video_dir, video_file)
            video_name = os.path.splitext(video_file)[0]
            output_folder = os.path.join(frame_dir, video_name)
            os.makedirs(output_folder, exist_ok=True)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            if not cap.isOpened():
                print(f"Error: Could not open {video_file}")
                continue  # Skip this file

            frame_count = 0
            while True:
                ret, frame = cap.read()
                if not ret:
                    print(f"Finished extracting {frame_count} frames from {video_file}")
                    break

                frame_path = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
                cv2.imwrite(frame_path, frame)
                frame_count += 1

            cap.release()

# Run extraction
extract_frames(video_dir, frame_dir)
# Out:
# Finished extracting 68 frames from 1001_DFA_ANG_XX.mp4
# Finished extracting 71 frames from 1001_DFA_DIS_XX.mp4
# Finished extracting 66 frames from 1001_DFA_FEA_XX.mp4
# Finished extracting 57 frames from 1001_DFA_HAP_XX.mp4
# Finished extracting 62 frames from 1001_DFA_NEU_XX.mp4
# Finished extracting 61 frames from 1001_DFA_SAD_XX.mp4
# Finished extracting 59 frames from 1001_IEO_ANG_HI.mp4
# Finished extracting 63 frames from 1001_IEO_ANG_LO.mp4
# Finished extracting 80 frames from 1001_IEO_ANG_MD.mp4
# Finished extracting 61 frames from 1001_IEO_DIS_HI.mp4
# Finished extracting 61 frames from 1001_IEO_DIS_LO.mp4
# Finished extracting 58 frames from 1001_IEO_DIS_MD.mp4
# Finished extracting 48 frames from 1001_IEO_FEA_HI.mp4
# Finished extracting 47 frames from 1001_IEO_FEA_LO.mp4
# Finished extracting 49 frames from 1001_IEO_FEA_MD.mp4
# Finished extracting 54 frames from 1001_IEO_HAP_HI.mp4
# Finished extracting 52 frames from 1001_IEO_HAP_LO.mp4
# Finished extracting 51 frames from 1001_IEO_HAP_MD.mp4
# Finished extracting 49 frames from 1001_IEO_NEU_XX.mp4
# Finished extracting 61 frames from 1001_IEO_SAD_HI.mp4
# Finished extracting 58 frames from 1001_IEO_SAD_LO.mp4
# Finished extracting 53 frames from 1001_IEO_SAD_MD.mp4
# Finished extracting 65 frames from 1001_IOM_ANG_XX.mp4
# Finished extracting 69 frames from 1001_IOM_DIS_XX.mp4
# Finished extracting 86 frames from 1001_IOM_FEA_XX.mp4
# Finished extracting 61 frames from 1001_IOM_HAP_XX.mp4
# Finished extracting 75 frames from 1001_IOM_NEU_XX.mp4
# Finished extracting 59 frames from 1001_IOM_SAD_XX.mp4
# Finished extracting 72 frames from 1001_ITH_ANG_XX.mp4
# Finished extracting 66 frames from 1001_ITH_DIS_XX.mp4
# Finished extracting 64 frames from 1001_ITH_FEA_XX.mp4
# Finished extracting 75 frames from 1001_ITH_HAP_XX.mp4
# Finished extracting 79 frames from 1001_ITH_NEU_XX.mp4
# Finished extracting 72 frames from 1001_ITH_SAD_XX.mp4
# Finished extracting 78 frames from 1001_ITS_ANG_XX.mp4
# Finished extracting 67 frames from 1001_ITS_DIS_XX.mp4
# Finished extracting 65 frames from 1001_ITS_FEA_XX.mp4
# Finished extracting 67 frames from 1001_ITS_HAP_XX.mp4
# Finished extracting 74 frames from 1001_ITS_NEU_XX.mp4
# Finished extracting 81 frames from 1001_ITS_SAD_XX.mp4
# Finished extracting 96 frames from 1001_IWL_ANG_XX.mp4
# Finished extracting 78 frames from 1001_IWL_DIS_XX.mp4
# Finished extracting 72 frames from 1001_IWL_FEA_XX.mp4
# Finished extracting 64 frames from 1001_IWL_HAP_XX.mp4
# Finished extracting 86 frames from 1001_IWL_NEU_XX.mp4
# Finished extracting 86 frames from 1001_IWL_SAD_XX.mp4
# Finished extracting 68 frames from 1001_IWW_ANG_XX.mp4
# Finished extracting 63 frames from 1001_IWW_DIS_XX.mp4
# Finished extracting 67 frames from 1001_IWW_FEA_XX.mp4
# Finished extracting 60 frames from 1001_IWW_HAP_XX.mp4
# Finished extracting 69 frames from 1001_IWW_NEU_XX.mp4
# Finished extracting 62 frames from 1001_IWW_SAD_XX.mp4
# Finished extracting 91 frames from 1001_MTI_ANG_XX.mp4
# Finished extracting 89 frames from 1001_MTI_DIS_XX.mp4
# Finished extracting 72 frames from 1001_MTI_FEA_XX.mp4
# Finished extracting 72 frames from 1001_MTI_HAP_XX.mp4
# Finished extracting 70 frames from 1001_MTI_NEU_XX.mp4
# Finished extracting 70 frames from 1001_MTI_SAD_XX.mp4
# Finished extracting 71 frames from 1001_TAI_ANG_XX.mp4
# Finished extracting 83 frames from 1001_TAI_DIS_XX.mp4
# Finished extracting 73 frames from 1001_TAI_FEA_XX.mp4
# Finished extracting 76 frames from 1001_TAI_HAP_XX.mp4
# Finished extracting 78 frames from 1001_TAI_NEU_XX.mp4
# Finished extracting 85 frames from 1001_TAI_SAD_XX.mp4
# Finished extracting 94 frames from 1001_TIE_ANG_XX.mp4
# Finished extracting 67 frames from 1001_TIE_DIS_XX.mp4
# Finished extracting 68 frames from 1001_TIE_FEA_XX.mp4
# Finished extracting 70 frames from 1001_TIE_HAP_XX.mp4
# Finished extracting 77 frames from 1001_TIE_NEU_XX.mp4
# Finished extracting 92 frames from 1001_TIE_SAD_XX.mp4
# Finished extracting 76 frames from 1001_TSI_ANG_XX.mp4
# Finished extracting 66 frames from 1001_TSI_DIS_XX.mp4
# Finished extracting 58 frames from 1001_TSI_FEA_XX.mp4
# Finished extracting 66 frames from 1001_TSI_HAP_XX.mp4
# Finished extracting 74 frames from 1001_TSI_NEU_XX.mp4
# Finished extracting 76 frames from 1001_TSI_SAD_XX.mp4
# Finished extracting 83 frames from 1001_WSI_ANG_XX.mp4
# Finished extracting 81 frames from 1001_WSI_DIS_XX.mp4
# Finished extracting 71 frames from 1001_WSI_FEA_XX.mp4
# Finished extracting 68 frames from 1001_WSI_HAP_XX.mp4
# Finished extracting 83 frames from 1001_WSI_NEU_XX.mp4
# Finished extracting 71 frames from 1001_WSI_SAD_XX.mp4
# Finished extracting 78 frames from 1002_DFA_ANG_XX.mp4
# Finished extracting 77 frames from 1002_DFA_DIS_XX.mp4
# Finished extracting 83 frames from 1002_DFA_FEA_XX.mp4
# Finished extracting 67 frames from 1002_DFA_HAP_XX.mp4
# Finished extracting 76 frames from 1002_DFA_NEU_XX.mp4
# Finished extracting 72 frames from 1002_DFA_SAD_XX.mp4
# Finished extracting 83 frames from 1002_IEO_ANG_HI.mp4
# Finished extracting 73 frames from 1002_IEO_ANG_LO.mp4
# Finished extracting 84 frames from 1002_IEO_ANG_MD.mp4
# Finished extracting 91 frames from 1002_IEO_DIS_HI.mp4
# Finished extracting 87 frames from 1002_IEO_DIS_LO.mp4
# Finished extracting 79 frames from 1002_IEO_DIS_MD.mp4
# Finished extracting 97 frames from 1002_IEO_FEA_HI.mp4
# Finished extracting 79 frames from 1002_IEO_FEA_LO.mp4
# Finished extracting 59 frames from 1002_IEO_FEA_MD.mp4
# Finished extracting 76 frames from 1002_IEO_HAP_HI.mp4
# Finished extracting 86 frames from 1002_IEO_HAP_LO.mp4
# Finished extracting 69 frames from 1002_IEO_HAP_MD.mp4
# Finished extracting 78 frames from 1002_IEO_NEU_XX.mp4
# Finished extracting 83 frames from 1002_IEO_SAD_HI.mp4
# Finished extracting 69 frames from 1002_IEO_SAD_LO.mp4
# Finished extracting 72 frames from 1002_IEO_SAD_MD.mp4
# Finished extracting 86 frames from 1002_IOM_ANG_XX.mp4
# Finished extracting 84 frames from 1002_IOM_DIS_XX.mp4
# Finished extracting 79 frames from 1002_IOM_FEA_XX.mp4
# Finished extracting 71 frames from 1002_IOM_HAP_XX.mp4
# Finished extracting 71 frames from 1002_IOM_NEU_XX.mp4
# Finished extracting 81 frames from 1002_IOM_SAD_XX.mp4
# Finished extracting 89 frames from 1002_ITH_ANG_XX.mp4
# Finished extracting 115 frames from 1002_ITH_DIS_XX.mp4
# Finished extracting 106 frames from 1002_ITH_FEA_XX.mp4
# Finished extracting 84 frames from 1002_ITH_HAP_XX.mp4
# Finished extracting 76 frames from 1002_ITH_NEU_XX.mp4
# Finished extracting 83 frames from 1002_ITH_SAD_XX.mp4
# Finished extracting 82 frames from 1002_ITS_ANG_XX.mp4
# Finished extracting 86 frames from 1002_ITS_DIS_XX.mp4
# Finished extracting 75 frames from 1002_ITS_FEA_XX.mp4
# Finished extracting 74 frames from 1002_ITS_HAP_XX.mp4
# Finished extracting 71 frames from 1002_ITS_NEU_XX.mp4
# Finished extracting 80 frames from 1002_ITS_SAD_XX.mp4
# Finished extracting 79 frames from 1002_IWL_ANG_XX.mp4
# Finished extracting 94 frames from 1002_IWL_DIS_XX.mp4
# Finished extracting 98 frames from 1002_IWL_FEA_XX.mp4
# Finished extracting 87 frames from 1002_IWL_HAP_XX.mp4
# Finished extracting 80 frames from 1002_IWL_NEU_XX.mp4
# Finished extracting 82 frames from 1002_IWL_SAD_XX.mp4
# Finished extracting 73 frames from 1002_IWW_ANG_XX.mp4
# Finished extracting 94 frames from 1002_IWW_DIS_XX.mp4
# Finished extracting 79 frames from 1002_IWW_FEA_XX.mp4
# Finished extracting 75 frames from 1002_IWW_HAP_XX.mp4
# Finished extracting 76 frames from 1002_IWW_NEU_XX.mp4
# Finished extracting 72 frames from 1002_IWW_SAD_XX.mp4
# Finished extracting 83 frames from 1002_MTI_ANG_XX.mp4
# Finished extracting 110 frames from 1002_MTI_DIS_XX.mp4
# Finished extracting 89 frames from 1002_MTI_FEA_XX.mp4
# Finished extracting 81 frames from 1002_MTI_HAP_XX.mp4
# Finished extracting 87 frames from 1002_MTI_NEU_XX.mp4
# Finished extracting 82 frames from 1002_MTI_SAD_XX.mp4
# Finished extracting 76 frames from 1002_TAI_ANG_XX.mp4
# Finished extracting 97 frames from 1002_TAI_DIS_XX.mp4
# Finished extracting 84 frames from 1002_TAI_FEA_XX.mp4
# Finished extracting 77 frames from 1002_TAI_HAP_XX.mp4
# Finished extracting 80 frames from 1002_TAI_NEU_XX.mp4
# Finished extracting 84 frames from 1002_TAI_SAD_XX.mp4
# Finished extracting 77 frames from 1002_TIE_ANG_XX.mp4
# Finished extracting 109 frames from 1002_TIE_DIS_XX.mp4
# Finished extracting 95 frames from 1002_TIE_FEA_XX.mp4
# Finished extracting 73 frames from 1002_TIE_HAP_XX.mp4
# Finished extracting 95 frames from 1002_TIE_SAD_XX.mp4
# Finished extracting 74 frames from 1002_TSI_ANG_XX.mp4
# Finished extracting 84 frames from 1002_TSI_DIS_XX.mp4
# Finished extracting 71 frames from 1002_TSI_FEA_XX.mp4
# Finished extracting 62 frames from 1002_TSI_HAP_XX.mp4
# Finished extracting 72 frames from 1002_TSI_NEU_XX.mp4
# Finished extracting 73 frames from 1002_TSI_SAD_XX.mp4
# Finished extracting 79 frames from 1002_WSI_ANG_XX.mp4
# Finished extracting 104 frames from 1002_WSI_DIS_XX.mp4
# Finished extracting 76 frames from 1002_WSI_FEA_XX.mp4
# Finished extracting 84 frames from 1002_WSI_HAP_XX.mp4
# Finished extracting 74 frames from 1002_WSI_NEU_XX.mp4
# Finished extracting 83 frames from 1002_WSI_SAD_XX.mp4
# Finished extracting 95 frames from 1003_DFA_ANG_XX.mp4
# Finished extracting 98 frames from 1003_DFA_DIS_XX.mp4
# Finished extracting 93 frames from 1003_DFA_FEA_XX.mp4
# Finished extracting 99 frames from 1003_DFA_HAP_XX.mp4
# Finished extracting 98 frames from 1003_DFA_NEU_XX.mp4
# Finished extracting 97 frames from 1003_DFA_SAD_XX.mp4
# Finished extracting 78 frames from 1003_IEO_ANG_HI.mp4
# Finished extracting 68 frames from 1003_IEO_ANG_LO.mp4
# Finished extracting 78 frames from 1003_IEO_ANG_MD.mp4
# Finished extracting 96 frames from 1003_IEO_DIS_HI.mp4
# Finished extracting 61 frames from 1003_IEO_DIS_LO.mp4
# Finished extracting 63 frames from 1003_IEO_DIS_MD.mp4
# Finished extracting 84 frames from 1003_IEO_FEA_HI.mp4
# Finished extracting 78 frames from 1003_IEO_FEA_LO.mp4
# Finished extracting 76 frames from 1003_IEO_FEA_MD.mp4
# Finished extracting 67 frames from 1003_IEO_HAP_HI.mp4
# Finished extracting 72 frames from 1003_IEO_HAP_LO.mp4
# Finished extracting 70 frames from 1003_IEO_HAP_MD.mp4
# Finished extracting 69 frames from 1003_IEO_NEU_XX.mp4
# Finished extracting 75 frames from 1003_IEO_SAD_HI.mp4
# Finished extracting 76 frames from 1003_IEO_SAD_LO.mp4
# Finished extracting 81 frames from 1003_IEO_SAD_MD.mp4
# Finished extracting 83 frames from 1003_IOM_ANG_XX.mp4
# Finished extracting 100 frames from 1003_IOM_DIS_XX.mp4
# Finished extracting 81 frames from 1003_IOM_FEA_XX.mp4
# Finished extracting 88 frames from 1003_IOM_HAP_XX.mp4
# Finished extracting 97 frames from 1003_IOM_NEU_XX.mp4
# Finished extracting 86 frames from 1003_IOM_SAD_XX.mp4
# Finished extracting 111 frames from 1003_ITH_ANG_XX.mp4
# Finished extracting 122 frames from 1003_ITH_DIS_XX.mp4
# Finished extracting 107 frames from 1003_ITH_FEA_XX.mp4
# Finished extracting 95 frames from 1003_ITH_HAP_XX.mp4
# Finished extracting 122 frames from 1003_ITH_NEU_XX.mp4
# Finished extracting 110 frames from 1003_ITH_SAD_XX.mp4
# Finished extracting 113 frames from 1003_ITS_ANG_XX.mp4
# Finished extracting 112 frames from 1003_ITS_DIS_XX.mp4
# Finished extracting 95 frames from 1003_ITS_FEA_XX.mp4
# Finished extracting 113 frames from 1003_ITS_HAP_XX.mp4
# Finished extracting 113 frames from 1003_ITS_NEU_XX.mp4
# Finished extracting 106 frames from 1003_ITS_SAD_XX.mp4
# Finished extracting 107 frames from 1003_IWL_ANG_XX.mp4
# Finished extracting 133 frames from 1003_IWL_DIS_XX.mp4
# Finished extracting 111 frames from 1003_IWL_FEA_XX.mp4
# Finished extracting 118 frames from 1003_IWL_HAP_XX.mp4
# Finished extracting 119 frames from 1003_IWL_NEU_XX.mp4
# Finished extracting 113 frames from 1003_IWL_SAD_XX.mp4
# Finished extracting 103 frames from 1003_IWW_ANG_XX.mp4
# Finished extracting 94 frames from 1003_IWW_DIS_XX.mp4
# Finished extracting 101 frames from 1003_IWW_FEA_XX.mp4
# Finished extracting 106 frames from 1003_IWW_HAP_XX.mp4
# Finished extracting 88 frames from 1003_IWW_NEU_XX.mp4
# Finished extracting 82 frames from 1003_IWW_SAD_XX.mp4
# Finished extracting 101 frames from 1003_MTI_ANG_XX.mp4
# Finished extracting 128 frames from 1003_MTI_DIS_XX.mp4
# Finished extracting 97 frames from 1003_MTI_FEA_XX.mp4
# Finished extracting 100 frames from 1003_MTI_HAP_XX.mp4
# Finished extracting 113 frames from 1003_MTI_NEU_XX.mp4
# Finished extracting 114 frames from 1003_MTI_SAD_XX.mp4
# Finished extracting 87 frames from 1003_TAI_ANG_XX.mp4
# Finished extracting 97 frames from 1003_TAI_DIS_XX.mp4
# Finished extracting 95 frames from 1003_TAI_FEA_XX.mp4
# Finished extracting 95 frames from 1003_TAI_HAP_XX.mp4
# Finished extracting 111 frames from 1003_TAI_NEU_XX.mp4
# Finished extracting 101 frames from 1003_TAI_SAD_XX.mp4
# Finished extracting 96 frames from 1003_TIE_ANG_XX.mp4
# Finished extracting 129 frames from 1003_TIE_DIS_XX.mp4
# Finished extracting 88 frames from 1003_TIE_FEA_XX.mp4
# Finished extracting 99 frames from 1003_TIE_HAP_XX.mp4
# Finished extracting 77 frames from 1003_TIE_NEU_XX.mp4
# Finished extracting 132 frames from 1003_TIE_SAD_XX.mp4
# Finished extracting 120 frames from 1003_TSI_ANG_XX.mp4
# Finished extracting 109 frames from 1003_TSI_DIS_XX.mp4
# Finished extracting 98 frames from 1003_TSI_FEA_XX.mp4
# Finished extracting 102 frames from 1003_TSI_HAP_XX.mp4
# Finished extracting 104 frames from 1003_TSI_NEU_XX.mp4
# Finished extracting 90 frames from 1003_TSI_SAD_XX.mp4
# Finished extracting 107 frames from 1003_WSI_ANG_XX.mp4
# Finished extracting 105 frames from 1003_WSI_DIS_XX.mp4
# Finished extracting 100 frames from 1003_WSI_FEA_XX.mp4
# Finished extracting 96 frames from 1003_WSI_HAP_XX.mp4
# Finished extracting 104 frames from 1003_WSI_NEU_XX.mp4
# Finished extracting 102 frames from 1003_WSI_SAD_XX.mp4
# Finished extracting 93 frames from 1004_DFA_ANG_XX.mp4
# Finished extracting 88 frames from 1004_DFA_DIS_XX.mp4
# Finished extracting 92 frames from 1004_DFA_FEA_XX.mp4
# Finished extracting 83 frames from 1004_DFA_HAP_XX.mp4
# Finished extracting 94 frames from 1004_DFA_NEU_XX.mp4
# Finished extracting 86 frames from 1004_DFA_SAD_XX.mp4
# Finished extracting 121 frames from 1004_IEO_ANG_HI.mp4
# Finished extracting 81 frames from 1004_IEO_ANG_LO.mp4
# Finished extracting 88 frames from 1004_IEO_ANG_MD.mp4
# Finished extracting 146 frames from 1004_IEO_DIS_HI.mp4
# Finished extracting 74 frames from 1004_IEO_DIS_LO.mp4
# Finished extracting 110 frames from 1004_IEO_DIS_MD.mp4
# Finished extracting 102 frames from 1004_IEO_FEA_HI.mp4
# Finished extracting 104 frames from 1004_IEO_FEA_LO.mp4
# Finished extracting 84 frames from 1004_IEO_FEA_MD.mp4
# Finished extracting 89 frames from 1004_IEO_HAP_HI.mp4
# Finished extracting 73 frames from 1004_IEO_HAP_LO.mp4
# Finished extracting 92 frames from 1004_IEO_HAP_MD.mp4
# Finished extracting 71 frames from 1004_IEO_NEU_XX.mp4
# Finished extracting 151 frames from 1004_IEO_SAD_HI.mp4
# Finished extracting 86 frames from 1004_IEO_SAD_LO.mp4
# Finished extracting 122 frames from 1004_IEO_SAD_MD.mp4
# Finished extracting 79 frames from 1004_IOM_ANG_XX.mp4
# Finished extracting 82 frames from 1004_IOM_DIS_XX.mp4
# Finished extracting 74 frames from 1004_IOM_FEA_XX.mp4
# Finished extracting 101 frames from 1004_IOM_HAP_XX.mp4
# Finished extracting 77 frames from 1004_IOM_NEU_XX.mp4
# Finished extracting 87 frames from 1004_IOM_SAD_XX.mp4
# Finished extracting 99 frames from 1004_ITH_ANG_XX.mp4
# Finished extracting 110 frames from 1004_ITH_DIS_XX.mp4
# Finished extracting 113 frames from 1004_ITH_FEA_XX.mp4
# Finished extracting 91 frames from 1004_ITH_HAP_XX.mp4
# Finished extracting 110 frames from 1004_ITH_NEU_XX.mp4
# Finished extracting 107 frames from 1004_ITH_SAD_XX.mp4
# Finished extracting 102 frames from 1004_ITS_ANG_XX.mp4
# Finished extracting 93 frames from 1004_ITS_DIS_XX.mp4
# Finished extracting 83 frames from 1004_ITS_FEA_XX.mp4
# Finished extracting 87 frames from 1004_ITS_HAP_XX.mp4
# Finished extracting 101 frames from 1004_ITS_NEU_XX.mp4
# Finished extracting 91 frames from 1004_ITS_SAD_XX.mp4
# Finished extracting 96 frames from 1004_IWL_ANG_XX.mp4
# Finished extracting 101 frames from 1004_IWL_DIS_XX.mp4
# Finished extracting 102 frames from 1004_IWL_FEA_XX.mp4
# Finished extracting 91 frames from 1004_IWL_HAP_XX.mp4
# Finished extracting 118 frames from 1004_IWL_NEU_XX.mp4
# Finished extracting 100 frames from 1004_IWL_SAD_XX.mp4
# Finished extracting 72 frames from 1004_IWW_ANG_XX.mp4
# Finished extracting 89 frames from 1004_IWW_DIS_XX.mp4
# Finished extracting 81 frames from 1004_IWW_FEA_XX.mp4
# Finished extracting 99 frames from 1004_IWW_HAP_XX.mp4
# Finished extracting 92 frames from 1004_IWW_NEU_XX.mp4
# Finished extracting 86 frames from 1004_IWW_SAD_XX.mp4
# Finished extracting 100 frames from 1004_MTI_ANG_XX.mp4
# Finished extracting 110 frames from 1004_MTI_DIS_XX.mp4
# Finished extracting 97 frames from 1004_MTI_FEA_XX.mp4
# Finished extracting 97 frames from 1004_MTI_HAP_XX.mp4
# Finished extracting 112 frames from 1004_MTI_NEU_XX.mp4
# Finished extracting 100 frames from 1004_MTI_SAD_XX.mp4
# Finished extracting 102 frames from 1004_TAI_ANG_XX.mp4
# Finished extracting 118 frames from 1004_TAI_DIS_XX.mp4
# Finished extracting 89 frames from 1004_TAI_FEA_XX.mp4
# Finished extracting 79 frames from 1004_TAI_HAP_XX.mp4
# Finished extracting 105 frames from 1004_TAI_NEU_XX.mp4
# Finished extracting 104 frames from 1004_TAI_SAD_XX.mp4
# Finished extracting 86 frames from 1004_TIE_ANG_XX.mp4
# Finished extracting 131 frames from 1004_TIE_DIS_XX.mp4
# Finished extracting 84 frames from 1004_TIE_FEA_XX.mp4
# Finished extracting 90 frames from 1004_TIE_HAP_XX.mp4
# Finished extracting 71 frames from 1004_TIE_NEU_XX.mp4
# Finished extracting 91 frames from 1004_TIE_SAD_XX.mp4
# Finished extracting 72 frames from 1004_TSI_ANG_XX.mp4
# Finished extracting 92 frames from 1004_TSI_DIS_XX.mp4
# Finished extracting 88 frames from 1004_TSI_FEA_XX.mp4
# Finished extracting 71 frames from 1004_TSI_HAP_XX.mp4
# Finished extracting 101 frames from 1004_TSI_NEU_XX.mp4
# Finished extracting 74 frames from 1004_TSI_SAD_XX.mp4
# Finished extracting 91 frames from 1004_WSI_ANG_XX.mp4
# Finished extracting 106 frames from 1004_WSI_DIS_XX.mp4
# Finished extracting 79 frames from 1004_WSI_FEA_XX.mp4
# Finished extracting 78 frames from 1004_WSI_HAP_XX.mp4
# Finished extracting 98 frames from 1004_WSI_NEU_XX.mp4
# Finished extracting 113 frames from 1004_WSI_SAD_XX.mp4
# Finished extracting 79 frames from 1005_DFA_ANG_XX.mp4
# Finished extracting 83 frames from 1005_DFA_DIS_XX.mp4
# Finished extracting 75 frames from 1005_DFA_FEA_XX.mp4
# Finished extracting 78 frames from 1005_DFA_HAP_XX.mp4
# Finished extracting 94 frames from 1005_DFA_NEU_XX.mp4
# Finished extracting 92 frames from 1005_DFA_SAD_XX.mp4
# Finished extracting 76 frames from 1005_IEO_ANG_HI.mp4
# Finished extracting 69 frames from 1005_IEO_ANG_LO.mp4
# Finished extracting 83 frames from 1005_IEO_ANG_MD.mp4
# Finished extracting 85 frames from 1005_IEO_DIS_HI.mp4
# Finished extracting 73 frames from 1005_IEO_DIS_LO.mp4
# Finished extracting 76 frames from 1005_IEO_DIS_MD.mp4
# Finished extracting 73 frames from 1005_IEO_FEA_HI.mp4
# Finished extracting 67 frames from 1005_IEO_FEA_LO.mp4
# Finished extracting 95 frames from 1005_IEO_FEA_MD.mp4
# Finished extracting 69 frames from 1005_IEO_HAP_HI.mp4
# Finished extracting 64 frames from 1005_IEO_HAP_LO.mp4
# Finished extracting 66 frames from 1005_IEO_HAP_MD.mp4
# Finished extracting 64 frames from 1005_IEO_NEU_XX.mp4
# Finished extracting 75 frames from 1005_IEO_SAD_HI.mp4
# Finished extracting 73 frames from 1005_IEO_SAD_LO.mp4
# Finished extracting 68 frames from 1005_IEO_SAD_MD.mp4
# Finished extracting 102 frames from 1005_IOM_ANG_XX.mp4
# Finished extracting 90 frames from 1005_IOM_DIS_XX.mp4
# Finished extracting 97 frames from 1005_IOM_FEA_XX.mp4
# Finished extracting 95 frames from 1005_IOM_HAP_XX.mp4
# Finished extracting 83 frames from 1005_IOM_NEU_XX.mp4
# Finished extracting 91 frames from 1005_IOM_SAD_XX.mp4
# Finished extracting 100 frames from 1005_ITH_ANG_XX.mp4
# Finished extracting 113 frames from 1005_ITH_DIS_XX.mp4
# Finished extracting 96 frames from 1005_ITH_FEA_XX.mp4
# Finished extracting 99 frames from 1005_ITH_HAP_XX.mp4
# Finished extracting 102 frames from 1005_ITH_NEU_XX.mp4
# Finished extracting 99 frames from 1005_ITH_SAD_XX.mp4
# Finished extracting 108 frames from 1005_ITS_ANG_XX.mp4
# Finished extracting 95 frames from 1005_ITS_DIS_XX.mp4
# Finished extracting 90 frames from 1005_ITS_FEA_XX.mp4
# Finished extracting 90 frames from 1005_ITS_HAP_XX.mp4
# Finished extracting 95 frames from 1005_ITS_NEU_XX.mp4
# Finished extracting 101 frames from 1005_ITS_SAD_XX.mp4
# Finished extracting 102 frames from 1005_IWL_ANG_XX.mp4
# Finished extracting 101 frames from 1005_IWL_DIS_XX.mp4
# Finished extracting 102 frames from 1005_IWL_FEA_XX.mp4
# Finished extracting 91 frames from 1005_IWL_HAP_XX.mp4
# Finished extracting 98 frames from 1005_IWL_NEU_XX.mp4
# Finished extracting 112 frames from 1005_IWL_SAD_XX.mp4
# Finished extracting 100 frames from 1005_IWW_ANG_XX.mp4
# Finished extracting 94 frames from 1005_IWW_DIS_XX.mp4
# Finished extracting 94 frames from 1005_IWW_FEA_XX.mp4
# Finished extracting 82 frames from 1005_IWW_HAP_XX.mp4
# Finished extracting 82 frames from 1005_IWW_NEU_XX.mp4
# Finished extracting 71 frames from 1005_IWW_SAD_XX.mp4
# Finished extracting 112 frames from 1005_MTI_ANG_XX.mp4
# Finished extracting 119 frames from 1005_MTI_DIS_XX.mp4
# Finished extracting 109 frames from 1005_MTI_FEA_XX.mp4
# Finished extracting 106 frames from 1005_MTI_HAP_XX.mp4
# Finished extracting 102 frames from 1005_MTI_NEU_XX.mp4
# Finished extracting 94 frames from 1005_MTI_SAD_XX.mp4
# Finished extracting 109 frames from 1005_TAI_ANG_XX.mp4
# Finished extracting 110 frames from 1005_TAI_DIS_XX.mp4
# Finished extracting 77 frames from 1005_TAI_FEA_XX.mp4
# Finished extracting 86 frames from 1005_TAI_HAP_XX.mp4
# Finished extracting 100 frames from 1005_TAI_NEU_XX.mp4
# Finished extracting 110 frames from 1005_TAI_SAD_XX.mp4
# Finished extracting 89 frames from 1005_TIE_ANG_XX.mp4
# Finished extracting 103 frames from 1005_TIE_DIS_XX.mp4
# Finished extracting 78 frames from 1005_TIE_FEA_XX.mp4
# Finished extracting 127 frames from 1005_TIE_HAP_XX.mp4
# Finished extracting 87 frames from 1005_TIE_NEU_XX.mp4
# Finished extracting 142 frames from 1005_TIE_SAD_XX.mp4
# Finished extracting 91 frames from 1005_TSI_ANG_XX.mp4
# Finished extracting 109 frames from 1005_TSI_DIS_XX.mp4
# Finished extracting 88 frames from 1005_TSI_FEA_XX.mp4
# Finished extracting 86 frames from 1005_TSI_HAP_XX.mp4
# Finished extracting 85 frames from 1005_TSI_NEU_XX.mp4
# Finished extracting 100 frames from 1005_TSI_SAD_XX.mp4
# Finished extracting 103 frames from 1005_WSI_ANG_XX.mp4
# Finished extracting 112 frames from 1005_WSI_DIS_XX.mp4
# Finished extracting 84 frames from 1005_WSI_FEA_XX.mp4
# Finished extracting 82 frames from 1005_WSI_HAP_XX.mp4
# Finished extracting 95 frames from 1005_WSI_NEU_XX.mp4
# Finished extracting 101 frames from 1005_WSI_SAD_XX.mp4
# Finished extracting 79 frames from 1006_DFA_ANG_XX.mp4
# Finished extracting 84 frames from 1006_DFA_DIS_XX.mp4
# Finished extracting 72 frames from 1006_DFA_FEA_XX.mp4
# Finished extracting 70 frames from 1006_DFA_HAP_XX.mp4
# Finished extracting 78 frames from 1006_DFA_NEU_XX.mp4
# Finished extracting 81 frames from 1006_DFA_SAD_XX.mp4
# Finished extracting 78 frames from 1006_IEO_ANG_HI.mp4
# Finished extracting 76 frames from 1006_IEO_ANG_LO.mp4
# Finished extracting 55 frames from 1006_IEO_ANG_MD.mp4
# Finished extracting 98 frames from 1006_IEO_DIS_HI.mp4
# Finished extracting 63 frames from 1006_IEO_DIS_LO.mp4
# Finished extracting 91 frames from 1006_IEO_DIS_MD.mp4
# Finished extracting 80 frames from 1006_IEO_FEA_HI.mp4
# Finished extracting 66 frames from 1006_IEO_FEA_LO.mp4
# Finished extracting 70 frames from 1006_IEO_FEA_MD.mp4
# Finished extracting 56 frames from 1006_IEO_HAP_HI.mp4
# Finished extracting 52 frames from 1006_IEO_HAP_LO.mp4
# Finished extracting 69 frames from 1006_IEO_HAP_MD.mp4
# Finished extracting 64 frames from 1006_IEO_NEU_XX.mp4
# Finished extracting 68 frames from 1006_IEO_SAD_HI.mp4
# Finished extracting 56 frames from 1006_IEO_SAD_LO.mp4
# Finished extracting 58 frames from 1006_IEO_SAD_MD.mp4
# Finished extracting 99 frames from 1006_IOM_ANG_XX.mp4
# Finished extracting 98 frames from 1006_IOM_DIS_XX.mp4
# Finished extracting 114 frames from 1006_IOM_FEA_XX.mp4
# Finished extracting 81 frames from 1006_IOM_HAP_XX.mp4
# Finished extracting 98 frames from 1006_IOM_NEU_XX.mp4
# Finished extracting 91 frames from 1006_IOM_SAD_XX.mp4
# Finished extracting 97 frames from 1006_ITH_ANG_XX.mp4
# Finished extracting 127 frames from 1006_ITH_DIS_XX.mp4
# Finished extracting 98 frames from 1006_ITH_FEA_XX.mp4
# Finished extracting 92 frames from 1006_ITH_HAP_XX.mp4
# Finished extracting 104 frames from 1006_ITH_NEU_XX.mp4
# Finished extracting 112 frames from 1006_ITH_SAD_XX.mp4
# Finished extracting 97 frames from 1006_ITS_ANG_XX.mp4
# Finished extracting 101 frames from 1006_ITS_DIS_XX.mp4
# Finished extracting 90 frames from 1006_ITS_FEA_XX.mp4
# Finished extracting 84 frames from 1006_ITS_HAP_XX.mp4
# Finished extracting 91 frames from 1006_ITS_NEU_XX.mp4
# Finished extracting 94 frames from 1006_ITS_SAD_XX.mp4
# Finished extracting 101 frames from 1006_IWL_ANG_XX.mp4
# Finished extracting 105 frames from 1006_IWL_DIS_XX.mp4
# Finished extracting 82 frames from 1006_IWL_FEA_XX.mp4
# Finished extracting 86 frames from 1006_IWL_HAP_XX.mp4
# Finished extracting 92 frames from 1006_IWL_NEU_XX.mp4
# Finished extracting 95 frames from 1006_IWL_SAD_XX.mp4
# Finished extracting 83 frames from 1006_IWW_ANG_XX.mp4
# Finished extracting 111 frames from 1006_IWW_DIS_XX.mp4
# Finished extracting 107 frames from 1006_IWW_FEA_XX.mp4
# Finished extracting 85 frames from 1006_IWW_HAP_XX.mp4
# Finished extracting 94 frames from 1006_IWW_NEU_XX.mp4
# Finished extracting 116 frames from 1006_IWW_SAD_XX.mp4
# Finished extracting 114 frames from 1006_MTI_ANG_XX.mp4
# Finished extracting 113 frames from 1006_MTI_DIS_XX.mp4
# Finished extracting 137 frames from 1006_MTI_FEA_XX.mp4
# Finished extracting 109 frames from 1006_MTI_HAP_XX.mp4
# Finished extracting 123 frames from 1006_MTI_NEU_XX.mp4
# Finished extracting 128 frames from 1006_MTI_SAD_XX.mp4
# Finished extracting 97 frames from 1006_TAI_ANG_XX.mp4
# Finished extracting 107 frames from 1006_TAI_DIS_XX.mp4
# Finished extracting 102 frames from 1006_TAI_FEA_XX.mp4
# Finished extracting 118 frames from 1006_TAI_HAP_XX.mp4
# Finished extracting 96 frames from 1006_TAI_NEU_XX.mp4
# Finished extracting 110 frames from 1006_TAI_SAD_XX.mp4
# Finished extracting 126 frames from 1006_TIE_ANG_XX.mp4
# Finished extracting 102 frames from 1006_TIE_DIS_XX.mp4
# Finished extracting 96 frames from 1006_TIE_FEA_XX.mp4
# Finished extracting 75 frames from 1006_TIE_HAP_XX.mp4
# Finished extracting 75 frames from 1006_TIE_NEU_XX.mp4
# Finished extracting 111 frames from 1006_TIE_SAD_XX.mp4
# Finished extracting 76 frames from 1006_TSI_ANG_XX.mp4
# Finished extracting 99 frames from 1006_TSI_DIS_XX.mp4
# Finished extracting 101 frames from 1006_TSI_FEA_XX.mp4
# Finished extracting 75 frames from 1006_TSI_HAP_XX.mp4
# Finished extracting 75 frames from 1006_TSI_NEU_XX.mp4
# Finished extracting 93 frames from 1006_TSI_SAD_XX.mp4
# Finished extracting 83 frames from 1006_WSI_ANG_XX.mp4
# Finished extracting 87 frames from 1006_WSI_DIS_XX.mp4
# Finished extracting 90 frames from 1006_WSI_FEA_XX.mp4
# Finished extracting 83 frames from 1006_WSI_HAP_XX.mp4
# Finished extracting 104 frames from 1006_WSI_NEU_XX.mp4
# Finished extracting 118 frames from 1006_WSI_SAD_XX.mp4
# Finished extracting 76 frames from 1007_DFA_ANG_XX.mp4
# Finished extracting 87 frames from 1007_DFA_DIS_XX.mp4
# Finished extracting 83 frames from 1007_DFA_FEA_XX.mp4
# Finished extracting 67 frames from 1007_DFA_HAP_XX.mp4
# Finished extracting 80 frames from 1007_DFA_NEU_XX.mp4
# Finished extracting 66 frames from 1007_DFA_SAD_XX.mp4
# Finished extracting 74 frames from 1007_IEO_ANG_HI.mp4
# Finished extracting 56 frames from 1007_IEO_ANG_LO.mp4
# Finished extracting 82 frames from 1007_IEO_ANG_MD.mp4
# Finished extracting 69 frames from 1007_IEO_DIS_HI.mp4
# Finished extracting 59 frames from 1007_IEO_DIS_LO.mp4
# Finished extracting 62 frames from 1007_IEO_DIS_MD.mp4
# Finished extracting 60 frames from 1007_IEO_FEA_HI.mp4
# Finished extracting 70 frames from 1007_IEO_FEA_LO.mp4
# Finished extracting 90 frames from 1007_IEO_FEA_MD.mp4
# Finished extracting 56 frames from 1007_IEO_HAP_HI.mp4
# Finished extracting 52 frames from 1007_IEO_HAP_LO.mp4
# Finished extracting 64 frames from 1007_IEO_HAP_MD.mp4
# Finished extracting 63 frames from 1007_IEO_NEU_XX.mp4
# Finished extracting 77 frames from 1007_IEO_SAD_HI.mp4
# Finished extracting 65 frames from 1007_IEO_SAD_LO.mp4
# Finished extracting 74 frames from 1007_IEO_SAD_MD.mp4
# Finished extracting 107 frames from 1007_IOM_ANG_XX.mp4
# Finished extracting 112 frames from 1007_IOM_DIS_XX.mp4
# Finished extracting 102 frames from 1007_IOM_FEA_XX.mp4
# Finished extracting 115 frames from 1007_IOM_HAP_XX.mp4
# Finished extracting 98 frames from 1007_IOM_NEU_XX.mp4
# Finished extracting 82 frames from 1007_IOM_SAD_XX.mp4
# Finished extracting 104 frames from 1007_ITH_ANG_XX.mp4
# Finished extracting 129 frames from 1007_ITH_DIS_XX.mp4
# Finished extracting 117 frames from 1007_ITH_FEA_XX.mp4
# Finished extracting 98 frames from 1007_ITH_HAP_XX.mp4
# Finished extracting 144 frames from 1007_ITH_NEU_XX.mp4
# Finished extracting 109 frames from 1007_ITH_SAD_XX.mp4
# Finished extracting 106 frames from 1007_ITS_ANG_XX.mp4
# Finished extracting 136 frames from 1007_ITS_DIS_XX.mp4
# Finished extracting 115 frames from 1007_ITS_FEA_XX.mp4
# Finished extracting 101 frames from 1007_ITS_HAP_XX.mp4
# Finished extracting 104 frames from 1007_ITS_NEU_XX.mp4
# Finished extracting 110 frames from 1007_ITS_SAD_XX.mp4
# Finished extracting 104 frames from 1007_IWL_ANG_XX.mp4
# Finished extracting 118 frames from 1007_IWL_DIS_XX.mp4
# Finished extracting 103 frames from 1007_IWL_FEA_XX.mp4
# Finished extracting 97 frames from 1007_IWL_HAP_XX.mp4
# Finished extracting 93 frames from 1007_IWL_NEU_XX.mp4
# Finished extracting 101 frames from 1007_IWL_SAD_XX.mp4
# Finished extracting 86 frames from 1007_IWW_ANG_XX.mp4
# Finished extracting 89 frames from 1007_IWW_DIS_XX.mp4
# Finished extracting 101 frames from 1007_IWW_FEA_XX.mp4
# Finished extracting 96 frames from 1007_IWW_HAP_XX.mp4
# Finished extracting 99 frames from 1007_IWW_NEU_XX.mp4
# Finished extracting 113 frames from 1007_IWW_SAD_XX.mp4
# Finished extracting 132 frames from 1007_MTI_ANG_XX.mp4
# Finished extracting 123 frames from 1007_MTI_DIS_XX.mp4
# Finished extracting 97 frames from 1007_MTI_FEA_XX.mp4
# Finished extracting 102 frames from 1007_MTI_HAP_XX.mp4
# Finished extracting 103 frames from 1007_MTI_NEU_XX.mp4
# Finished extracting 103 frames from 1007_MTI_SAD_XX.mp4
# Finished extracting 98 frames from 1007_TAI_ANG_XX.mp4
# Finished extracting 92 frames from 1007_TAI_DIS_XX.mp4
# Finished extracting 123 frames from 1007_TAI_FEA_XX.mp4
# Finished extracting 103 frames from 1007_TAI_HAP_XX.mp4
# Finished extracting 109 frames from 1007_TAI_NEU_XX.mp4
# Finished extracting 89 frames from 1007_TAI_SAD_XX.mp4
# Finished extracting 139 frames from 1007_TIE_ANG_XX.mp4
# Finished extracting 136 frames from 1007_TIE_DIS_XX.mp4
# Finished extracting 100 frames from 1007_TIE_FEA_XX.mp4
# Finished extracting 80 frames from 1007_TIE_HAP_XX.mp4
# Finished extracting 100 frames from 1007_TIE_NEU_XX.mp4
# Finished extracting 114 frames from 1007_TIE_SAD_XX.mp4
# Finished extracting 69 frames from 1007_TSI_ANG_XX.mp4
# Finished extracting 89 frames from 1007_TSI_DIS_XX.mp4
# Finished extracting 85 frames from 1007_TSI_FEA_XX.mp4
# Finished extracting 64 frames from 1007_TSI_HAP_XX.mp4
# Finished extracting 90 frames from 1007_TSI_NEU_XX.mp4
# Finished extracting 95 frames from 1007_TSI_SAD_XX.mp4
# Finished extracting 97 frames from 1007_WSI_ANG_XX.mp4
# Finished extracting 120 frames from 1007_WSI_DIS_XX.mp4
# Finished extracting 96 frames from 1007_WSI_FEA_XX.mp4
# Finished extracting 92 frames from 1007_WSI_HAP_XX.mp4
# Finished extracting 132 frames from 1007_WSI_NEU_XX.mp4
# Finished extracting 104 frames from 1007_WSI_SAD_XX.mp4
# Finished extracting 94 frames from 1008_DFA_ANG_XX.mp4
# Finished extracting 110 frames from 1008_DFA_DIS_XX.mp4
# Finished extracting 78 frames from 1008_DFA_FEA_XX.mp4
# Finished extracting 97 frames from 1008_DFA_HAP_XX.mp4
# Finished extracting 73 frames from 1008_DFA_NEU_XX.mp4
# Finished extracting 113 frames from 1008_DFA_SAD_XX.mp4
# Finished extracting 87 frames from 1008_IEO_ANG_HI.mp4
# Finished extracting 70 frames from 1008_IEO_ANG_LO.mp4
# Finished extracting 78 frames from 1008_IEO_ANG_MD.mp4
# Finished extracting 103 frames from 1008_IEO_DIS_HI.mp4
# Finished extracting 80 frames from 1008_IEO_DIS_LO.mp4
# Finished extracting 95 frames from 1008_IEO_DIS_MD.mp4
# Finished extracting 92 frames from 1008_IEO_FEA_HI.mp4
# Finished extracting 75 frames from 1008_IEO_FEA_LO.mp4
# Finished extracting 61 frames from 1008_IEO_FEA_MD.mp4
# Finished extracting 79 frames from 1008_IEO_HAP_HI.mp4
# Finished extracting 67 frames from 1008_IEO_HAP_LO.mp4
# Finished extracting 73 frames from 1008_IEO_HAP_MD.mp4
# Finished extracting 43 frames from 1008_IEO_NEU_XX.mp4
# Finished extracting 99 frames from 1008_IEO_SAD_HI.mp4
# Finished extracting 89 frames from 1008_IEO_SAD_LO.mp4
# Finished extracting 75 frames from 1008_IEO_SAD_MD.mp4
# Finished extracting 111 frames from 1008_IOM_ANG_XX.mp4
# Finished extracting 110 frames from 1008_IOM_DIS_XX.mp4
# Finished extracting 115 frames from 1008_IOM_FEA_XX.mp4
# Finished extracting 80 frames from 1008_IOM_HAP_XX.mp4
# Finished extracting 74 frames from 1008_IOM_NEU_XX.mp4
# Finished extracting 112 frames from 1008_IOM_SAD_XX.mp4
# Finished extracting 128 frames from 1008_ITH_ANG_XX.mp4
# Finished extracting 115 frames from 1008_ITH_DIS_XX.mp4
# Finished extracting 125 frames from 1008_ITH_FEA_XX.mp4
# Finished extracting 101 frames from 1008_ITH_HAP_XX.mp4
# Finished extracting 94 frames from 1008_ITH_NEU_XX.mp4
# Finished extracting 132 frames from 1008_ITH_SAD_XX.mp4
# Finished extracting 96 frames from 1008_ITS_ANG_XX.mp4
# Finished extracting 95 frames from 1008_ITS_DIS_XX.mp4
# Finished extracting 96 frames from 1008_ITS_FEA_XX.mp4
# Finished extracting 81 frames from 1008_ITS_HAP_XX.mp4
# Finished extracting 96 frames from 1008_ITS_NEU_XX.mp4
# Finished extracting 103 frames from 1008_ITS_SAD_XX.mp4
# Finished extracting 117 frames from 1008_IWL_ANG_XX.mp4
# Finished extracting 107 frames from 1008_IWL_DIS_XX.mp4
# Finished extracting 100 frames from 1008_IWL_FEA_XX.mp4
# Finished extracting 80 frames from 1008_IWL_HAP_XX.mp4
# Finished extracting 81 frames from 1008_IWL_NEU_XX.mp4
# Finished extracting 119 frames from 1008_IWL_SAD_XX.mp4
# Finished extracting 105 frames from 1008_IWW_ANG_XX.mp4
# Finished extracting 101 frames from 1008_IWW_DIS_XX.mp4
# Finished extracting 82 frames from 1008_IWW_FEA_XX.mp4
# Finished extracting 94 frames from 1008_IWW_HAP_XX.mp4
# Finished extracting 80 frames from 1008_IWW_NEU_XX.mp4
# Finished extracting 93 frames from 1008_IWW_SAD_XX.mp4
# Finished extracting 107 frames from 1008_MTI_ANG_XX.mp4
# Finished extracting 116 frames from 1008_MTI_DIS_XX.mp4
# Finished extracting 108 frames from 1008_MTI_FEA_XX.mp4
# Finished extracting 98 frames from 1008_MTI_HAP_XX.mp4
# Finished extracting 88 frames from 1008_MTI_NEU_XX.mp4
# Finished extracting 109 frames from 1008_MTI_SAD_XX.mp4
# Finished extracting 115 frames from 1008_TAI_ANG_XX.mp4
# Finished extracting 124 frames from 1008_TAI_DIS_XX.mp4
# Finished extracting 105 frames from 1008_TAI_FEA_XX.mp4
# Finished extracting 97 frames from 1008_TAI_HAP_XX.mp4
# Finished extracting 110 frames from 1008_TAI_NEU_XX.mp4
# Finished extracting 112 frames from 1008_TAI_SAD_XX.mp4
# Finished extracting 150 frames from 1008_TIE_ANG_XX.mp4
# Finished extracting 146 frames from 1008_TIE_DIS_XX.mp4
# Finished extracting 136 frames from 1008_TIE_FEA_XX.mp4
# Finished extracting 103 frames from 1008_TIE_HAP_XX.mp4
# Finished extracting 92 frames from 1008_TIE_NEU_XX.mp4
# Finished extracting 142 frames from 1008_TIE_SAD_XX.mp4
# Finished extracting 90 frames from 1008_TSI_ANG_XX.mp4
# Finished extracting 92 frames from 1008_TSI_DIS_XX.mp4
# Finished extracting 71 frames from 1008_TSI_FEA_XX.mp4
# Finished extracting 96 frames from 1008_TSI_HAP_XX.mp4
# Finished extracting 111 frames from 1008_TSI_NEU_XX.mp4
# Finished extracting 91 frames from 1008_TSI_SAD_XX.mp4
# Finished extracting 62 frames from 1009_DFA_ANG_XX.mp4
# Finished extracting 78 frames from 1009_DFA_DIS_XX.mp4
# Finished extracting 77 frames from 1009_DFA_FEA_XX.mp4
# Finished extracting 73 frames from 1009_DFA_HAP_XX.mp4
# Finished extracting 73 frames from 1009_DFA_NEU_XX.mp4
# Finished extracting 94 frames from 1009_DFA_SAD_XX.mp4
# Finished extracting 84 frames from 1009_IEO_ANG_HI.mp4
# Finished extracting 74 frames from 1009_IEO_ANG_LO.mp4
# Finished extracting 71 frames from 1009_IEO_ANG_MD.mp4
# Finished extracting 83 frames from 1009_IEO_DIS_HI.mp4
# Finished extracting 70 frames from 1009_IEO_DIS_LO.mp4
# Finished extracting 58 frames from 1009_IEO_DIS_MD.mp4
# Finished extracting 69 frames from 1009_IEO_FEA_HI.mp4
# Finished extracting 59 frames from 1009_IEO_FEA_LO.mp4
# Finished extracting 56 frames from 1009_IEO_FEA_MD.mp4
# Finished extracting 83 frames from 1009_IEO_HAP_HI.mp4
# Finished extracting 83 frames from 1009_IEO_HAP_LO.mp4
# Finished extracting 79 frames from 1009_IEO_HAP_MD.mp4
# Finished extracting 77 frames from 1009_IEO_NEU_XX.mp4
# Finished extracting 113 frames from 1009_IEO_SAD_HI.mp4
# Finished extracting 78 frames from 1009_IEO_SAD_LO.mp4
# Finished extracting 77 frames from 1009_IEO_SAD_MD.mp4
# Finished extracting 86 frames from 1009_IOM_ANG_XX.mp4
# Finished extracting 89 frames from 1009_IOM_DIS_XX.mp4
# Finished extracting 76 frames from 1009_IOM_FEA_XX.mp4
# Finished extracting 72 frames from 1009_IOM_HAP_XX.mp4
# Finished extracting 66 frames from 1009_IOM_NEU_XX.mp4
# Finished extracting 91 frames from 1009_IOM_SAD_XX.mp4
# Finished extracting 86 frames from 1009_ITH_ANG_XX.mp4
# Finished extracting 90 frames from 1009_ITH_DIS_XX.mp4
# Finished extracting 87 frames from 1009_ITH_FEA_XX.mp4
# Finished extracting 73 frames from 1009_ITH_HAP_XX.mp4
# Finished extracting 95 frames from 1009_ITH_NEU_XX.mp4
# Finished extracting 105 frames from 1009_ITH_SAD_XX.mp4
# Finished extracting 111 frames from 1009_ITS_ANG_XX.mp4
# Finished extracting 91 frames from 1009_ITS_DIS_XX.mp4
# Finished extracting 77 frames from 1009_ITS_FEA_XX.mp4
# Finished extracting 78 frames from 1009_ITS_HAP_XX.mp4
# Finished extracting 85 frames from 1009_ITS_NEU_XX.mp4
# Finished extracting 94 frames from 1009_ITS_SAD_XX.mp4
# Finished extracting 97 frames from 1009_IWL_ANG_XX.mp4
# Finished extracting 97 frames from 1009_IWL_DIS_XX.mp4
# Finished extracting 74 frames from 1009_IWL_FEA_XX.mp4
# Finished extracting 98 frames from 1009_IWL_HAP_XX.mp4
# Finished extracting 84 frames from 1009_IWL_NEU_XX.mp4
# Finished extracting 93 frames from 1009_IWL_SAD_XX.mp4
# Finished extracting 96 frames from 1009_IWW_ANG_XX.mp4
# Finished extracting 108 frames from 1009_IWW_DIS_XX.mp4
# Finished extracting 80 frames from 1009_IWW_FEA_XX.mp4
# Finished extracting 64 frames from 1009_IWW_HAP_XX.mp4
# Finished extracting 74 frames from 1009_IWW_NEU_XX.mp4
# Finished extracting 84 frames from 1009_IWW_SAD_XX.mp4
# Finished extracting 74 frames from 1009_TAI_ANG_XX.mp4
# Finished extracting 100 frames from 1009_TAI_DIS_XX.mp4
# Finished extracting 87 frames from 1009_TAI_FEA_XX.mp4
# Finished extracting 82 frames from 1009_TAI_HAP_XX.mp4
# Finished extracting 86 frames from 1009_TAI_NEU_XX.mp4
# Finished extracting 99 frames from 1009_TAI_SAD_XX.mp4
# Finished extracting 89 frames from 1009_TIE_ANG_XX.mp4
# Finished extracting 102 frames from 1009_TIE_DIS_XX.mp4
# Finished extracting 81 frames from 1009_TIE_FEA_XX.mp4
# Finished extracting 81 frames from 1009_TIE_HAP_XX.mp4
# Finished extracting 81 frames from 1009_TIE_NEU_XX.mp4
# Finished extracting 82 frames from 1009_TIE_SAD_XX.mp4
# Finished extracting 71 frames from 1009_TSI_ANG_XX.mp4
# Finished extracting 75 frames from 1009_TSI_DIS_XX.mp4
# Finished extracting 70 frames from 1009_TSI_FEA_XX.mp4
# Finished extracting 78 frames from 1009_TSI_HAP_XX.mp4
# Finished extracting 74 frames from 1009_TSI_NEU_XX.mp4
# Finished extracting 76 frames from 1009_TSI_SAD_XX.mp4
# Finished extracting 100 frames from 1009_WSI_ANG_XX.mp4
# Finished extracting 87 frames from 1009_WSI_DIS_XX.mp4
# Finished extracting 84 frames from 1009_WSI_FEA_XX.mp4
# Finished extracting 81 frames from 1009_WSI_HAP_XX.mp4
# Finished extracting 82 frames from 1009_WSI_NEU_XX.mp4
# Finished extracting 87 frames from 1009_WSI_SAD_XX.mp4
# Finished extracting 67 frames from 1010_DFA_ANG_XX.mp4
# Finished extracting 80 frames from 1010_DFA_DIS_XX.mp4
# Finished extracting 69 frames from 1010_DFA_FEA_XX.mp4
# Finished extracting 58 frames from 1010_DFA_HAP_XX.mp4
# Finished extracting 77 frames from 1010_DFA_NEU_XX.mp4
# Finished extracting 66 frames from 1010_DFA_SAD_XX.mp4
# Finished extracting 66 frames from 1010_IEO_ANG_HI.mp4
# Finished extracting 70 frames from 1010_IEO_ANG_LO.mp4
# Finished extracting 75 frames from 1010_IEO_ANG_MD.mp4
# Finished extracting 100 frames from 1010_IEO_DIS_HI.mp4
# Finished extracting 80 frames from 1010_IEO_DIS_LO.mp4
# Finished extracting 92 frames from 1010_IEO_DIS_MD.mp4
# Finished extracting 93 frames from 1010_IEO_FEA_HI.mp4
# Finished extracting 68 frames from 1010_IEO_FEA_LO.mp4
# Finished extracting 85 frames from 1010_IEO_FEA_MD.mp4
# Finished extracting 63 frames from 1010_IEO_HAP_HI.mp4
# Finished extracting 74 frames from 1010_IEO_HAP_LO.mp4
# Finished extracting 74 frames from 1010_IEO_HAP_MD.mp4
# Finished extracting 69 frames from 1010_IEO_NEU_XX.mp4
# Finished extracting 104 frames from 1010_IEO_SAD_HI.mp4
# Finished extracting 61 frames from 1010_IEO_SAD_LO.mp4
# Finished extracting 81 frames from 1010_IEO_SAD_MD.mp4
# Finished extracting 79 frames from 1010_IOM_ANG_XX.mp4
# Finished extracting 83 frames from 1010_IOM_DIS_XX.mp4
# Finished extracting 75 frames from 1010_IOM_FEA_XX.mp4
# Finished extracting 59 frames from 1010_IOM_HAP_XX.mp4
# Finished extracting 87 frames from 1010_IOM_NEU_XX.mp4
# Finished extracting 73 frames from 1010_IOM_SAD_XX.mp4
# Finished extracting 100 frames from 1010_ITH_ANG_XX.mp4
# Finished extracting 102 frames from 1010_ITH_DIS_XX.mp4
# Finished extracting 71 frames from 1010_ITH_FEA_XX.mp4
# Finished extracting 86 frames from 1010_ITH_HAP_XX.mp4
# Finished extracting 81 frames from 1010_ITH_NEU_XX.mp4
# Finished extracting 87 frames from 1010_ITH_SAD_XX.mp4
# Finished extracting 83 frames from 1010_ITS_ANG_XX.mp4
# Finished extracting 94 frames from 1010_ITS_DIS_XX.mp4
# Finished extracting 88 frames from 1010_ITS_FEA_XX.mp4
# Finished extracting 60 frames from 1010_ITS_HAP_XX.mp4
# Finished extracting 76 frames from 1010_ITS_NEU_XX.mp4
# Finished extracting 95 frames from 1010_ITS_SAD_XX.mp4
# Finished extracting 91 frames from 1010_IWL_ANG_XX.mp4
# Finished extracting 87 frames from 1010_IWL_DIS_XX.mp4
# Finished extracting 87 frames from 1010_IWL_FEA_XX.mp4
# Finished extracting 71 frames from 1010_IWL_HAP_XX.mp4
# Finished extracting 112 frames from 1010_IWL_NEU_XX.mp4
# Finished extracting 72 frames from 1010_IWL_SAD_XX.mp4
# Finished extracting 68 frames from 1010_IWW_ANG_XX.mp4
# Finished extracting 79 frames from 1010_IWW_DIS_XX.mp4
# Finished extracting 109 frames from 1010_IWW_FEA_XX.mp4
# Finished extracting 87 frames from 1010_IWW_HAP_XX.mp4
# Finished extracting 76 frames from 1010_IWW_NEU_XX.mp4
# Finished extracting 85 frames from 1010_IWW_SAD_XX.mp4
# Finished extracting 90 frames from 1010_MTI_ANG_XX.mp4
# Finished extracting 82 frames from 1010_MTI_DIS_XX.mp4
# Finished extracting 88 frames from 1010_MTI_FEA_XX.mp4
# Finished extracting 72 frames from 1010_MTI_HAP_XX.mp4
# Finished extracting 86 frames from 1010_MTI_NEU_XX.mp4
# Finished extracting 75 frames from 1010_MTI_SAD_XX.mp4
# Finished extracting 78 frames from 1010_TAI_ANG_XX.mp4
# Finished extracting 93 frames from 1010_TAI_DIS_XX.mp4
# Finished extracting 82 frames from 1010_TAI_FEA_XX.mp4
# Finished extracting 72 frames from 1010_TAI_HAP_XX.mp4
# Finished extracting 93 frames from 1010_TAI_NEU_XX.mp4
# Finished extracting 88 frames from 1010_TAI_SAD_XX.mp4
# Finished extracting 105 frames from 1010_TIE_ANG_XX.mp4
# Finished extracting 119 frames from 1010_TIE_DIS_XX.mp4
# Finished extracting 84 frames from 1010_TIE_FEA_XX.mp4
# Finished extracting 90 frames from 1010_TIE_HAP_XX.mp4
# Finished extracting 80 frames from 1010_TIE_NEU_XX.mp4
# Finished extracting 102 frames from 1010_TIE_SAD_XX.mp4
# Finished extracting 74 frames from 1010_TSI_ANG_XX.mp4
# Finished extracting 83 frames from 1010_TSI_DIS_XX.mp4
# Finished extracting 67 frames from 1010_TSI_FEA_XX.mp4
# Finished extracting 55 frames from 1010_TSI_HAP_XX.mp4
# Finished extracting 64 frames from 1010_TSI_NEU_XX.mp4
# Finished extracting 68 frames from 1010_TSI_SAD_XX.mp4
# Finished extracting 96 frames from 1010_WSI_ANG_XX.mp4
# Finished extracting 95 frames from 1010_WSI_DIS_XX.mp4
# Finished extracting 95 frames from 1010_WSI_FEA_XX.mp4
# Finished extracting 67 frames from 1010_WSI_HAP_XX.mp4
# Finished extracting 78 frames from 1010_WSI_NEU_XX.mp4
# Finished extracting 89 frames from 1010_WSI_SAD_XX.mp4
# Finished extracting 90 frames from 1011_DFA_ANG_XX.mp4
# Finished extracting 77 frames from 1011_DFA_DIS_XX.mp4
# Finished extracting 62 frames from 1011_DFA_FEA_XX.mp4
# Finished extracting 62 frames from 1011_DFA_HAP_XX.mp4
# Finished extracting 75 frames from 1011_DFA_NEU_XX.mp4
# Finished extracting 76 frames from 1011_DFA_SAD_XX.mp4
# Finished extracting 104 frames from 1011_IEO_ANG_HI.mp4
# Finished extracting 92 frames from 1011_IEO_ANG_LO.mp4
# Finished extracting 76 frames from 1011_IEO_ANG_MD.mp4
# Finished extracting 84 frames from 1011_IEO_DIS_HI.mp4
# Finished extracting 84 frames from 1011_IEO_DIS_LO.mp4
# Finished extracting 86 frames from 1011_IEO_DIS_MD.mp4
# Finished extracting 79 frames from 1011_IEO_FEA_HI.mp4
# Finished extracting 85 frames from 1011_IEO_FEA_LO.mp4
# Finished extracting 78 frames from 1011_IEO_FEA_MD.mp4
# Finished extracting 77 frames from 1011_IEO_HAP_HI.mp4
# Finished extracting 64 frames from 1011_IEO_HAP_LO.mp4
# Finished extracting 66 frames from 1011_IEO_HAP_MD.mp4
# Finished extracting 53 frames from 1011_IEO_NEU_XX.mp4
# Finished extracting 99 frames from 1011_IEO_SAD_HI.mp4
# Finished extracting 74 frames from 1011_IEO_SAD_LO.mp4
# Finished extracting 71 frames from 1011_IEO_SAD_MD.mp4
# Finished extracting 80 frames from 1011_IOM_ANG_XX.mp4
# Finished extracting 86 frames from 1011_IOM_DIS_XX.mp4
# Finished extracting 83 frames from 1011_IOM_FEA_XX.mp4
# Finished extracting 74 frames from 1011_IOM_HAP_XX.mp4
# Finished extracting 65 frames from 1011_IOM_NEU_XX.mp4
# Finished extracting 77 frames from 1011_IOM_SAD_XX.mp4
# Finished extracting 91 frames from 1011_ITH_ANG_XX.mp4
# Finished extracting 87 frames from 1011_ITH_DIS_XX.mp4
# Finished extracting 70 frames from 1011_ITH_FEA_XX.mp4
# Finished extracting 77 frames from 1011_ITH_HAP_XX.mp4
# Finished extracting 86 frames from 1011_ITH_NEU_XX.mp4
# Finished extracting 70 frames from 1011_ITH_SAD_XX.mp4
# Finished extracting 82 frames from 1011_ITS_ANG_XX.mp4
# Finished extracting 96 frames from 1011_ITS_DIS_XX.mp4
# Finished extracting 76 frames from 1011_ITS_FEA_XX.mp4
# Finished extracting 71 frames from 1011_ITS_HAP_XX.mp4
# Finished extracting 74 frames from 1011_ITS_NEU_XX.mp4
# Finished extracting 83 frames from 1011_ITS_SAD_XX.mp4
# Finished extracting 80 frames from 1011_IWL_ANG_XX.mp4
# Finished extracting 69 frames from 1011_IWL_DIS_XX.mp4
# Finished extracting 74 frames from 1011_IWL_FEA_XX.mp4
# Finished extracting 68 frames from 1011_IWL_HAP_XX.mp4
# Finished extracting 74 frames from 1011_IWL_NEU_XX.mp4
# Finished extracting 87 frames from 1011_IWL_SAD_XX.mp4
# Finished extracting 80 frames from 1011_IWW_ANG_XX.mp4
# Finished extracting 94 frames from 1011_IWW_DIS_XX.mp4
# Finished extracting 71 frames from 1011_IWW_FEA_XX.mp4
# Finished extracting 65 frames from 1011_IWW_HAP_XX.mp4
# Finished extracting 84 frames from 1011_IWW_NEU_XX.mp4
# Finished extracting 68 frames from 1011_IWW_SAD_XX.mp4
# Finished extracting 88 frames from 1011_MTI_ANG_XX.mp4
# Finished extracting 86 frames from 1011_MTI_DIS_XX.mp4
# Finished extracting 71 frames from 1011_MTI_FEA_XX.mp4
# Finished extracting 84 frames from 1011_MTI_HAP_XX.mp4
# Finished extracting 86 frames from 1011_MTI_NEU_XX.mp4
# Finished extracting 73 frames from 1011_MTI_SAD_XX.mp4
# Finished extracting 79 frames from 1011_TAI_ANG_XX.mp4
# Finished extracting 86 frames from 1011_TAI_DIS_XX.mp4
# Finished extracting 80 frames from 1011_TAI_FEA_XX.mp4
# ...
# Finished extracting 75 frames from 1088_ITS_NEU_XX.mp4
# Finished extracting 106 frames from 1088_ITS_SAD_XX.mp4
# Finished extracting 73 frames from 1088_IWL_ANG_XX.mp4
# Finished extracting 95 frames from 1088_IWL_DIS_XX.mp4
# Finished extracting 102 frames from 1088_IWL_FEA_XX.mp4
# Finished extracting 66 frames from 1088_IWL_HAP_XX.mp4
# Finished extracting 77 frames from 1088_IWL_NEU_XX.mp4
# Finished extracting 94 frames from 1088_IWL_SAD_XX.mp4
# Finished extracting 64 frames from 1088_IWW_ANG_XX.mp4
# Finished extracting 88 frames from 1088_IWW_DIS_XX.mp4
# Finished extracting 96 frames from 1088_IWW_FEA_XX.mp4
# Finished extracting 60 frames from 1088_IWW_HAP_XX.mp4
# Finished extracting 63 frames from 1088_IWW_NEU_XX.mp4
# Finished extracting 84 frames from 1088_IWW_SAD_XX.mp4
# Finished extracting 82 frames from 1088_MTI_ANG_XX.mp4
# Finished extracting 89 frames from 1088_MTI_DIS_XX.mp4
# Finished extracting 86 frames from 1088_MTI_FEA_XX.mp4
# Finished extracting 86 frames from 1088_MTI_HAP_XX.mp4
# Finished extracting 72 frames from 1088_MTI_NEU_XX.mp4
# Finished extracting 87 frames from 1088_MTI_SAD_XX.mp4
# Finished extracting 95 frames from 1088_TAI_ANG_XX.mp4
# Finished extracting 87 frames from 1088_TAI_DIS_XX.mp4
# Finished extracting 90 frames from 1088_TAI_FEA_XX.mp4
# Finished extracting 74 frames from 1088_TAI_HAP_XX.mp4
# Finished extracting 60 frames from 1088_TAI_NEU_XX.mp4
# Finished extracting 78 frames from 1088_TAI_SAD_XX.mp4
# Finished extracting 91 frames from 1088_TIE_ANG_XX.mp4
# Finished extracting 91 frames from 1088_TIE_DIS_XX.mp4
# Finished extracting 91 frames from 1088_TIE_FEA_XX.mp4
# Finished extracting 83 frames from 1088_TIE_HAP_XX.mp4
# Finished extracting 77 frames from 1088_TIE_NEU_XX.mp4
# Finished extracting 81 frames from 1088_TIE_SAD_XX.mp4
# Finished extracting 63 frames from 1088_TSI_ANG_XX.mp4
# Finished extracting 73 frames from 1088_TSI_DIS_XX.mp4
# Finished extracting 96 frames from 1088_TSI_FEA_XX.mp4
# Finished extracting 77 frames from 1088_TSI_HAP_XX.mp4
# Finished extracting 59 frames from 1088_TSI_NEU_XX.mp4
# Finished extracting 72 frames from 1088_TSI_SAD_XX.mp4
# Finished extracting 98 frames from 1088_WSI_ANG_XX.mp4
# Finished extracting 61 frames from 1088_WSI_DIS_XX.mp4
# Finished extracting 93 frames from 1088_WSI_FEA_XX.mp4
# Finished extracting 72 frames from 1088_WSI_HAP_XX.mp4
# Finished extracting 80 frames from 1088_WSI_NEU_XX.mp4
# Finished extracting 80 frames from 1088_WSI_SAD_XX.mp4
# Finished extracting 59 frames from 1089_DFA_ANG_XX.mp4
# Finished extracting 81 frames from 1089_DFA_DIS_XX.mp4
# Finished extracting 76 frames from 1089_DFA_FEA_XX.mp4
# Finished extracting 75 frames from 1089_DFA_HAP_XX.mp4
# Finished extracting 64 frames from 1089_DFA_NEU_XX.mp4
# Finished extracting 67 frames from 1089_DFA_SAD_XX.mp4
# Finished extracting 76 frames from 1089_IEO_ANG_HI.mp4
# Finished extracting 62 frames from 1089_IEO_ANG_LO.mp4
# Finished extracting 71 frames from 1089_IEO_ANG_MD.mp4
# Finished extracting 93 frames from 1089_IEO_DIS_HI.mp4
# Finished extracting 83 frames from 1089_IEO_DIS_LO.mp4
# Finished extracting 68 frames from 1089_IEO_DIS_MD.mp4
# Finished extracting 71 frames from 1089_IEO_FEA_HI.mp4
# Finished extracting 82 frames from 1089_IEO_FEA_LO.mp4
# Finished extracting 100 frames from 1089_IEO_FEA_MD.mp4
# Finished extracting 70 frames from 1089_IEO_HAP_HI.mp4
# Finished extracting 62 frames from 1089_IEO_HAP_LO.mp4
# Finished extracting 67 frames from 1089_IEO_HAP_MD.mp4
# Finished extracting 73 frames from 1089_IEO_NEU_XX.mp4
# Finished extracting 71 frames from 1089_IEO_SAD_HI.mp4
# Finished extracting 82 frames from 1089_IEO_SAD_LO.mp4
# Finished extracting 85 frames from 1089_IEO_SAD_MD.mp4
# Finished extracting 86 frames from 1089_IOM_ANG_XX.mp4
# Finished extracting 94 frames from 1089_IOM_DIS_XX.mp4
# Finished extracting 78 frames from 1089_IOM_FEA_XX.mp4
# Finished extracting 83 frames from 1089_IOM_HAP_XX.mp4
# Finished extracting 67 frames from 1089_IOM_NEU_XX.mp4
# Finished extracting 62 frames from 1089_IOM_SAD_XX.mp4
# Finished extracting 92 frames from 1089_ITH_ANG_XX.mp4
# Finished extracting 120 frames from 1089_ITH_DIS_XX.mp4
# Finished extracting 72 frames from 1089_ITH_FEA_XX.mp4
# Finished extracting 66 frames from 1089_ITH_HAP_XX.mp4
# Finished extracting 62 frames from 1089_ITH_NEU_XX.mp4
# Finished extracting 78 frames from 1089_ITH_SAD_XX.mp4
# Finished extracting 84 frames from 1089_ITS_ANG_XX.mp4
# Finished extracting 88 frames from 1089_ITS_DIS_XX.mp4
# Finished extracting 95 frames from 1089_ITS_FEA_XX.mp4
# Finished extracting 80 frames from 1089_ITS_HAP_XX.mp4
# Finished extracting 63 frames from 1089_ITS_NEU_XX.mp4
# Finished extracting 84 frames from 1089_ITS_SAD_XX.mp4
# Finished extracting 91 frames from 1089_IWL_ANG_XX.mp4
# Finished extracting 113 frames from 1089_IWL_DIS_XX.mp4
# Finished extracting 84 frames from 1089_IWL_FEA_XX.mp4
# Finished extracting 70 frames from 1089_IWL_HAP_XX.mp4
# Finished extracting 74 frames from 1089_IWL_NEU_XX.mp4
# Finished extracting 86 frames from 1089_IWL_SAD_XX.mp4
# Finished extracting 74 frames from 1089_IWW_ANG_XX.mp4
# Finished extracting 96 frames from 1089_IWW_DIS_XX.mp4
# Finished extracting 77 frames from 1089_IWW_FEA_XX.mp4
# Finished extracting 65 frames from 1089_IWW_HAP_XX.mp4
# Finished extracting 97 frames from 1089_IWW_NEU_XX.mp4
# Finished extracting 86 frames from 1089_IWW_SAD_XX.mp4
# Finished extracting 89 frames from 1089_MTI_ANG_XX.mp4
# Finished extracting 137 frames from 1089_MTI_DIS_XX.mp4
# Finished extracting 86 frames from 1089_MTI_FEA_XX.mp4
# Finished extracting 75 frames from 1089_MTI_HAP_XX.mp4
# Finished extracting 87 frames from 1089_MTI_NEU_XX.mp4
# Finished extracting 86 frames from 1089_MTI_SAD_XX.mp4
# Finished extracting 87 frames from 1089_TAI_ANG_XX.mp4
# Finished extracting 112 frames from 1089_TAI_DIS_XX.mp4
# Finished extracting 88 frames from 1089_TAI_FEA_XX.mp4
# Finished extracting 75 frames from 1089_TAI_HAP_XX.mp4
# Finished extracting 75 frames from 1089_TAI_NEU_XX.mp4
# Finished extracting 97 frames from 1089_TAI_SAD_XX.mp4
# Finished extracting 91 frames from 1089_TIE_ANG_XX.mp4
# Finished extracting 121 frames from 1089_TIE_DIS_XX.mp4
# Finished extracting 91 frames from 1089_TIE_FEA_XX.mp4
# Finished extracting 91 frames from 1089_TIE_HAP_XX.mp4
# Finished extracting 90 frames from 1089_TIE_NEU_XX.mp4
# Finished extracting 97 frames from 1089_TIE_SAD_XX.mp4
# Finished extracting 72 frames from 1089_TSI_ANG_XX.mp4
# Finished extracting 91 frames from 1089_TSI_DIS_XX.mp4
# Finished extracting 56 frames from 1089_TSI_FEA_XX.mp4
# Finished extracting 71 frames from 1089_TSI_HAP_XX.mp4
# Finished extracting 71 frames from 1089_TSI_NEU_XX.mp4
# Finished extracting 76 frames from 1089_TSI_SAD_XX.mp4
# Finished extracting 69 frames from 1089_WSI_ANG_XX.mp4
# Finished extracting 123 frames from 1089_WSI_DIS_XX.mp4
# Finished extracting 70 frames from 1089_WSI_FEA_XX.mp4
# Finished extracting 67 frames from 1089_WSI_HAP_XX.mp4
# Finished extracting 78 frames from 1089_WSI_NEU_XX.mp4
# Finished extracting 81 frames from 1089_WSI_SAD_XX.mp4
# Finished extracting 67 frames from 1090_DFA_ANG_XX.mp4
# Finished extracting 75 frames from 1090_DFA_DIS_XX.mp4
# Finished extracting 67 frames from 1090_DFA_FEA_XX.mp4
# Finished extracting 58 frames from 1090_DFA_HAP_XX.mp4
# Finished extracting 55 frames from 1090_DFA_NEU_XX.mp4
# Finished extracting 57 frames from 1090_DFA_SAD_XX.mp4
# Finished extracting 87 frames from 1090_IEO_ANG_HI.mp4
# Finished extracting 78 frames from 1090_IEO_ANG_LO.mp4
# Finished extracting 74 frames from 1090_IEO_ANG_MD.mp4
# Finished extracting 57 frames from 1090_IEO_DIS_HI.mp4
# Finished extracting 57 frames from 1090_IEO_DIS_LO.mp4
# Finished extracting 80 frames from 1090_IEO_DIS_MD.mp4
# Finished extracting 56 frames from 1090_IEO_FEA_HI.mp4
# Finished extracting 51 frames from 1090_IEO_FEA_LO.mp4
# Finished extracting 61 frames from 1090_IEO_FEA_MD.mp4
# Finished extracting 61 frames from 1090_IEO_HAP_HI.mp4
# Finished extracting 59 frames from 1090_IEO_HAP_LO.mp4
# Finished extracting 58 frames from 1090_IEO_HAP_MD.mp4
# Finished extracting 51 frames from 1090_IEO_NEU_XX.mp4
# Finished extracting 55 frames from 1090_IEO_SAD_HI.mp4
# Finished extracting 61 frames from 1090_IEO_SAD_LO.mp4
# Finished extracting 61 frames from 1090_IEO_SAD_MD.mp4
# Finished extracting 76 frames from 1090_IOM_ANG_XX.mp4
# Finished extracting 83 frames from 1090_IOM_DIS_XX.mp4
# Finished extracting 79 frames from 1090_IOM_FEA_XX.mp4
# Finished extracting 75 frames from 1090_IOM_HAP_XX.mp4
# Finished extracting 66 frames from 1090_IOM_NEU_XX.mp4
# Finished extracting 82 frames from 1090_IOM_SAD_XX.mp4
# Finished extracting 105 frames from 1090_ITH_ANG_XX.mp4
# Finished extracting 108 frames from 1090_ITH_DIS_XX.mp4
# Finished extracting 104 frames from 1090_ITH_FEA_XX.mp4
# Finished extracting 65 frames from 1090_ITH_HAP_XX.mp4
# Finished extracting 70 frames from 1090_ITH_NEU_XX.mp4
# Finished extracting 81 frames from 1090_ITH_SAD_XX.mp4
# Finished extracting 78 frames from 1090_ITS_ANG_XX.mp4
# Finished extracting 87 frames from 1090_ITS_DIS_XX.mp4
# Finished extracting 76 frames from 1090_ITS_FEA_XX.mp4
# Finished extracting 89 frames from 1090_ITS_HAP_XX.mp4
# Finished extracting 77 frames from 1090_ITS_NEU_XX.mp4
# Finished extracting 89 frames from 1090_ITS_SAD_XX.mp4
# Finished extracting 100 frames from 1090_IWL_ANG_XX.mp4
# Finished extracting 99 frames from 1090_IWL_DIS_XX.mp4
# Finished extracting 75 frames from 1090_IWL_FEA_XX.mp4
# Finished extracting 79 frames from 1090_IWL_HAP_XX.mp4
# Finished extracting 84 frames from 1090_IWL_NEU_XX.mp4
# Finished extracting 78 frames from 1090_IWL_SAD_XX.mp4
# Finished extracting 87 frames from 1090_IWW_ANG_XX.mp4
# Finished extracting 69 frames from 1090_IWW_DIS_XX.mp4
# Finished extracting 76 frames from 1090_IWW_FEA_XX.mp4
# Finished extracting 67 frames from 1090_IWW_HAP_XX.mp4
# Finished extracting 65 frames from 1090_IWW_NEU_XX.mp4
# Finished extracting 87 frames from 1090_IWW_SAD_XX.mp4
# Finished extracting 101 frames from 1090_MTI_ANG_XX.mp4
# Finished extracting 115 frames from 1090_MTI_DIS_XX.mp4
# Finished extracting 87 frames from 1090_MTI_FEA_XX.mp4
# Finished extracting 85 frames from 1090_MTI_HAP_XX.mp4
# Finished extracting 71 frames from 1090_MTI_NEU_XX.mp4
# Finished extracting 83 frames from 1090_MTI_SAD_XX.mp4
# Finished extracting 105 frames from 1090_TAI_ANG_XX.mp4
# Finished extracting 92 frames from 1090_TAI_DIS_XX.mp4
# Finished extracting 74 frames from 1090_TAI_FEA_XX.mp4
# Finished extracting 73 frames from 1090_TAI_HAP_XX.mp4
# Finished extracting 73 frames from 1090_TAI_NEU_XX.mp4
# Finished extracting 76 frames from 1090_TAI_SAD_XX.mp4
# Finished extracting 89 frames from 1090_TIE_ANG_XX.mp4
# Finished extracting 121 frames from 1090_TIE_DIS_XX.mp4
# Finished extracting 89 frames from 1090_TIE_FEA_XX.mp4
# Finished extracting 75 frames from 1090_TIE_HAP_XX.mp4
# Finished extracting 74 frames from 1090_TIE_NEU_XX.mp4
# Finished extracting 116 frames from 1090_TIE_SAD_XX.mp4
# Finished extracting 87 frames from 1090_TSI_ANG_XX.mp4
# Finished extracting 99 frames from 1090_TSI_DIS_XX.mp4
# Finished extracting 77 frames from 1090_TSI_FEA_XX.mp4
# Finished extracting 78 frames from 1090_TSI_HAP_XX.mp4
# Finished extracting 66 frames from 1090_TSI_NEU_XX.mp4
# Finished extracting 78 frames from 1090_TSI_SAD_XX.mp4
# Finished extracting 88 frames from 1090_WSI_ANG_XX.mp4
# Finished extracting 90 frames from 1090_WSI_DIS_XX.mp4
# Finished extracting 67 frames from 1090_WSI_FEA_XX.mp4
# Finished extracting 70 frames from 1090_WSI_HAP_XX.mp4
# Finished extracting 72 frames from 1090_WSI_NEU_XX.mp4
# Finished extracting 96 frames from 1090_WSI_SAD_XX.mp4
# Finished extracting 61 frames from 1091_DFA_ANG_XX.mp4
# Finished extracting 81 frames from 1091_DFA_DIS_XX.mp4
# Finished extracting 61 frames from 1091_DFA_FEA_XX.mp4
# Finished extracting 61 frames from 1091_DFA_HAP_XX.mp4
# Finished extracting 61 frames from 1091_DFA_NEU_XX.mp4
# Finished extracting 61 frames from 1091_DFA_SAD_XX.mp4
# Finished extracting 66 frames from 1091_IEO_ANG_HI.mp4
# Finished extracting 66 frames from 1091_IEO_ANG_LO.mp4
# Finished extracting 71 frames from 1091_IEO_ANG_MD.mp4
# Finished extracting 86 frames from 1091_IEO_DIS_HI.mp4
# Finished extracting 81 frames from 1091_IEO_DIS_LO.mp4
# Finished extracting 76 frames from 1091_IEO_DIS_MD.mp4
# Finished extracting 71 frames from 1091_IEO_FEA_HI.mp4
# Finished extracting 76 frames from 1091_IEO_FEA_LO.mp4
# Finished extracting 81 frames from 1091_IEO_FEA_MD.mp4
# Finished extracting 61 frames from 1091_IEO_HAP_HI.mp4
# Finished extracting 51 frames from 1091_IEO_HAP_LO.mp4
# Finished extracting 81 frames from 1091_IEO_HAP_MD.mp4
# Finished extracting 56 frames from 1091_IEO_NEU_XX.mp4
# Finished extracting 61 frames from 1091_IEO_SAD_HI.mp4
# Finished extracting 66 frames from 1091_IEO_SAD_LO.mp4
# Finished extracting 71 frames from 1091_IEO_SAD_MD.mp4
# Finished extracting 61 frames from 1091_IOM_ANG_XX.mp4
# Finished extracting 81 frames from 1091_IOM_DIS_XX.mp4
# Finished extracting 91 frames from 1091_IOM_FEA_XX.mp4
# Finished extracting 76 frames from 1091_IOM_HAP_XX.mp4
# Finished extracting 61 frames from 1091_IOM_NEU_XX.mp4
# Finished extracting 71 frames from 1091_IOM_SAD_XX.mp4
# Finished extracting 81 frames from 1091_ITH_ANG_XX.mp4
# Finished extracting 91 frames from 1091_ITH_DIS_XX.mp4
# Finished extracting 81 frames from 1091_ITH_FEA_XX.mp4
# Finished extracting 81 frames from 1091_ITH_HAP_XX.mp4
# Finished extracting 71 frames from 1091_ITH_NEU_XX.mp4
# Finished extracting 91 frames from 1091_ITH_SAD_XX.mp4
# Finished extracting 86 frames from 1091_ITS_ANG_XX.mp4
# Finished extracting 81 frames from 1091_ITS_DIS_XX.mp4
# Finished extracting 81 frames from 1091_ITS_FEA_XX.mp4
# Finished extracting 86 frames from 1091_ITS_HAP_XX.mp4
# Finished extracting 76 frames from 1091_ITS_NEU_XX.mp4
# Finished extracting 79 frames from 1091_ITS_SAD_XX.mp4
# Finished extracting 76 frames from 1091_IWL_ANG_XX.mp4
# Finished extracting 91 frames from 1091_IWL_DIS_XX.mp4
# Finished extracting 81 frames from 1091_IWL_FEA_XX.mp4
# Finished extracting 81 frames from 1091_IWL_HAP_XX.mp4
# Finished extracting 71 frames from 1091_IWL_NEU_XX.mp4
# Finished extracting 76 frames from 1091_IWL_SAD_XX.mp4
# Finished extracting 76 frames from 1091_IWW_ANG_XX.mp4
# Finished extracting 91 frames from 1091_IWW_DIS_XX.mp4
# Finished extracting 87 frames from 1091_IWW_FEA_XX.mp4
# Finished extracting 91 frames from 1091_IWW_HAP_XX.mp4
# Finished extracting 86 frames from 1091_IWW_NEU_XX.mp4
# Finished extracting 76 frames from 1091_IWW_SAD_XX.mp4
# Finished extracting 71 frames from 1091_MTI_ANG_XX.mp4
# Finished extracting 91 frames from 1091_MTI_DIS_XX.mp4
# Finished extracting 81 frames from 1091_MTI_FEA_XX.mp4
# Finished extracting 86 frames from 1091_MTI_HAP_XX.mp4
# Finished extracting 66 frames from 1091_MTI_NEU_XX.mp4
# Finished extracting 76 frames from 1091_MTI_SAD_XX.mp4
# Finished extracting 71 frames from 1091_TAI_ANG_XX.mp4
# Finished extracting 81 frames from 1091_TAI_DIS_XX.mp4
# Finished extracting 76 frames from 1091_TAI_FEA_XX.mp4
# Finished extracting 71 frames from 1091_TAI_HAP_XX.mp4
# Finished extracting 69 frames from 1091_TAI_NEU_XX.mp4
# Finished extracting 66 frames from 1091_TAI_SAD_XX.mp4
# Finished extracting 81 frames from 1091_TIE_ANG_XX.mp4
# Finished extracting 114 frames from 1091_TIE_DIS_XX.mp4
# Finished extracting 76 frames from 1091_TIE_FEA_XX.mp4
# Finished extracting 86 frames from 1091_TIE_HAP_XX.mp4
# Finished extracting 68 frames from 1091_TIE_NEU_XX.mp4
# Finished extracting 101 frames from 1091_TIE_SAD_XX.mp4
# Finished extracting 66 frames from 1091_TSI_ANG_XX.mp4
# Finished extracting 81 frames from 1091_TSI_DIS_XX.mp4
# Finished extracting 66 frames from 1091_TSI_FEA_XX.mp4
# Finished extracting 76 frames from 1091_TSI_HAP_XX.mp4
# Finished extracting 66 frames from 1091_TSI_NEU_XX.mp4
# Finished extracting 81 frames from 1091_TSI_SAD_XX.mp4
# Finished extracting 81 frames from 1091_WSI_ANG_XX.mp4
# Finished extracting 76 frames from 1091_WSI_DIS_XX.mp4
# Finished extracting 76 frames from 1091_WSI_FEA_XX.mp4
# Finished extracting 66 frames from 1091_WSI_HAP_XX.mp4
# Finished extracting 71 frames from 1091_WSI_NEU_XX.mp4
# Finished extracting 76 frames from 1091_WSI_SAD_XX.mp4

# %%
import os
import subprocess
import cv2
import torch
import torch.nn as nn
from torchvision import models
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, classification_report
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
import pickle
import json
from torchsummary import summary

# Check device for PyTorch library
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device (PyTorch):", device)

def load_and_prepare_data(video_dir, frame_dir):
    def count_frames(directory):
        frame_count = 0
        for root, dirs, files in os.walk(directory):
            frame_count += len(files)
        return frame_count

    def extract_frames(video_dir, frame_dir):
        os.makedirs(frame_dir, exist_ok=True)
        for video_file in os.listdir(video_dir):
            if video_file.endswith(".mp4"):
                video_path = os.path.join(video_dir, video_file)
                video_name = os.path.splitext(video_file)[0]
                output_folder = os.path.join(frame_dir, video_name)
                os.makedirs(output_folder, exist_ok=True)

                cap = cv2.VideoCapture(video_path)
                frame_count = 0
                while cap.isOpened():
                    ret, frame = cap.read()
                    if not ret:
                        break
                    frame_path = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
                    cv2.imwrite(frame_path, frame)
                    frame_count += 1

                cap.release()
                print(f"Extracted {frame_count} frames from {video_file}")

    total_frames = count_frames(frame_dir)
    print(f"Total number of frames: {total_frames}")
    extract_frames(video_dir, frame_dir)
def preprocess_data(frame_dir, transform):
    class CREMADataset(Dataset):
        def __init__(self, frame_dir, transform=None):
            self.frame_dir = frame_dir
            self.transform = transform
            self.data = []
            self._label_encoder = preprocessing.LabelEncoder()
            self.emotion_map = {}
            self._setup_dataset()

        def _setup_dataset(self):
            emotions = set()
            for video_folder in os.listdir(self.frame_dir):
                video_path = os.path.join(self.frame_dir, video_folder)
                if os.path.isdir(video_path):
                    emotion_code = video_folder.split('_')[2]
                    emotions.add(emotion_code)
                    for frame_file in os.listdir(video_path):
                        if frame_file.endswith(".jpg"):
                            frame_path = os.path.join(video_path, frame_file)
                            self.data.append((frame_path, emotion_code))
            
            # Create emotion mapping after collecting all unique emotions
            self._label_encoder.fit(list(emotions))
            self.emotion_map = {emotion: idx for idx, emotion in enumerate(self._label_encoder.classes_)}

        def __len__(self):
            return len(self.data)

        def __getitem__(self, idx):
            frame_path, emotion_code = self.data[idx]
            image = Image.open(frame_path).convert("RGB")
            if self.transform:
                image = self.transform(image)
            label = self.emotion_map[emotion_code]
            return image, label

        @property
        def label_encoder(self):
            return self._label_encoder
        
        @property
        def num_classes(self):
            return len(self._label_encoder.classes_)

    dataset = CREMADataset(frame_dir=frame_dir, transform=transform)
    print(f"Found {dataset.num_classes} classes: {dataset.label_encoder.classes_}")
    
    indices = list(range(len(dataset)))
    train_indices, val_test_indices = train_test_split(indices, test_size=0.4, random_state=42)
    val_indices, test_indices = train_test_split(val_test_indices, test_size=0.5, random_state=42)

    train_subset = Subset(dataset, train_indices)
    val_subset = Subset(dataset, val_indices)
    test_subset = Subset(dataset, test_indices)

    train_loader = DataLoader(train_subset, batch_size=16, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=16, shuffle=False)
    test_loader = DataLoader(test_subset, batch_size=16, shuffle=False)

    return train_loader, val_loader, test_loader, dataset.label_encoder, dataset.num_classes


def build_model(model_type, num_classes, device):
    """Build ResNet50 model with custom classifier"""
    model = models.resnet50(pretrained=True)
    
    # Freeze all layers except the final layer
    for param in model.parameters():
        param.requires_grad = False
    
    # Replace the final fully connected layer
    num_ftrs = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Linear(num_ftrs, 512),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, num_classes)
    )
    
    # Unfreeze the last few layers for fine-tuning
    for param in model.layer4.parameters():
        param.requires_grad = True
    for param in model.fc.parameters():
        param.requires_grad = True
    
    return model.to(device)
def save_model_and_artifacts(model, label_encoder, model_name="emotion_recognition_resnet"):
    """Save model in multiple formats and related artifacts"""
    os.makedirs("saved_models", exist_ok=True)
    
    # 1. Save PyTorch model (.pth)
    torch_path = f"saved_models/{model_name}.pth"
    torch.save(model.state_dict(), torch_path)
    print(f"Model saved as PyTorch .pth file: {torch_path}")
    
    # 2. Save model weights as HDF5 (.h5)
    h5_path = f"saved_models/{model_name}_weights.h5"
    with h5py.File(h5_path, 'w') as f:
        # Save model weights
        for name, param in model.named_parameters():
            f.create_dataset(name, data=param.cpu().detach().numpy())
        # Save model metadata
        f.attrs['model_type'] = str(type(model)).split("'")[1]
        f.attrs['num_classes'] = len(label_encoder.classes_)
        f.attrs['class_names'] = np.array(label_encoder.classes_, dtype='S')
    print(f"Model weights saved as HDF5 .h5 file: {h5_path}")
    
    # 3. Save label encoder as pickle (.pkl)
    label_encoder_path = f"saved_models/{model_name}_label_encoder.pkl"
    with open(label_encoder_path, 'wb') as f:
        pickle.dump(label_encoder, f)
    print(f"Label encoder saved as pickle .pkl file: {label_encoder_path}")
    
    # 4. Save complete model config as JSON
    model_config = {
        'input_size': [3, 224, 224],
        'mean': [0.485, 0.456, 0.406],
        'std': [0.229, 0.224, 0.225],
        'class_names': list(label_encoder.classes_)
    }
    config_path = f"saved_models/{model_name}_config.json"
    with open(config_path, 'w') as f:
        json.dump(model_config, f, indent=4)
    print(f"Model config saved as JSON file: {config_path}")
    
    
def train_and_evaluate_model(model, train_loader, val_loader, test_loader, device, num_epochs, checkpoint_dir, label_encoder):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5)

    # Print model summary
    print("\nModel Summary:")
    summary(model, input_size=(3, 224, 224))
    
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    best_val_loss = float('inf')
    best_model = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                val_loss += criterion(outputs, labels).item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_loss /= len(val_loader)
        val_accuracy = correct_val / total_val
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)
        
        scheduler.step(val_loss)

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
        print(f"Train Acc: {train_accuracy*100:.2f}% | Val Acc: {val_accuracy*100:.2f}%")
        print("-" * 50)

        # Save checkpoint
        checkpoint_path = os.path.join(checkpoint_dir, f"model_epoch_{epoch+1}.pth")
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': val_loss,
            'val_accuracy': val_accuracy
        }, checkpoint_path)

        # Keep track of the best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model.state_dict()
            print(f"New best model found at epoch {epoch+1} with val loss: {val_loss:.4f}")

    # Save the best model
    if best_model is not None:
        model.load_state_dict(best_model)
        best_model_path = os.path.join(checkpoint_dir, "best_model.pth")
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model saved to {best_model_path}")

    # Plot training history
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig("training_history.png")
    plt.show()

    # Evaluate on test set
    model.eval()
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    cm_df = pd.DataFrame(cm, index=label_encoder.classes_, columns=label_encoder.classes_)

    plt.figure(figsize=(12, 8))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.savefig("confusion_matrix.png")
    plt.show()

    # Classification report
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=label_encoder.classes_))

    test_accuracy = np.mean(np.array(all_preds) == np.array(all_labels))
    print(f"\nFinal Test Accuracy: {test_accuracy * 100:.2f}%")

    # Save model and artifacts
    save_model_and_artifacts(model, label_encoder)

    return model




def main():
    # video_dir = r"../datasets/CREMA-D"
    frame_dir = r"D:\graduation project folder farid version\video dataset_frames"
    checkpoint_dir = "./checkpoints_resnet"
    os.makedirs(checkpoint_dir, exist_ok=True)

    # Uncomment to extract frames from videos
    # load_and_prepare_data(video_dir, frame_dir)

    # Data transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # Load and preprocess data
    train_loader, val_loader, test_loader, label_encoder, num_classes = preprocess_data(frame_dir, transform)
    
    # Build model
    model = build_model("resnet", num_classes=num_classes, device=device)
    
    # Train and evaluate
    trained_model = train_and_evaluate_model(
        model, 
        train_loader, 
        val_loader, 
        test_loader, 
        device, 
        num_epochs=10, 
        checkpoint_dir=checkpoint_dir, 
        label_encoder=label_encoder
    )

if __name__ == "__main__":
    main()
# Out:
# Using device (PyTorch): cuda
# Found 6 classes: ['ANG' 'DIS' 'FEA' 'HAP' 'NEU' 'SAD']
# c:\ProgramData\anaconda3\envs\bassem_env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bassem_env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                  [-1, 512]       1,049,088
#             ReLU-175                  [-1, 512]               0
#          Dropout-176                  [-1, 512]               0
#           Linear-177                    [-1, 6]           3,078
# ================================================================
# Total params: 24,560,198
# Trainable params: 16,016,902
# Non-trainable params: 8,543,296
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.56
# Params size (MB): 93.69
# Estimated Total Size (MB): 380.83
# ----------------------------------------------------------------
# Epoch 1/10: 100%|██████████| 21675/21675 [3:07:49<00:00,  1.92it/s]
# Epoch 1/10
# Train Loss: 0.9783 | Val Loss: 0.5647
# Train Acc: 62.06% | Val Acc: 78.85%
# --------------------------------------------------
# New best model found at epoch 1 with val loss: 0.5647
# Epoch 2/10: 100%|██████████| 21675/21675 [34:33<00:00, 10.45it/s]
# Epoch 2/10
# Train Loss: 0.5267 | Val Loss: 0.3592
# Train Acc: 81.11% | Val Acc: 87.19%
# --------------------------------------------------
# New best model found at epoch 2 with val loss: 0.3592
# Epoch 3/10: 100%|██████████| 21675/21675 [34:33<00:00, 10.45it/s]
# Epoch 3/10
# Train Loss: 0.3422 | Val Loss: 0.2767
# Train Acc: 88.00% | Val Acc: 90.21%
# --------------------------------------------------
# New best model found at epoch 3 with val loss: 0.2767
# Epoch 4/10: 100%|██████████| 21675/21675 [34:11<00:00, 10.56it/s]
# Epoch 4/10
# Train Loss: 0.2462 | Val Loss: 0.2307
# Train Acc: 91.47% | Val Acc: 92.25%
# --------------------------------------------------
# New best model found at epoch 4 with val loss: 0.2307
# Epoch 5/10: 100%|██████████| 21675/21675 [34:30<00:00, 10.47it/s]
# Epoch 5/10
# Train Loss: 0.1882 | Val Loss: 0.1912
# Train Acc: 93.52% | Val Acc: 94.48%
# --------------------------------------------------
# New best model found at epoch 5 with val loss: 0.1912
# Epoch 6/10: 100%|██████████| 21675/21675 [34:22<00:00, 10.51it/s]
# Epoch 6/10
# Train Loss: 0.1531 | Val Loss: 0.1506
# Train Acc: 94.81% | Val Acc: 95.63%
# --------------------------------------------------
# New best model found at epoch 6 with val loss: 0.1506
# Epoch 7/10: 100%|██████████| 21675/21675 [34:33<00:00, 10.46it/s]
# Epoch 7/10
# Train Loss: 0.1279 | Val Loss: 0.1386
# Train Acc: 95.70% | Val Acc: 96.14%
# --------------------------------------------------
# New best model found at epoch 7 with val loss: 0.1386
# Epoch 8/10: 100%|██████████| 21675/21675 [34:26<00:00, 10.49it/s]
# Epoch 8/10
# Train Loss: 0.1099 | Val Loss: 0.0919
# Train Acc: 96.33% | Val Acc: 97.17%
# --------------------------------------------------
# New best model found at epoch 8 with val loss: 0.0919
# Epoch 9/10: 100%|██████████| 21675/21675 [34:31<00:00, 10.46it/s]
# Epoch 9/10
# Train Loss: 0.0955 | Val Loss: 0.0970
# Train Acc: 96.84% | Val Acc: 97.22%
# --------------------------------------------------
# Epoch 10/10: 100%|██████████| 21675/21675 [34:28<00:00, 10.48it/s]
# Epoch 10/10
# Train Loss: 0.0851 | Val Loss: 0.0981
# Train Acc: 97.20% | Val Acc: 97.06%
# --------------------------------------------------
# Best model saved to ./checkpoints_resnet\best_model.pth
# Classification Report:
#               precision    recall  f1-score   support
#
#          ANG       0.98      0.95      0.97     20028
#          DIS       0.96      0.99      0.98     22016
#          FEA       0.95      0.98      0.97     19455
#          HAP       0.96      0.99      0.98     18080
#          NEU       0.98      0.96      0.97     16057
#          SAD       0.98      0.95      0.97     19961
#
#     accuracy                           0.97    115597
#    macro avg       0.97      0.97      0.97    115597
# weighted avg       0.97      0.97      0.97    115597
#
#
# Final Test Accuracy: 97.08%
# Model saved as PyTorch .pth file: saved_models/emotion_recognition_resnet.pth
# Model weights saved as HDF5 .h5 file: saved_models/emotion_recognition_resnet_weights.h5
# Label encoder saved as pickle .pkl file: saved_models/emotion_recognition_resnet_label_encoder.pkl
# Model config saved as JSON file: saved_models/emotion_recognition_resnet_config.json
