# %%
import cv2
import os
import torch
import torch.nn as nn
from torchvision import models
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

# %%
import os

# Path to the frames directory
frames_directory = r"C:\Users\dell\Desktop\gradproject\AI04-Grad\datasets\CREMA-D\frames"

# Count the number of files in the directory
def count_frames(directory):
    frame_count = 0
    for root, dirs, files in os.walk(directory):
        frame_count += len(files)  # Add the number of files in each subdirectory
    return frame_count

# Call the function
total_frames = count_frames(frames_directory)
print(f"Total number of frames: {total_frames}")
# Out:
# Total number of frames: 564916

# %%
# Path to the CREMA-D videos and frames
video_dir = r"C:\Users\dell\Desktop\gradproject\AI04-Grad\datasets\CREMA-D\crema-d videos"
frame_dir = r"C:\Users\dell\Desktop\gradproject\AI04-Grad\datasets\CREMA-D\frames"

# Extract frames
def extract_frames(video_dir, frame_dir):
    os.makedirs(frame_dir, exist_ok=True)
    for video_file in os.listdir(video_dir):
        if video_file.endswith(".mp4"):
            video_path = os.path.join(video_dir, video_file)
            video_name = os.path.splitext(video_file)[0]
            output_folder = os.path.join(frame_dir, video_name)
            os.makedirs(output_folder, exist_ok=True)

            cap = cv2.VideoCapture(video_path)
            frame_count = 0
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                frame_path = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
                cv2.imwrite(frame_path, frame)
                frame_count += 1

            cap.release()
            print(f"Extracted {frame_count} frames from {video_file}")

# Call the function to extract frames
extract_frames(video_dir, frame_dir)
# Out:
# Extracted 77 frames from 1002_DFA_ANG_XX.mp4
# Extracted 76 frames from 1002_DFA_DIS_XX.mp4
# Extracted 82 frames from 1002_DFA_FEA_XX.mp4
# Extracted 66 frames from 1002_DFA_HAP_XX.mp4
# Extracted 75 frames from 1002_DFA_NEU_XX.mp4
# Extracted 71 frames from 1002_DFA_SAD_XX.mp4
# Extracted 82 frames from 1002_IEO_ANG_HI.mp4
# Extracted 72 frames from 1002_IEO_ANG_LO.mp4
# Extracted 83 frames from 1002_IEO_ANG_MD.mp4
# Extracted 90 frames from 1002_IEO_DIS_HI.mp4
# Extracted 86 frames from 1002_IEO_DIS_LO.mp4
# Extracted 78 frames from 1002_IEO_DIS_MD.mp4
# Extracted 96 frames from 1002_IEO_FEA_HI.mp4
# Extracted 78 frames from 1002_IEO_FEA_LO.mp4
# Extracted 58 frames from 1002_IEO_FEA_MD.mp4
# Extracted 75 frames from 1002_IEO_HAP_HI.mp4
# Extracted 85 frames from 1002_IEO_HAP_LO.mp4
# Extracted 68 frames from 1002_IEO_HAP_MD.mp4
# Extracted 77 frames from 1002_IEO_NEU_XX.mp4
# Extracted 82 frames from 1002_IEO_SAD_HI.mp4
# Extracted 68 frames from 1002_IEO_SAD_LO.mp4
# Extracted 71 frames from 1002_IEO_SAD_MD.mp4
# Extracted 85 frames from 1002_IOM_ANG_XX.mp4
# Extracted 83 frames from 1002_IOM_DIS_XX.mp4
# Extracted 78 frames from 1002_IOM_FEA_XX.mp4
# Extracted 70 frames from 1002_IOM_HAP_XX.mp4
# Extracted 70 frames from 1002_IOM_NEU_XX.mp4
# Extracted 80 frames from 1002_IOM_SAD_XX.mp4
# Extracted 88 frames from 1002_ITH_ANG_XX.mp4
# Extracted 114 frames from 1002_ITH_DIS_XX.mp4
# Extracted 105 frames from 1002_ITH_FEA_XX.mp4
# Extracted 83 frames from 1002_ITH_HAP_XX.mp4
# Extracted 75 frames from 1002_ITH_NEU_XX.mp4
# Extracted 82 frames from 1002_ITH_SAD_XX.mp4
# Extracted 81 frames from 1002_ITS_ANG_XX.mp4
# Extracted 85 frames from 1002_ITS_DIS_XX.mp4
# Extracted 74 frames from 1002_ITS_FEA_XX.mp4
# Extracted 73 frames from 1002_ITS_HAP_XX.mp4
# Extracted 70 frames from 1002_ITS_NEU_XX.mp4
# Extracted 79 frames from 1002_ITS_SAD_XX.mp4
# Extracted 78 frames from 1002_IWL_ANG_XX.mp4
# Extracted 93 frames from 1002_IWL_DIS_XX.mp4
# Extracted 97 frames from 1002_IWL_FEA_XX.mp4
# Extracted 86 frames from 1002_IWL_HAP_XX.mp4
# Extracted 79 frames from 1002_IWL_NEU_XX.mp4
# Extracted 81 frames from 1002_IWL_SAD_XX.mp4
# Extracted 72 frames from 1002_IWW_ANG_XX.mp4
# Extracted 93 frames from 1002_IWW_DIS_XX.mp4
# Extracted 78 frames from 1002_IWW_FEA_XX.mp4
# Extracted 74 frames from 1002_IWW_HAP_XX.mp4
# Extracted 75 frames from 1002_IWW_NEU_XX.mp4
# Extracted 71 frames from 1002_IWW_SAD_XX.mp4
# Extracted 82 frames from 1002_MTI_ANG_XX.mp4
# Extracted 109 frames from 1002_MTI_DIS_XX.mp4
# Extracted 88 frames from 1002_MTI_FEA_XX.mp4
# Extracted 80 frames from 1002_MTI_HAP_XX.mp4
# Extracted 86 frames from 1002_MTI_NEU_XX.mp4
# Extracted 81 frames from 1002_MTI_SAD_XX.mp4
# Extracted 75 frames from 1002_TAI_ANG_XX.mp4
# Extracted 96 frames from 1002_TAI_DIS_XX.mp4
# Extracted 83 frames from 1002_TAI_FEA_XX.mp4
# Extracted 76 frames from 1002_TAI_HAP_XX.mp4
# Extracted 79 frames from 1002_TAI_NEU_XX.mp4
# Extracted 83 frames from 1002_TAI_SAD_XX.mp4
# Extracted 76 frames from 1002_TIE_ANG_XX.mp4
# Extracted 108 frames from 1002_TIE_DIS_XX.mp4
# Extracted 94 frames from 1002_TIE_FEA_XX.mp4
# Extracted 72 frames from 1002_TIE_HAP_XX.mp4
# Extracted 94 frames from 1002_TIE_SAD_XX.mp4
# Extracted 73 frames from 1002_TSI_ANG_XX.mp4
# Extracted 83 frames from 1002_TSI_DIS_XX.mp4
# Extracted 70 frames from 1002_TSI_FEA_XX.mp4
# Extracted 61 frames from 1002_TSI_HAP_XX.mp4
# Extracted 71 frames from 1002_TSI_NEU_XX.mp4
# Extracted 72 frames from 1002_TSI_SAD_XX.mp4
# Extracted 78 frames from 1002_WSI_ANG_XX.mp4
# Extracted 103 frames from 1002_WSI_DIS_XX.mp4
# Extracted 75 frames from 1002_WSI_FEA_XX.mp4
# Extracted 83 frames from 1002_WSI_HAP_XX.mp4
# Extracted 73 frames from 1002_WSI_NEU_XX.mp4
# Extracted 82 frames from 1002_WSI_SAD_XX.mp4
# Extracted 94 frames from 1003_DFA_ANG_XX.mp4
# Extracted 97 frames from 1003_DFA_DIS_XX.mp4
# Extracted 92 frames from 1003_DFA_FEA_XX.mp4
# Extracted 98 frames from 1003_DFA_HAP_XX.mp4
# Extracted 97 frames from 1003_DFA_NEU_XX.mp4
# Extracted 96 frames from 1003_DFA_SAD_XX.mp4
# Extracted 77 frames from 1003_IEO_ANG_HI.mp4
# Extracted 67 frames from 1003_IEO_ANG_LO.mp4
# Extracted 77 frames from 1003_IEO_ANG_MD.mp4
# Extracted 95 frames from 1003_IEO_DIS_HI.mp4
# Extracted 60 frames from 1003_IEO_DIS_LO.mp4
# Extracted 62 frames from 1003_IEO_DIS_MD.mp4
# Extracted 83 frames from 1003_IEO_FEA_HI.mp4
# Extracted 77 frames from 1003_IEO_FEA_LO.mp4
# Extracted 75 frames from 1003_IEO_FEA_MD.mp4
# Extracted 66 frames from 1003_IEO_HAP_HI.mp4
# Extracted 71 frames from 1003_IEO_HAP_LO.mp4
# Extracted 69 frames from 1003_IEO_HAP_MD.mp4
# Extracted 68 frames from 1003_IEO_NEU_XX.mp4
# Extracted 74 frames from 1003_IEO_SAD_HI.mp4
# Extracted 75 frames from 1003_IEO_SAD_LO.mp4
# Extracted 80 frames from 1003_IEO_SAD_MD.mp4
# Extracted 82 frames from 1003_IOM_ANG_XX.mp4
# Extracted 99 frames from 1003_IOM_DIS_XX.mp4
# Extracted 80 frames from 1003_IOM_FEA_XX.mp4
# Extracted 87 frames from 1003_IOM_HAP_XX.mp4
# Extracted 96 frames from 1003_IOM_NEU_XX.mp4
# Extracted 85 frames from 1003_IOM_SAD_XX.mp4
# Extracted 110 frames from 1003_ITH_ANG_XX.mp4
# Extracted 121 frames from 1003_ITH_DIS_XX.mp4
# Extracted 106 frames from 1003_ITH_FEA_XX.mp4
# Extracted 94 frames from 1003_ITH_HAP_XX.mp4
# Extracted 121 frames from 1003_ITH_NEU_XX.mp4
# Extracted 109 frames from 1003_ITH_SAD_XX.mp4
# Extracted 112 frames from 1003_ITS_ANG_XX.mp4
# Extracted 111 frames from 1003_ITS_DIS_XX.mp4
# Extracted 94 frames from 1003_ITS_FEA_XX.mp4
# Extracted 112 frames from 1003_ITS_HAP_XX.mp4
# Extracted 112 frames from 1003_ITS_NEU_XX.mp4
# Extracted 105 frames from 1003_ITS_SAD_XX.mp4
# Extracted 106 frames from 1003_IWL_ANG_XX.mp4
# Extracted 132 frames from 1003_IWL_DIS_XX.mp4
# Extracted 110 frames from 1003_IWL_FEA_XX.mp4
# Extracted 117 frames from 1003_IWL_HAP_XX.mp4
# Extracted 118 frames from 1003_IWL_NEU_XX.mp4
# Extracted 112 frames from 1003_IWL_SAD_XX.mp4
# Extracted 102 frames from 1003_IWW_ANG_XX.mp4
# Extracted 93 frames from 1003_IWW_DIS_XX.mp4
# Extracted 100 frames from 1003_IWW_FEA_XX.mp4
# Extracted 105 frames from 1003_IWW_HAP_XX.mp4
# Extracted 87 frames from 1003_IWW_NEU_XX.mp4
# Extracted 81 frames from 1003_IWW_SAD_XX.mp4
# Extracted 100 frames from 1003_MTI_ANG_XX.mp4
# Extracted 127 frames from 1003_MTI_DIS_XX.mp4
# Extracted 96 frames from 1003_MTI_FEA_XX.mp4
# Extracted 99 frames from 1003_MTI_HAP_XX.mp4
# Extracted 112 frames from 1003_MTI_NEU_XX.mp4
# Extracted 113 frames from 1003_MTI_SAD_XX.mp4
# Extracted 86 frames from 1003_TAI_ANG_XX.mp4
# Extracted 96 frames from 1003_TAI_DIS_XX.mp4
# Extracted 94 frames from 1003_TAI_FEA_XX.mp4
# Extracted 94 frames from 1003_TAI_HAP_XX.mp4
# Extracted 110 frames from 1003_TAI_NEU_XX.mp4
# Extracted 100 frames from 1003_TAI_SAD_XX.mp4
# Extracted 95 frames from 1003_TIE_ANG_XX.mp4
# Extracted 128 frames from 1003_TIE_DIS_XX.mp4
# Extracted 87 frames from 1003_TIE_FEA_XX.mp4
# Extracted 98 frames from 1003_TIE_HAP_XX.mp4
# Extracted 76 frames from 1003_TIE_NEU_XX.mp4
# Extracted 131 frames from 1003_TIE_SAD_XX.mp4
# Extracted 119 frames from 1003_TSI_ANG_XX.mp4
# Extracted 108 frames from 1003_TSI_DIS_XX.mp4
# Extracted 97 frames from 1003_TSI_FEA_XX.mp4
# Extracted 101 frames from 1003_TSI_HAP_XX.mp4
# Extracted 103 frames from 1003_TSI_NEU_XX.mp4
# Extracted 89 frames from 1003_TSI_SAD_XX.mp4
# Extracted 106 frames from 1003_WSI_ANG_XX.mp4
# Extracted 104 frames from 1003_WSI_DIS_XX.mp4
# Extracted 99 frames from 1003_WSI_FEA_XX.mp4
# Extracted 95 frames from 1003_WSI_HAP_XX.mp4
# Extracted 103 frames from 1003_WSI_NEU_XX.mp4
# Extracted 101 frames from 1003_WSI_SAD_XX.mp4
# Extracted 92 frames from 1004_DFA_ANG_XX.mp4
# Extracted 87 frames from 1004_DFA_DIS_XX.mp4
# Extracted 91 frames from 1004_DFA_FEA_XX.mp4
# Extracted 82 frames from 1004_DFA_HAP_XX.mp4
# Extracted 93 frames from 1004_DFA_NEU_XX.mp4
# Extracted 85 frames from 1004_DFA_SAD_XX.mp4
# Extracted 120 frames from 1004_IEO_ANG_HI.mp4
# Extracted 80 frames from 1004_IEO_ANG_LO.mp4
# Extracted 87 frames from 1004_IEO_ANG_MD.mp4
# Extracted 145 frames from 1004_IEO_DIS_HI.mp4
# Extracted 73 frames from 1004_IEO_DIS_LO.mp4
# Extracted 109 frames from 1004_IEO_DIS_MD.mp4
# Extracted 101 frames from 1004_IEO_FEA_HI.mp4
# Extracted 103 frames from 1004_IEO_FEA_LO.mp4
# Extracted 83 frames from 1004_IEO_FEA_MD.mp4
# Extracted 88 frames from 1004_IEO_HAP_HI.mp4
# Extracted 72 frames from 1004_IEO_HAP_LO.mp4
# Extracted 91 frames from 1004_IEO_HAP_MD.mp4
# Extracted 70 frames from 1004_IEO_NEU_XX.mp4
# Extracted 150 frames from 1004_IEO_SAD_HI.mp4
# Extracted 85 frames from 1004_IEO_SAD_LO.mp4
# Extracted 121 frames from 1004_IEO_SAD_MD.mp4
# Extracted 78 frames from 1004_IOM_ANG_XX.mp4
# Extracted 81 frames from 1004_IOM_DIS_XX.mp4
# Extracted 73 frames from 1004_IOM_FEA_XX.mp4
# Extracted 100 frames from 1004_IOM_HAP_XX.mp4
# Extracted 76 frames from 1004_IOM_NEU_XX.mp4
# Extracted 86 frames from 1004_IOM_SAD_XX.mp4
# Extracted 98 frames from 1004_ITH_ANG_XX.mp4
# Extracted 109 frames from 1004_ITH_DIS_XX.mp4
# Extracted 112 frames from 1004_ITH_FEA_XX.mp4
# Extracted 90 frames from 1004_ITH_HAP_XX.mp4
# Extracted 109 frames from 1004_ITH_NEU_XX.mp4
# Extracted 106 frames from 1004_ITH_SAD_XX.mp4
# Extracted 101 frames from 1004_ITS_ANG_XX.mp4
# Extracted 92 frames from 1004_ITS_DIS_XX.mp4
# Extracted 82 frames from 1004_ITS_FEA_XX.mp4
# Extracted 86 frames from 1004_ITS_HAP_XX.mp4
# Extracted 100 frames from 1004_ITS_NEU_XX.mp4
# Extracted 90 frames from 1004_ITS_SAD_XX.mp4
# Extracted 95 frames from 1004_IWL_ANG_XX.mp4
# Extracted 100 frames from 1004_IWL_DIS_XX.mp4
# Extracted 101 frames from 1004_IWL_FEA_XX.mp4
# Extracted 90 frames from 1004_IWL_HAP_XX.mp4
# Extracted 117 frames from 1004_IWL_NEU_XX.mp4
# Extracted 99 frames from 1004_IWL_SAD_XX.mp4
# Extracted 71 frames from 1004_IWW_ANG_XX.mp4
# Extracted 88 frames from 1004_IWW_DIS_XX.mp4
# Extracted 80 frames from 1004_IWW_FEA_XX.mp4
# Extracted 98 frames from 1004_IWW_HAP_XX.mp4
# Extracted 91 frames from 1004_IWW_NEU_XX.mp4
# Extracted 85 frames from 1004_IWW_SAD_XX.mp4
# Extracted 99 frames from 1004_MTI_ANG_XX.mp4
# Extracted 109 frames from 1004_MTI_DIS_XX.mp4
# Extracted 96 frames from 1004_MTI_FEA_XX.mp4
# Extracted 96 frames from 1004_MTI_HAP_XX.mp4
# Extracted 111 frames from 1004_MTI_NEU_XX.mp4
# Extracted 99 frames from 1004_MTI_SAD_XX.mp4
# Extracted 101 frames from 1004_TAI_ANG_XX.mp4
# Extracted 117 frames from 1004_TAI_DIS_XX.mp4
# Extracted 88 frames from 1004_TAI_FEA_XX.mp4
# Extracted 78 frames from 1004_TAI_HAP_XX.mp4
# Extracted 104 frames from 1004_TAI_NEU_XX.mp4
# Extracted 103 frames from 1004_TAI_SAD_XX.mp4
# Extracted 85 frames from 1004_TIE_ANG_XX.mp4
# Extracted 130 frames from 1004_TIE_DIS_XX.mp4
# Extracted 83 frames from 1004_TIE_FEA_XX.mp4
# Extracted 89 frames from 1004_TIE_HAP_XX.mp4
# Extracted 70 frames from 1004_TIE_NEU_XX.mp4
# Extracted 90 frames from 1004_TIE_SAD_XX.mp4
# Extracted 71 frames from 1004_TSI_ANG_XX.mp4
# Extracted 91 frames from 1004_TSI_DIS_XX.mp4
# Extracted 87 frames from 1004_TSI_FEA_XX.mp4
# Extracted 70 frames from 1004_TSI_HAP_XX.mp4
# Extracted 100 frames from 1004_TSI_NEU_XX.mp4
# Extracted 73 frames from 1004_TSI_SAD_XX.mp4
# Extracted 90 frames from 1004_WSI_ANG_XX.mp4
# Extracted 105 frames from 1004_WSI_DIS_XX.mp4
# Extracted 78 frames from 1004_WSI_FEA_XX.mp4
# Extracted 77 frames from 1004_WSI_HAP_XX.mp4
# Extracted 97 frames from 1004_WSI_NEU_XX.mp4
# Extracted 112 frames from 1004_WSI_SAD_XX.mp4
# Extracted 78 frames from 1005_DFA_ANG_XX.mp4
# Extracted 82 frames from 1005_DFA_DIS_XX.mp4
# Extracted 74 frames from 1005_DFA_FEA_XX.mp4
# Extracted 77 frames from 1005_DFA_HAP_XX.mp4
# Extracted 93 frames from 1005_DFA_NEU_XX.mp4
# Extracted 91 frames from 1005_DFA_SAD_XX.mp4
# Extracted 75 frames from 1005_IEO_ANG_HI.mp4
# Extracted 68 frames from 1005_IEO_ANG_LO.mp4
# Extracted 82 frames from 1005_IEO_ANG_MD.mp4
# Extracted 84 frames from 1005_IEO_DIS_HI.mp4
# Extracted 72 frames from 1005_IEO_DIS_LO.mp4
# Extracted 75 frames from 1005_IEO_DIS_MD.mp4
# Extracted 72 frames from 1005_IEO_FEA_HI.mp4
# Extracted 66 frames from 1005_IEO_FEA_LO.mp4
# Extracted 94 frames from 1005_IEO_FEA_MD.mp4
# Extracted 68 frames from 1005_IEO_HAP_HI.mp4
# Extracted 63 frames from 1005_IEO_HAP_LO.mp4
# Extracted 65 frames from 1005_IEO_HAP_MD.mp4
# Extracted 63 frames from 1005_IEO_NEU_XX.mp4
# Extracted 74 frames from 1005_IEO_SAD_HI.mp4
# Extracted 72 frames from 1005_IEO_SAD_LO.mp4
# Extracted 67 frames from 1005_IEO_SAD_MD.mp4
# Extracted 101 frames from 1005_IOM_ANG_XX.mp4
# Extracted 89 frames from 1005_IOM_DIS_XX.mp4
# Extracted 96 frames from 1005_IOM_FEA_XX.mp4
# Extracted 94 frames from 1005_IOM_HAP_XX.mp4
# Extracted 82 frames from 1005_IOM_NEU_XX.mp4
# Extracted 90 frames from 1005_IOM_SAD_XX.mp4
# Extracted 99 frames from 1005_ITH_ANG_XX.mp4
# Extracted 112 frames from 1005_ITH_DIS_XX.mp4
# Extracted 95 frames from 1005_ITH_FEA_XX.mp4
# Extracted 98 frames from 1005_ITH_HAP_XX.mp4
# Extracted 101 frames from 1005_ITH_NEU_XX.mp4
# Extracted 98 frames from 1005_ITH_SAD_XX.mp4
# Extracted 107 frames from 1005_ITS_ANG_XX.mp4
# Extracted 94 frames from 1005_ITS_DIS_XX.mp4
# Extracted 89 frames from 1005_ITS_FEA_XX.mp4
# Extracted 89 frames from 1005_ITS_HAP_XX.mp4
# Extracted 94 frames from 1005_ITS_NEU_XX.mp4
# Extracted 100 frames from 1005_ITS_SAD_XX.mp4
# Extracted 101 frames from 1005_IWL_ANG_XX.mp4
# Extracted 100 frames from 1005_IWL_DIS_XX.mp4
# Extracted 101 frames from 1005_IWL_FEA_XX.mp4
# Extracted 90 frames from 1005_IWL_HAP_XX.mp4
# Extracted 97 frames from 1005_IWL_NEU_XX.mp4
# Extracted 111 frames from 1005_IWL_SAD_XX.mp4
# Extracted 99 frames from 1005_IWW_ANG_XX.mp4
# Extracted 93 frames from 1005_IWW_DIS_XX.mp4
# Extracted 93 frames from 1005_IWW_FEA_XX.mp4
# Extracted 81 frames from 1005_IWW_HAP_XX.mp4
# Extracted 81 frames from 1005_IWW_NEU_XX.mp4
# Extracted 70 frames from 1005_IWW_SAD_XX.mp4
# Extracted 111 frames from 1005_MTI_ANG_XX.mp4
# Extracted 118 frames from 1005_MTI_DIS_XX.mp4
# Extracted 108 frames from 1005_MTI_FEA_XX.mp4
# Extracted 105 frames from 1005_MTI_HAP_XX.mp4
# Extracted 101 frames from 1005_MTI_NEU_XX.mp4
# Extracted 93 frames from 1005_MTI_SAD_XX.mp4
# Extracted 108 frames from 1005_TAI_ANG_XX.mp4
# Extracted 109 frames from 1005_TAI_DIS_XX.mp4
# Extracted 76 frames from 1005_TAI_FEA_XX.mp4
# Extracted 85 frames from 1005_TAI_HAP_XX.mp4
# Extracted 99 frames from 1005_TAI_NEU_XX.mp4
# Extracted 109 frames from 1005_TAI_SAD_XX.mp4
# Extracted 88 frames from 1005_TIE_ANG_XX.mp4
# Extracted 102 frames from 1005_TIE_DIS_XX.mp4
# Extracted 77 frames from 1005_TIE_FEA_XX.mp4
# Extracted 126 frames from 1005_TIE_HAP_XX.mp4
# Extracted 86 frames from 1005_TIE_NEU_XX.mp4
# Extracted 141 frames from 1005_TIE_SAD_XX.mp4
# Extracted 90 frames from 1005_TSI_ANG_XX.mp4
# Extracted 108 frames from 1005_TSI_DIS_XX.mp4
# Extracted 87 frames from 1005_TSI_FEA_XX.mp4
# Extracted 85 frames from 1005_TSI_HAP_XX.mp4
# Extracted 84 frames from 1005_TSI_NEU_XX.mp4
# Extracted 99 frames from 1005_TSI_SAD_XX.mp4
# Extracted 102 frames from 1005_WSI_ANG_XX.mp4
# Extracted 111 frames from 1005_WSI_DIS_XX.mp4
# Extracted 83 frames from 1005_WSI_FEA_XX.mp4
# Extracted 81 frames from 1005_WSI_HAP_XX.mp4
# Extracted 94 frames from 1005_WSI_NEU_XX.mp4
# Extracted 100 frames from 1005_WSI_SAD_XX.mp4
# Extracted 78 frames from 1006_DFA_ANG_XX.mp4
# Extracted 83 frames from 1006_DFA_DIS_XX.mp4
# Extracted 71 frames from 1006_DFA_FEA_XX.mp4
# Extracted 69 frames from 1006_DFA_HAP_XX.mp4
# Extracted 77 frames from 1006_DFA_NEU_XX.mp4
# Extracted 80 frames from 1006_DFA_SAD_XX.mp4
# Extracted 77 frames from 1006_IEO_ANG_HI.mp4
# Extracted 75 frames from 1006_IEO_ANG_LO.mp4
# Extracted 54 frames from 1006_IEO_ANG_MD.mp4
# Extracted 97 frames from 1006_IEO_DIS_HI.mp4
# Extracted 62 frames from 1006_IEO_DIS_LO.mp4
# Extracted 90 frames from 1006_IEO_DIS_MD.mp4
# Extracted 79 frames from 1006_IEO_FEA_HI.mp4
# Extracted 65 frames from 1006_IEO_FEA_LO.mp4
# Extracted 69 frames from 1006_IEO_FEA_MD.mp4
# Extracted 55 frames from 1006_IEO_HAP_HI.mp4
# Extracted 51 frames from 1006_IEO_HAP_LO.mp4
# Extracted 68 frames from 1006_IEO_HAP_MD.mp4
# Extracted 63 frames from 1006_IEO_NEU_XX.mp4
# Extracted 67 frames from 1006_IEO_SAD_HI.mp4
# Extracted 55 frames from 1006_IEO_SAD_LO.mp4
# Extracted 57 frames from 1006_IEO_SAD_MD.mp4
# Extracted 98 frames from 1006_IOM_ANG_XX.mp4
# Extracted 97 frames from 1006_IOM_DIS_XX.mp4
# Extracted 113 frames from 1006_IOM_FEA_XX.mp4
# Extracted 80 frames from 1006_IOM_HAP_XX.mp4
# Extracted 97 frames from 1006_IOM_NEU_XX.mp4
# Extracted 90 frames from 1006_IOM_SAD_XX.mp4
# Extracted 96 frames from 1006_ITH_ANG_XX.mp4
# Extracted 126 frames from 1006_ITH_DIS_XX.mp4
# Extracted 97 frames from 1006_ITH_FEA_XX.mp4
# Extracted 91 frames from 1006_ITH_HAP_XX.mp4
# Extracted 103 frames from 1006_ITH_NEU_XX.mp4
# Extracted 111 frames from 1006_ITH_SAD_XX.mp4
# Extracted 96 frames from 1006_ITS_ANG_XX.mp4
# Extracted 100 frames from 1006_ITS_DIS_XX.mp4
# Extracted 89 frames from 1006_ITS_FEA_XX.mp4
# Extracted 83 frames from 1006_ITS_HAP_XX.mp4
# Extracted 90 frames from 1006_ITS_NEU_XX.mp4
# Extracted 93 frames from 1006_ITS_SAD_XX.mp4
# Extracted 100 frames from 1006_IWL_ANG_XX.mp4
# Extracted 104 frames from 1006_IWL_DIS_XX.mp4
# Extracted 81 frames from 1006_IWL_FEA_XX.mp4
# Extracted 85 frames from 1006_IWL_HAP_XX.mp4
# Extracted 91 frames from 1006_IWL_NEU_XX.mp4
# Extracted 94 frames from 1006_IWL_SAD_XX.mp4
# Extracted 82 frames from 1006_IWW_ANG_XX.mp4
# Extracted 110 frames from 1006_IWW_DIS_XX.mp4
# Extracted 106 frames from 1006_IWW_FEA_XX.mp4
# Extracted 84 frames from 1006_IWW_HAP_XX.mp4
# Extracted 93 frames from 1006_IWW_NEU_XX.mp4
# Extracted 115 frames from 1006_IWW_SAD_XX.mp4
# Extracted 113 frames from 1006_MTI_ANG_XX.mp4
# Extracted 112 frames from 1006_MTI_DIS_XX.mp4
# Extracted 136 frames from 1006_MTI_FEA_XX.mp4
# Extracted 108 frames from 1006_MTI_HAP_XX.mp4
# Extracted 122 frames from 1006_MTI_NEU_XX.mp4
# Extracted 127 frames from 1006_MTI_SAD_XX.mp4
# Extracted 96 frames from 1006_TAI_ANG_XX.mp4
# Extracted 106 frames from 1006_TAI_DIS_XX.mp4
# Extracted 101 frames from 1006_TAI_FEA_XX.mp4
# Extracted 117 frames from 1006_TAI_HAP_XX.mp4
# Extracted 95 frames from 1006_TAI_NEU_XX.mp4
# Extracted 109 frames from 1006_TAI_SAD_XX.mp4
# Extracted 125 frames from 1006_TIE_ANG_XX.mp4
# Extracted 101 frames from 1006_TIE_DIS_XX.mp4
# Extracted 95 frames from 1006_TIE_FEA_XX.mp4
# Extracted 74 frames from 1006_TIE_HAP_XX.mp4
# Extracted 74 frames from 1006_TIE_NEU_XX.mp4
# Extracted 110 frames from 1006_TIE_SAD_XX.mp4
# Extracted 75 frames from 1006_TSI_ANG_XX.mp4
# Extracted 98 frames from 1006_TSI_DIS_XX.mp4
# Extracted 100 frames from 1006_TSI_FEA_XX.mp4
# Extracted 74 frames from 1006_TSI_HAP_XX.mp4
# Extracted 74 frames from 1006_TSI_NEU_XX.mp4
# Extracted 92 frames from 1006_TSI_SAD_XX.mp4
# Extracted 82 frames from 1006_WSI_ANG_XX.mp4
# Extracted 86 frames from 1006_WSI_DIS_XX.mp4
# Extracted 89 frames from 1006_WSI_FEA_XX.mp4
# Extracted 82 frames from 1006_WSI_HAP_XX.mp4
# Extracted 103 frames from 1006_WSI_NEU_XX.mp4
# Extracted 117 frames from 1006_WSI_SAD_XX.mp4
# Extracted 75 frames from 1007_DFA_ANG_XX.mp4
# Extracted 86 frames from 1007_DFA_DIS_XX.mp4
# Extracted 82 frames from 1007_DFA_FEA_XX.mp4
# Extracted 66 frames from 1007_DFA_HAP_XX.mp4
# Extracted 79 frames from 1007_DFA_NEU_XX.mp4
# Extracted 65 frames from 1007_DFA_SAD_XX.mp4
# Extracted 73 frames from 1007_IEO_ANG_HI.mp4
# Extracted 55 frames from 1007_IEO_ANG_LO.mp4
# Extracted 81 frames from 1007_IEO_ANG_MD.mp4
# Extracted 68 frames from 1007_IEO_DIS_HI.mp4
# Extracted 58 frames from 1007_IEO_DIS_LO.mp4
# Extracted 61 frames from 1007_IEO_DIS_MD.mp4
# Extracted 59 frames from 1007_IEO_FEA_HI.mp4
# Extracted 69 frames from 1007_IEO_FEA_LO.mp4
# Extracted 89 frames from 1007_IEO_FEA_MD.mp4
# Extracted 55 frames from 1007_IEO_HAP_HI.mp4
# Extracted 51 frames from 1007_IEO_HAP_LO.mp4
# Extracted 63 frames from 1007_IEO_HAP_MD.mp4
# Extracted 62 frames from 1007_IEO_NEU_XX.mp4
# Extracted 76 frames from 1007_IEO_SAD_HI.mp4
# Extracted 64 frames from 1007_IEO_SAD_LO.mp4
# Extracted 73 frames from 1007_IEO_SAD_MD.mp4
# Extracted 106 frames from 1007_IOM_ANG_XX.mp4
# Extracted 111 frames from 1007_IOM_DIS_XX.mp4
# Extracted 101 frames from 1007_IOM_FEA_XX.mp4
# Extracted 114 frames from 1007_IOM_HAP_XX.mp4
# Extracted 97 frames from 1007_IOM_NEU_XX.mp4
# Extracted 81 frames from 1007_IOM_SAD_XX.mp4
# Extracted 103 frames from 1007_ITH_ANG_XX.mp4
# Extracted 128 frames from 1007_ITH_DIS_XX.mp4
# Extracted 116 frames from 1007_ITH_FEA_XX.mp4
# Extracted 97 frames from 1007_ITH_HAP_XX.mp4
# Extracted 143 frames from 1007_ITH_NEU_XX.mp4
# Extracted 108 frames from 1007_ITH_SAD_XX.mp4
# Extracted 105 frames from 1007_ITS_ANG_XX.mp4
# Extracted 135 frames from 1007_ITS_DIS_XX.mp4
# Extracted 114 frames from 1007_ITS_FEA_XX.mp4
# Extracted 100 frames from 1007_ITS_HAP_XX.mp4
# Extracted 103 frames from 1007_ITS_NEU_XX.mp4
# Extracted 109 frames from 1007_ITS_SAD_XX.mp4
# Extracted 103 frames from 1007_IWL_ANG_XX.mp4
# Extracted 117 frames from 1007_IWL_DIS_XX.mp4
# Extracted 102 frames from 1007_IWL_FEA_XX.mp4
# Extracted 96 frames from 1007_IWL_HAP_XX.mp4
# Extracted 92 frames from 1007_IWL_NEU_XX.mp4
# Extracted 100 frames from 1007_IWL_SAD_XX.mp4
# Extracted 85 frames from 1007_IWW_ANG_XX.mp4
# Extracted 88 frames from 1007_IWW_DIS_XX.mp4
# Extracted 100 frames from 1007_IWW_FEA_XX.mp4
# Extracted 95 frames from 1007_IWW_HAP_XX.mp4
# Extracted 98 frames from 1007_IWW_NEU_XX.mp4
# Extracted 112 frames from 1007_IWW_SAD_XX.mp4
# Extracted 131 frames from 1007_MTI_ANG_XX.mp4
# Extracted 122 frames from 1007_MTI_DIS_XX.mp4
# Extracted 96 frames from 1007_MTI_FEA_XX.mp4
# Extracted 101 frames from 1007_MTI_HAP_XX.mp4
# Extracted 102 frames from 1007_MTI_NEU_XX.mp4
# Extracted 102 frames from 1007_MTI_SAD_XX.mp4
# Extracted 97 frames from 1007_TAI_ANG_XX.mp4
# Extracted 91 frames from 1007_TAI_DIS_XX.mp4
# Extracted 122 frames from 1007_TAI_FEA_XX.mp4
# Extracted 102 frames from 1007_TAI_HAP_XX.mp4
# Extracted 108 frames from 1007_TAI_NEU_XX.mp4
# Extracted 88 frames from 1007_TAI_SAD_XX.mp4
# Extracted 138 frames from 1007_TIE_ANG_XX.mp4
# Extracted 135 frames from 1007_TIE_DIS_XX.mp4
# Extracted 99 frames from 1007_TIE_FEA_XX.mp4
# Extracted 79 frames from 1007_TIE_HAP_XX.mp4
# Extracted 99 frames from 1007_TIE_NEU_XX.mp4
# Extracted 113 frames from 1007_TIE_SAD_XX.mp4
# Extracted 68 frames from 1007_TSI_ANG_XX.mp4
# Extracted 88 frames from 1007_TSI_DIS_XX.mp4
# Extracted 84 frames from 1007_TSI_FEA_XX.mp4
# Extracted 63 frames from 1007_TSI_HAP_XX.mp4
# Extracted 89 frames from 1007_TSI_NEU_XX.mp4
# Extracted 94 frames from 1007_TSI_SAD_XX.mp4
# Extracted 96 frames from 1007_WSI_ANG_XX.mp4
# Extracted 119 frames from 1007_WSI_DIS_XX.mp4
# Extracted 95 frames from 1007_WSI_FEA_XX.mp4
# Extracted 91 frames from 1007_WSI_HAP_XX.mp4
# Extracted 131 frames from 1007_WSI_NEU_XX.mp4
# Extracted 103 frames from 1007_WSI_SAD_XX.mp4
# Extracted 93 frames from 1008_DFA_ANG_XX.mp4
# Extracted 109 frames from 1008_DFA_DIS_XX.mp4
# Extracted 77 frames from 1008_DFA_FEA_XX.mp4
# Extracted 96 frames from 1008_DFA_HAP_XX.mp4
# Extracted 72 frames from 1008_DFA_NEU_XX.mp4
# Extracted 112 frames from 1008_DFA_SAD_XX.mp4
# Extracted 86 frames from 1008_IEO_ANG_HI.mp4
# Extracted 69 frames from 1008_IEO_ANG_LO.mp4
# Extracted 77 frames from 1008_IEO_ANG_MD.mp4
# Extracted 102 frames from 1008_IEO_DIS_HI.mp4
# Extracted 79 frames from 1008_IEO_DIS_LO.mp4
# Extracted 94 frames from 1008_IEO_DIS_MD.mp4
# Extracted 91 frames from 1008_IEO_FEA_HI.mp4
# Extracted 74 frames from 1008_IEO_FEA_LO.mp4
# Extracted 60 frames from 1008_IEO_FEA_MD.mp4
# Extracted 78 frames from 1008_IEO_HAP_HI.mp4
# Extracted 66 frames from 1008_IEO_HAP_LO.mp4
# Extracted 72 frames from 1008_IEO_HAP_MD.mp4
# Extracted 42 frames from 1008_IEO_NEU_XX.mp4
# Extracted 98 frames from 1008_IEO_SAD_HI.mp4
# Extracted 88 frames from 1008_IEO_SAD_LO.mp4
# Extracted 74 frames from 1008_IEO_SAD_MD.mp4
# Extracted 110 frames from 1008_IOM_ANG_XX.mp4
# Extracted 109 frames from 1008_IOM_DIS_XX.mp4
# Extracted 114 frames from 1008_IOM_FEA_XX.mp4
# Extracted 79 frames from 1008_IOM_HAP_XX.mp4
# Extracted 73 frames from 1008_IOM_NEU_XX.mp4
# Extracted 111 frames from 1008_IOM_SAD_XX.mp4
# Extracted 127 frames from 1008_ITH_ANG_XX.mp4
# Extracted 114 frames from 1008_ITH_DIS_XX.mp4
# Extracted 124 frames from 1008_ITH_FEA_XX.mp4
# Extracted 100 frames from 1008_ITH_HAP_XX.mp4
# Extracted 93 frames from 1008_ITH_NEU_XX.mp4
# Extracted 131 frames from 1008_ITH_SAD_XX.mp4
# Extracted 95 frames from 1008_ITS_ANG_XX.mp4
# Extracted 94 frames from 1008_ITS_DIS_XX.mp4
# Extracted 95 frames from 1008_ITS_FEA_XX.mp4
# Extracted 80 frames from 1008_ITS_HAP_XX.mp4
# Extracted 95 frames from 1008_ITS_NEU_XX.mp4
# Extracted 102 frames from 1008_ITS_SAD_XX.mp4
# Extracted 116 frames from 1008_IWL_ANG_XX.mp4
# Extracted 106 frames from 1008_IWL_DIS_XX.mp4
# Extracted 99 frames from 1008_IWL_FEA_XX.mp4
# Extracted 79 frames from 1008_IWL_HAP_XX.mp4
# Extracted 80 frames from 1008_IWL_NEU_XX.mp4
# Extracted 118 frames from 1008_IWL_SAD_XX.mp4
# Extracted 104 frames from 1008_IWW_ANG_XX.mp4
# Extracted 100 frames from 1008_IWW_DIS_XX.mp4
# Extracted 81 frames from 1008_IWW_FEA_XX.mp4
# Extracted 93 frames from 1008_IWW_HAP_XX.mp4
# Extracted 79 frames from 1008_IWW_NEU_XX.mp4
# Extracted 92 frames from 1008_IWW_SAD_XX.mp4
# Extracted 106 frames from 1008_MTI_ANG_XX.mp4
# Extracted 115 frames from 1008_MTI_DIS_XX.mp4
# Extracted 107 frames from 1008_MTI_FEA_XX.mp4
# Extracted 97 frames from 1008_MTI_HAP_XX.mp4
# Extracted 87 frames from 1008_MTI_NEU_XX.mp4
# Extracted 108 frames from 1008_MTI_SAD_XX.mp4
# Extracted 114 frames from 1008_TAI_ANG_XX.mp4
# Extracted 123 frames from 1008_TAI_DIS_XX.mp4
# Extracted 104 frames from 1008_TAI_FEA_XX.mp4
# Extracted 96 frames from 1008_TAI_HAP_XX.mp4
# Extracted 109 frames from 1008_TAI_NEU_XX.mp4
# Extracted 111 frames from 1008_TAI_SAD_XX.mp4
# Extracted 149 frames from 1008_TIE_ANG_XX.mp4
# Extracted 145 frames from 1008_TIE_DIS_XX.mp4
# Extracted 135 frames from 1008_TIE_FEA_XX.mp4
# Extracted 102 frames from 1008_TIE_HAP_XX.mp4
# Extracted 91 frames from 1008_TIE_NEU_XX.mp4
# Extracted 141 frames from 1008_TIE_SAD_XX.mp4
# Extracted 89 frames from 1008_TSI_ANG_XX.mp4
# Extracted 91 frames from 1008_TSI_DIS_XX.mp4
# Extracted 70 frames from 1008_TSI_FEA_XX.mp4
# Extracted 95 frames from 1008_TSI_HAP_XX.mp4
# Extracted 110 frames from 1008_TSI_NEU_XX.mp4
# Extracted 90 frames from 1008_TSI_SAD_XX.mp4
# Extracted 61 frames from 1009_DFA_ANG_XX.mp4
# Extracted 77 frames from 1009_DFA_DIS_XX.mp4
# Extracted 76 frames from 1009_DFA_FEA_XX.mp4
# Extracted 72 frames from 1009_DFA_HAP_XX.mp4
# Extracted 72 frames from 1009_DFA_NEU_XX.mp4
# Extracted 93 frames from 1009_DFA_SAD_XX.mp4
# Extracted 83 frames from 1009_IEO_ANG_HI.mp4
# Extracted 73 frames from 1009_IEO_ANG_LO.mp4
# Extracted 70 frames from 1009_IEO_ANG_MD.mp4
# Extracted 82 frames from 1009_IEO_DIS_HI.mp4
# Extracted 69 frames from 1009_IEO_DIS_LO.mp4
# Extracted 57 frames from 1009_IEO_DIS_MD.mp4
# Extracted 68 frames from 1009_IEO_FEA_HI.mp4
# Extracted 58 frames from 1009_IEO_FEA_LO.mp4
# Extracted 55 frames from 1009_IEO_FEA_MD.mp4
# Extracted 82 frames from 1009_IEO_HAP_HI.mp4
# Extracted 82 frames from 1009_IEO_HAP_LO.mp4
# Extracted 78 frames from 1009_IEO_HAP_MD.mp4
# Extracted 76 frames from 1009_IEO_NEU_XX.mp4
# Extracted 112 frames from 1009_IEO_SAD_HI.mp4
# Extracted 77 frames from 1009_IEO_SAD_LO.mp4
# Extracted 76 frames from 1009_IEO_SAD_MD.mp4
# Extracted 85 frames from 1009_IOM_ANG_XX.mp4
# Extracted 88 frames from 1009_IOM_DIS_XX.mp4
# Extracted 75 frames from 1009_IOM_FEA_XX.mp4
# Extracted 71 frames from 1009_IOM_HAP_XX.mp4
# Extracted 65 frames from 1009_IOM_NEU_XX.mp4
# Extracted 90 frames from 1009_IOM_SAD_XX.mp4
# Extracted 85 frames from 1009_ITH_ANG_XX.mp4
# Extracted 89 frames from 1009_ITH_DIS_XX.mp4
# Extracted 86 frames from 1009_ITH_FEA_XX.mp4
# Extracted 72 frames from 1009_ITH_HAP_XX.mp4
# Extracted 94 frames from 1009_ITH_NEU_XX.mp4
# Extracted 104 frames from 1009_ITH_SAD_XX.mp4
# Extracted 110 frames from 1009_ITS_ANG_XX.mp4
# Extracted 90 frames from 1009_ITS_DIS_XX.mp4
# Extracted 76 frames from 1009_ITS_FEA_XX.mp4
# Extracted 77 frames from 1009_ITS_HAP_XX.mp4
# Extracted 84 frames from 1009_ITS_NEU_XX.mp4
# Extracted 93 frames from 1009_ITS_SAD_XX.mp4
# Extracted 96 frames from 1009_IWL_ANG_XX.mp4
# Extracted 96 frames from 1009_IWL_DIS_XX.mp4
# Extracted 73 frames from 1009_IWL_FEA_XX.mp4
# Extracted 97 frames from 1009_IWL_HAP_XX.mp4
# Extracted 83 frames from 1009_IWL_NEU_XX.mp4
# Extracted 92 frames from 1009_IWL_SAD_XX.mp4
# Extracted 95 frames from 1009_IWW_ANG_XX.mp4
# Extracted 107 frames from 1009_IWW_DIS_XX.mp4
# Extracted 79 frames from 1009_IWW_FEA_XX.mp4
# Extracted 63 frames from 1009_IWW_HAP_XX.mp4
# Extracted 73 frames from 1009_IWW_NEU_XX.mp4
# Extracted 83 frames from 1009_IWW_SAD_XX.mp4
# Extracted 73 frames from 1009_TAI_ANG_XX.mp4
# Extracted 99 frames from 1009_TAI_DIS_XX.mp4
# Extracted 86 frames from 1009_TAI_FEA_XX.mp4
# Extracted 81 frames from 1009_TAI_HAP_XX.mp4
# Extracted 85 frames from 1009_TAI_NEU_XX.mp4
# Extracted 98 frames from 1009_TAI_SAD_XX.mp4
# Extracted 88 frames from 1009_TIE_ANG_XX.mp4
# Extracted 101 frames from 1009_TIE_DIS_XX.mp4
# Extracted 80 frames from 1009_TIE_FEA_XX.mp4
# Extracted 80 frames from 1009_TIE_HAP_XX.mp4
# Extracted 80 frames from 1009_TIE_NEU_XX.mp4
# Extracted 81 frames from 1009_TIE_SAD_XX.mp4
# Extracted 70 frames from 1009_TSI_ANG_XX.mp4
# Extracted 74 frames from 1009_TSI_DIS_XX.mp4
# Extracted 69 frames from 1009_TSI_FEA_XX.mp4
# Extracted 77 frames from 1009_TSI_HAP_XX.mp4
# Extracted 73 frames from 1009_TSI_NEU_XX.mp4
# Extracted 75 frames from 1009_TSI_SAD_XX.mp4
# Extracted 99 frames from 1009_WSI_ANG_XX.mp4
# Extracted 86 frames from 1009_WSI_DIS_XX.mp4
# Extracted 83 frames from 1009_WSI_FEA_XX.mp4
# Extracted 80 frames from 1009_WSI_HAP_XX.mp4
# Extracted 81 frames from 1009_WSI_NEU_XX.mp4
# Extracted 86 frames from 1009_WSI_SAD_XX.mp4
# Extracted 66 frames from 1010_DFA_ANG_XX.mp4
# Extracted 79 frames from 1010_DFA_DIS_XX.mp4
# Extracted 68 frames from 1010_DFA_FEA_XX.mp4
# Extracted 57 frames from 1010_DFA_HAP_XX.mp4
# Extracted 76 frames from 1010_DFA_NEU_XX.mp4
# Extracted 65 frames from 1010_DFA_SAD_XX.mp4
# Extracted 65 frames from 1010_IEO_ANG_HI.mp4
# Extracted 69 frames from 1010_IEO_ANG_LO.mp4
# Extracted 74 frames from 1010_IEO_ANG_MD.mp4
# Extracted 99 frames from 1010_IEO_DIS_HI.mp4
# Extracted 79 frames from 1010_IEO_DIS_LO.mp4
# Extracted 91 frames from 1010_IEO_DIS_MD.mp4
# Extracted 92 frames from 1010_IEO_FEA_HI.mp4
# Extracted 67 frames from 1010_IEO_FEA_LO.mp4
# Extracted 84 frames from 1010_IEO_FEA_MD.mp4
# Extracted 62 frames from 1010_IEO_HAP_HI.mp4
# Extracted 73 frames from 1010_IEO_HAP_LO.mp4
# Extracted 73 frames from 1010_IEO_HAP_MD.mp4
# Extracted 68 frames from 1010_IEO_NEU_XX.mp4
# Extracted 103 frames from 1010_IEO_SAD_HI.mp4
# Extracted 60 frames from 1010_IEO_SAD_LO.mp4
# Extracted 80 frames from 1010_IEO_SAD_MD.mp4
# Extracted 78 frames from 1010_IOM_ANG_XX.mp4
# Extracted 82 frames from 1010_IOM_DIS_XX.mp4
# Extracted 74 frames from 1010_IOM_FEA_XX.mp4
# Extracted 58 frames from 1010_IOM_HAP_XX.mp4
# Extracted 86 frames from 1010_IOM_NEU_XX.mp4
# Extracted 72 frames from 1010_IOM_SAD_XX.mp4
# Extracted 99 frames from 1010_ITH_ANG_XX.mp4
# Extracted 101 frames from 1010_ITH_DIS_XX.mp4
# Extracted 70 frames from 1010_ITH_FEA_XX.mp4
# Extracted 85 frames from 1010_ITH_HAP_XX.mp4
# Extracted 80 frames from 1010_ITH_NEU_XX.mp4
# Extracted 86 frames from 1010_ITH_SAD_XX.mp4
# Extracted 82 frames from 1010_ITS_ANG_XX.mp4
# Extracted 93 frames from 1010_ITS_DIS_XX.mp4
# Extracted 87 frames from 1010_ITS_FEA_XX.mp4
# Extracted 59 frames from 1010_ITS_HAP_XX.mp4
# Extracted 75 frames from 1010_ITS_NEU_XX.mp4
# Extracted 94 frames from 1010_ITS_SAD_XX.mp4
# Extracted 90 frames from 1010_IWL_ANG_XX.mp4
# Extracted 86 frames from 1010_IWL_DIS_XX.mp4
# Extracted 86 frames from 1010_IWL_FEA_XX.mp4
# Extracted 70 frames from 1010_IWL_HAP_XX.mp4
# Extracted 111 frames from 1010_IWL_NEU_XX.mp4
# Extracted 71 frames from 1010_IWL_SAD_XX.mp4
# Extracted 67 frames from 1010_IWW_ANG_XX.mp4
# Extracted 78 frames from 1010_IWW_DIS_XX.mp4
# Extracted 108 frames from 1010_IWW_FEA_XX.mp4
# Extracted 86 frames from 1010_IWW_HAP_XX.mp4
# Extracted 75 frames from 1010_IWW_NEU_XX.mp4
# Extracted 84 frames from 1010_IWW_SAD_XX.mp4
# Extracted 89 frames from 1010_MTI_ANG_XX.mp4
# Extracted 81 frames from 1010_MTI_DIS_XX.mp4
# Extracted 87 frames from 1010_MTI_FEA_XX.mp4
# Extracted 71 frames from 1010_MTI_HAP_XX.mp4
# Extracted 85 frames from 1010_MTI_NEU_XX.mp4
# Extracted 74 frames from 1010_MTI_SAD_XX.mp4
# Extracted 77 frames from 1010_TAI_ANG_XX.mp4
# Extracted 92 frames from 1010_TAI_DIS_XX.mp4
# Extracted 81 frames from 1010_TAI_FEA_XX.mp4
# Extracted 71 frames from 1010_TAI_HAP_XX.mp4
# Extracted 92 frames from 1010_TAI_NEU_XX.mp4
# Extracted 87 frames from 1010_TAI_SAD_XX.mp4
# Extracted 104 frames from 1010_TIE_ANG_XX.mp4
# Extracted 118 frames from 1010_TIE_DIS_XX.mp4
# Extracted 83 frames from 1010_TIE_FEA_XX.mp4
# Extracted 89 frames from 1010_TIE_HAP_XX.mp4
# Extracted 79 frames from 1010_TIE_NEU_XX.mp4
# Extracted 101 frames from 1010_TIE_SAD_XX.mp4
# Extracted 73 frames from 1010_TSI_ANG_XX.mp4
# Extracted 82 frames from 1010_TSI_DIS_XX.mp4
# Extracted 66 frames from 1010_TSI_FEA_XX.mp4
# Extracted 54 frames from 1010_TSI_HAP_XX.mp4
# Extracted 63 frames from 1010_TSI_NEU_XX.mp4
# Extracted 67 frames from 1010_TSI_SAD_XX.mp4
# Extracted 95 frames from 1010_WSI_ANG_XX.mp4
# Extracted 94 frames from 1010_WSI_DIS_XX.mp4
# Extracted 94 frames from 1010_WSI_FEA_XX.mp4
# Extracted 66 frames from 1010_WSI_HAP_XX.mp4
# Extracted 77 frames from 1010_WSI_NEU_XX.mp4
# Extracted 88 frames from 1010_WSI_SAD_XX.mp4
# Extracted 89 frames from 1011_DFA_ANG_XX.mp4
# Extracted 76 frames from 1011_DFA_DIS_XX.mp4
# Extracted 61 frames from 1011_DFA_FEA_XX.mp4
# Extracted 61 frames from 1011_DFA_HAP_XX.mp4
# Extracted 74 frames from 1011_DFA_NEU_XX.mp4
# Extracted 75 frames from 1011_DFA_SAD_XX.mp4
# Extracted 103 frames from 1011_IEO_ANG_HI.mp4
# Extracted 91 frames from 1011_IEO_ANG_LO.mp4
# Extracted 75 frames from 1011_IEO_ANG_MD.mp4
# Extracted 83 frames from 1011_IEO_DIS_HI.mp4
# Extracted 83 frames from 1011_IEO_DIS_LO.mp4
# Extracted 85 frames from 1011_IEO_DIS_MD.mp4
# Extracted 78 frames from 1011_IEO_FEA_HI.mp4
# Extracted 84 frames from 1011_IEO_FEA_LO.mp4
# Extracted 77 frames from 1011_IEO_FEA_MD.mp4
# Extracted 76 frames from 1011_IEO_HAP_HI.mp4
# Extracted 63 frames from 1011_IEO_HAP_LO.mp4
# Extracted 65 frames from 1011_IEO_HAP_MD.mp4
# Extracted 52 frames from 1011_IEO_NEU_XX.mp4
# Extracted 98 frames from 1011_IEO_SAD_HI.mp4
# Extracted 73 frames from 1011_IEO_SAD_LO.mp4
# Extracted 70 frames from 1011_IEO_SAD_MD.mp4
# Extracted 79 frames from 1011_IOM_ANG_XX.mp4
# Extracted 85 frames from 1011_IOM_DIS_XX.mp4
# Extracted 82 frames from 1011_IOM_FEA_XX.mp4
# Extracted 73 frames from 1011_IOM_HAP_XX.mp4
# Extracted 64 frames from 1011_IOM_NEU_XX.mp4
# Extracted 76 frames from 1011_IOM_SAD_XX.mp4
# Extracted 90 frames from 1011_ITH_ANG_XX.mp4
# Extracted 86 frames from 1011_ITH_DIS_XX.mp4
# Extracted 69 frames from 1011_ITH_FEA_XX.mp4
# Extracted 76 frames from 1011_ITH_HAP_XX.mp4
# Extracted 85 frames from 1011_ITH_NEU_XX.mp4
# Extracted 69 frames from 1011_ITH_SAD_XX.mp4
# Extracted 81 frames from 1011_ITS_ANG_XX.mp4
# Extracted 95 frames from 1011_ITS_DIS_XX.mp4
# Extracted 75 frames from 1011_ITS_FEA_XX.mp4
# Extracted 70 frames from 1011_ITS_HAP_XX.mp4
# Extracted 73 frames from 1011_ITS_NEU_XX.mp4
# Extracted 82 frames from 1011_ITS_SAD_XX.mp4
# Extracted 79 frames from 1011_IWL_ANG_XX.mp4
# Extracted 68 frames from 1011_IWL_DIS_XX.mp4
# Extracted 73 frames from 1011_IWL_FEA_XX.mp4
# Extracted 67 frames from 1011_IWL_HAP_XX.mp4
# Extracted 73 frames from 1011_IWL_NEU_XX.mp4
# Extracted 86 frames from 1011_IWL_SAD_XX.mp4
# Extracted 79 frames from 1011_IWW_ANG_XX.mp4
# Extracted 93 frames from 1011_IWW_DIS_XX.mp4
# Extracted 70 frames from 1011_IWW_FEA_XX.mp4
# Extracted 64 frames from 1011_IWW_HAP_XX.mp4
# Extracted 83 frames from 1011_IWW_NEU_XX.mp4
# Extracted 67 frames from 1011_IWW_SAD_XX.mp4
# Extracted 87 frames from 1011_MTI_ANG_XX.mp4
# Extracted 85 frames from 1011_MTI_DIS_XX.mp4
# Extracted 70 frames from 1011_MTI_FEA_XX.mp4
# Extracted 83 frames from 1011_MTI_HAP_XX.mp4
# Extracted 85 frames from 1011_MTI_NEU_XX.mp4
# Extracted 72 frames from 1011_MTI_SAD_XX.mp4
# Extracted 78 frames from 1011_TAI_ANG_XX.mp4
# Extracted 85 frames from 1011_TAI_DIS_XX.mp4
# Extracted 79 frames from 1011_TAI_FEA_XX.mp4
# Extracted 66 frames from 1011_TAI_HAP_XX.mp4
# Extracted 81 frames from 1011_TAI_NEU_XX.mp4
# Extracted 70 frames from 1011_TAI_SAD_XX.mp4
# Extracted 104 frames from 1011_TIE_ANG_XX.mp4
# Extracted 131 frames from 1011_TIE_DIS_XX.mp4
# Extracted 83 frames from 1011_TIE_FEA_XX.mp4
# Extracted 74 frames from 1011_TIE_HAP_XX.mp4
# Extracted 67 frames from 1011_TIE_NEU_XX.mp4
# Extracted 113 frames from 1011_TIE_SAD_XX.mp4
# Extracted 85 frames from 1011_TSI_ANG_XX.mp4
# Extracted 81 frames from 1011_TSI_DIS_XX.mp4
# Extracted 78 frames from 1011_TSI_FEA_XX.mp4
# Extracted 66 frames from 1011_TSI_HAP_XX.mp4
# Extracted 74 frames from 1011_TSI_NEU_XX.mp4
# Extracted 72 frames from 1011_TSI_SAD_XX.mp4
# Extracted 104 frames from 1011_WSI_ANG_XX.mp4
# Extracted 94 frames from 1011_WSI_DIS_XX.mp4
# Extracted 68 frames from 1011_WSI_FEA_XX.mp4
# Extracted 70 frames from 1011_WSI_HAP_XX.mp4
# Extracted 88 frames from 1011_WSI_NEU_XX.mp4
# Extracted 78 frames from 1011_WSI_SAD_XX.mp4
# Extracted 81 frames from 1012_DFA_ANG_XX.mp4
# Extracted 62 frames from 1012_DFA_DIS_XX.mp4
# Extracted 62 frames from 1012_DFA_FEA_XX.mp4
# Extracted 70 frames from 1012_DFA_HAP_XX.mp4
# Extracted 69 frames from 1012_DFA_NEU_XX.mp4
# Extracted 68 frames from 1012_DFA_SAD_XX.mp4
# Extracted 64 frames from 1012_IEO_ANG_HI.mp4
# Extracted 66 frames from 1012_IEO_ANG_LO.mp4
# Extracted 68 frames from 1012_IEO_ANG_MD.mp4
# Extracted 86 frames from 1012_IEO_DIS_HI.mp4
# Extracted 68 frames from 1012_IEO_DIS_LO.mp4
# Extracted 82 frames from 1012_IEO_DIS_MD.mp4
# Extracted 83 frames from 1012_IEO_FEA_HI.mp4
# Extracted 60 frames from 1012_IEO_FEA_LO.mp4
# Extracted 89 frames from 1012_IEO_FEA_MD.mp4
# Extracted 82 frames from 1012_IEO_HAP_HI.mp4
# Extracted 80 frames from 1012_IEO_HAP_LO.mp4
# Extracted 66 frames from 1012_IEO_HAP_MD.mp4
# Extracted 67 frames from 1012_IEO_NEU_XX.mp4
# Extracted 81 frames from 1012_IEO_SAD_HI.mp4
# Extracted 72 frames from 1012_IEO_SAD_LO.mp4
# Extracted 80 frames from 1012_IEO_SAD_MD.mp4
# Extracted 62 frames from 1012_IOM_ANG_XX.mp4
# Extracted 74 frames from 1012_IOM_DIS_XX.mp4
# Extracted 68 frames from 1012_IOM_FEA_XX.mp4
# Extracted 70 frames from 1012_IOM_HAP_XX.mp4
# Extracted 65 frames from 1012_IOM_NEU_XX.mp4
# Extracted 69 frames from 1012_IOM_SAD_XX.mp4
# Extracted 88 frames from 1012_ITH_ANG_XX.mp4
# Extracted 79 frames from 1012_ITH_DIS_XX.mp4
# Extracted 83 frames from 1012_ITH_FEA_XX.mp4
# Extracted 86 frames from 1012_ITH_HAP_XX.mp4
# Extracted 73 frames from 1012_ITH_NEU_XX.mp4
# Extracted 73 frames from 1012_ITH_SAD_XX.mp4
# Extracted 87 frames from 1012_ITS_ANG_XX.mp4
# Extracted 79 frames from 1012_ITS_DIS_XX.mp4
# Extracted 67 frames from 1012_ITS_FEA_XX.mp4
# Extracted 77 frames from 1012_ITS_HAP_XX.mp4
# Extracted 66 frames from 1012_ITS_NEU_XX.mp4
# Extracted 93 frames from 1012_ITS_SAD_XX.mp4
# Extracted 79 frames from 1012_IWL_ANG_XX.mp4
# Extracted 86 frames from 1012_IWL_DIS_XX.mp4
# Extracted 72 frames from 1012_IWL_FEA_XX.mp4
# Extracted 91 frames from 1012_IWL_HAP_XX.mp4
# Extracted 79 frames from 1012_IWL_NEU_XX.mp4
# Extracted 86 frames from 1012_IWL_SAD_XX.mp4
# Extracted 70 frames from 1012_IWW_ANG_XX.mp4
# Extracted 68 frames from 1012_IWW_DIS_XX.mp4
# Extracted 78 frames from 1012_IWW_FEA_XX.mp4
# Extracted 81 frames from 1012_IWW_HAP_XX.mp4
# Extracted 71 frames from 1012_IWW_NEU_XX.mp4
# Extracted 73 frames from 1012_IWW_SAD_XX.mp4
# Extracted 72 frames from 1012_MTI_ANG_XX.mp4
# Extracted 89 frames from 1012_MTI_DIS_XX.mp4
# Extracted 68 frames from 1012_MTI_FEA_XX.mp4
# Extracted 80 frames from 1012_MTI_HAP_XX.mp4
# Extracted 75 frames from 1012_MTI_NEU_XX.mp4
# Extracted 80 frames from 1012_MTI_SAD_XX.mp4
# Extracted 70 frames from 1012_TAI_ANG_XX.mp4
# Extracted 93 frames from 1012_TAI_DIS_XX.mp4
# Extracted 72 frames from 1012_TAI_FEA_XX.mp4
# Extracted 81 frames from 1012_TAI_HAP_XX.mp4
# Extracted 74 frames from 1012_TAI_NEU_XX.mp4
# Extracted 78 frames from 1012_TAI_SAD_XX.mp4
# Extracted 84 frames from 1012_TIE_ANG_XX.mp4
# Extracted 81 frames from 1012_TIE_DIS_XX.mp4
# Extracted 80 frames from 1012_TIE_FEA_XX.mp4
# Extracted 107 frames from 1012_TIE_HAP_XX.mp4
# Extracted 85 frames from 1012_TIE_NEU_XX.mp4
# Extracted 93 frames from 1012_TIE_SAD_XX.mp4
# Extracted 73 frames from 1012_TSI_ANG_XX.mp4
# Extracted 77 frames from 1012_TSI_DIS_XX.mp4
# Extracted 73 frames from 1012_TSI_FEA_XX.mp4
# Extracted 60 frames from 1012_TSI_HAP_XX.mp4
# Extracted 67 frames from 1012_TSI_NEU_XX.mp4
# Extracted 76 frames from 1012_TSI_SAD_XX.mp4
# Extracted 74 frames from 1012_WSI_ANG_XX.mp4
# Extracted 89 frames from 1012_WSI_DIS_XX.mp4
# Extracted 83 frames from 1012_WSI_FEA_XX.mp4
# Extracted 86 frames from 1012_WSI_HAP_XX.mp4
# Extracted 82 frames from 1012_WSI_NEU_XX.mp4
# Extracted 95 frames from 1012_WSI_SAD_XX.mp4
# Extracted 82 frames from 1013_DFA_ANG_XX.mp4
# Extracted 68 frames from 1013_DFA_DIS_XX.mp4
# Extracted 55 frames from 1013_DFA_FEA_XX.mp4
# Extracted 62 frames from 1013_DFA_HAP_XX.mp4
# Extracted 70 frames from 1013_DFA_NEU_XX.mp4
# Extracted 67 frames from 1013_DFA_SAD_XX.mp4
# Extracted 88 frames from 1013_IEO_ANG_HI.mp4
# Extracted 50 frames from 1013_IEO_ANG_LO.mp4
# Extracted 55 frames from 1013_IEO_ANG_MD.mp4
# Extracted 93 frames from 1013_IEO_DIS_HI.mp4
# Extracted 64 frames from 1013_IEO_DIS_LO.mp4
# Extracted 64 frames from 1013_IEO_DIS_MD.mp4
# Extracted 49 frames from 1013_IEO_FEA_HI.mp4
# Extracted 77 frames from 1013_IEO_FEA_LO.mp4
# Extracted 65 frames from 1013_IEO_FEA_MD.mp4
# Extracted 45 frames from 1013_IEO_HAP_HI.mp4
# Extracted 69 frames from 1013_IEO_HAP_LO.mp4
# Extracted 60 frames from 1013_IEO_HAP_MD.mp4
# Extracted 57 frames from 1013_IEO_NEU_XX.mp4
# Extracted 79 frames from 1013_IEO_SAD_HI.mp4
# Extracted 57 frames from 1013_IEO_SAD_LO.mp4
# Extracted 75 frames from 1013_IEO_SAD_MD.mp4
# Extracted 74 frames from 1013_IOM_ANG_XX.mp4
# Extracted 88 frames from 1013_IOM_DIS_XX.mp4
# Extracted 92 frames from 1013_IOM_FEA_XX.mp4
# Extracted 73 frames from 1013_IOM_HAP_XX.mp4
# Extracted 84 frames from 1013_IOM_NEU_XX.mp4
# Extracted 76 frames from 1013_IOM_SAD_XX.mp4
# Extracted 87 frames from 1013_ITH_ANG_XX.mp4
# Extracted 80 frames from 1013_ITH_DIS_XX.mp4
# Extracted 77 frames from 1013_ITH_FEA_XX.mp4
# Extracted 78 frames from 1013_ITH_HAP_XX.mp4
# Extracted 67 frames from 1013_ITH_NEU_XX.mp4
# Extracted 74 frames from 1013_ITH_SAD_XX.mp4
# Extracted 79 frames from 1013_ITS_ANG_XX.mp4
# Extracted 80 frames from 1013_ITS_DIS_XX.mp4
# Extracted 64 frames from 1013_ITS_FEA_XX.mp4
# Extracted 72 frames from 1013_ITS_HAP_XX.mp4
# Extracted 62 frames from 1013_ITS_NEU_XX.mp4
# Extracted 68 frames from 1013_ITS_SAD_XX.mp4
# Extracted 86 frames from 1013_IWL_ANG_XX.mp4
# Extracted 90 frames from 1013_IWL_DIS_XX.mp4
# Extracted 68 frames from 1013_IWL_FEA_XX.mp4
# Extracted 74 frames from 1013_IWL_HAP_XX.mp4
# Extracted 70 frames from 1013_IWL_NEU_XX.mp4
# Extracted 77 frames from 1013_IWL_SAD_XX.mp4
# Extracted 65 frames from 1013_IWW_ANG_XX.mp4
# Extracted 64 frames from 1013_IWW_DIS_XX.mp4
# Extracted 64 frames from 1013_IWW_FEA_XX.mp4
# Extracted 59 frames from 1013_IWW_HAP_XX.mp4
# Extracted 79 frames from 1013_IWW_NEU_XX.mp4
# Extracted 61 frames from 1013_IWW_SAD_XX.mp4
# Extracted 83 frames from 1013_MTI_ANG_XX.mp4
# Extracted 88 frames from 1013_MTI_DIS_XX.mp4
# Extracted 80 frames from 1013_MTI_FEA_XX.mp4
# Extracted 72 frames from 1013_MTI_HAP_XX.mp4
# Extracted 82 frames from 1013_MTI_NEU_XX.mp4
# Extracted 84 frames from 1013_MTI_SAD_XX.mp4
# Extracted 82 frames from 1013_TAI_ANG_XX.mp4
# Extracted 98 frames from 1013_TAI_DIS_XX.mp4
# Extracted 69 frames from 1013_TAI_FEA_XX.mp4
# Extracted 76 frames from 1013_TAI_HAP_XX.mp4
# Extracted 63 frames from 1013_TAI_NEU_XX.mp4
# Extracted 76 frames from 1013_TAI_SAD_XX.mp4
# Extracted 106 frames from 1013_TIE_ANG_XX.mp4
# Extracted 91 frames from 1013_TIE_DIS_XX.mp4
# Extracted 68 frames from 1013_TIE_FEA_XX.mp4
# Extracted 77 frames from 1013_TIE_HAP_XX.mp4
# Extracted 68 frames from 1013_TIE_NEU_XX.mp4
# Extracted 114 frames from 1013_TIE_SAD_XX.mp4
# Extracted 71 frames from 1013_TSI_ANG_XX.mp4
# Extracted 91 frames from 1013_TSI_DIS_XX.mp4
# Extracted 73 frames from 1013_TSI_FEA_XX.mp4
# Extracted 67 frames from 1013_TSI_HAP_XX.mp4
# Extracted 75 frames from 1013_TSI_NEU_XX.mp4
# Extracted 75 frames from 1013_TSI_SAD_XX.mp4
# Extracted 93 frames from 1013_WSI_ANG_XX.mp4
# Extracted 100 frames from 1013_WSI_DIS_XX.mp4
# Extracted 80 frames from 1013_WSI_FEA_XX.mp4
# Extracted 82 frames from 1013_WSI_HAP_XX.mp4
# Extracted 72 frames from 1013_WSI_NEU_XX.mp4
# Extracted 100 frames from 1013_WSI_SAD_XX.mp4
# Extracted 71 frames from 1014_DFA_ANG_XX.mp4
# Extracted 62 frames from 1014_DFA_DIS_XX.mp4
# Extracted 82 frames from 1014_DFA_FEA_XX.mp4
# Extracted 68 frames from 1014_DFA_HAP_XX.mp4
# Extracted 75 frames from 1014_DFA_NEU_XX.mp4
# Extracted 59 frames from 1014_DFA_SAD_XX.mp4
# Extracted 83 frames from 1014_IEO_ANG_HI.mp4
# Extracted 66 frames from 1014_IEO_ANG_LO.mp4
# Extracted 85 frames from 1014_IEO_ANG_MD.mp4
# Extracted 89 frames from 1014_IEO_DIS_HI.mp4
# Extracted 71 frames from 1014_IEO_DIS_LO.mp4
# Extracted 68 frames from 1014_IEO_DIS_MD.mp4
# Extracted 74 frames from 1014_IEO_FEA_HI.mp4
# Extracted 57 frames from 1014_IEO_FEA_LO.mp4
# Extracted 81 frames from 1014_IEO_FEA_MD.mp4
# Extracted 69 frames from 1014_IEO_HAP_HI.mp4
# Extracted 49 frames from 1014_IEO_HAP_LO.mp4
# Extracted 65 frames from 1014_IEO_HAP_MD.mp4
# Extracted 59 frames from 1014_IEO_NEU_XX.mp4
# Extracted 58 frames from 1014_IEO_SAD_HI.mp4
# Extracted 59 frames from 1014_IEO_SAD_LO.mp4
# Extracted 56 frames from 1014_IEO_SAD_MD.mp4
# Extracted 98 frames from 1014_IOM_ANG_XX.mp4
# Extracted 62 frames from 1014_IOM_DIS_XX.mp4
# Extracted 88 frames from 1014_IOM_FEA_XX.mp4
# Extracted 63 frames from 1014_IOM_HAP_XX.mp4
# Extracted 63 frames from 1014_IOM_NEU_XX.mp4
# Extracted 93 frames from 1014_IOM_SAD_XX.mp4
# Extracted 107 frames from 1014_ITH_ANG_XX.mp4
# Extracted 101 frames from 1014_ITH_DIS_XX.mp4
# Extracted 70 frames from 1014_ITH_FEA_XX.mp4
# Extracted 73 frames from 1014_ITH_HAP_XX.mp4
# Extracted 80 frames from 1014_ITH_NEU_XX.mp4
# Extracted 103 frames from 1014_ITH_SAD_XX.mp4
# Extracted 83 frames from 1014_ITS_ANG_XX.mp4
# Extracted 102 frames from 1014_ITS_DIS_XX.mp4
# Extracted 77 frames from 1014_ITS_FEA_XX.mp4
# Extracted 68 frames from 1014_ITS_HAP_XX.mp4
# Extracted 83 frames from 1014_ITS_NEU_XX.mp4
# Extracted 76 frames from 1014_ITS_SAD_XX.mp4
# Extracted 115 frames from 1014_IWL_ANG_XX.mp4
# Extracted 118 frames from 1014_IWL_DIS_XX.mp4
# Extracted 77 frames from 1014_IWL_FEA_XX.mp4
# Extracted 98 frames from 1014_IWL_HAP_XX.mp4
# Extracted 86 frames from 1014_IWL_NEU_XX.mp4
# Extracted 103 frames from 1014_IWL_SAD_XX.mp4
# Extracted 81 frames from 1014_IWW_ANG_XX.mp4
# Extracted 88 frames from 1014_IWW_DIS_XX.mp4
# Extracted 66 frames from 1014_IWW_FEA_XX.mp4
# Extracted 65 frames from 1014_IWW_HAP_XX.mp4
# Extracted 76 frames from 1014_IWW_NEU_XX.mp4
# Extracted 75 frames from 1014_IWW_SAD_XX.mp4
# Extracted 102 frames from 1014_MTI_ANG_XX.mp4
# Extracted 76 frames from 1014_MTI_DIS_XX.mp4
# Extracted 93 frames from 1014_MTI_FEA_XX.mp4
# Extracted 69 frames from 1014_MTI_HAP_XX.mp4
# Extracted 93 frames from 1014_MTI_NEU_XX.mp4
# Extracted 69 frames from 1014_MTI_SAD_XX.mp4
# Extracted 90 frames from 1014_TAI_ANG_XX.mp4
# Extracted 94 frames from 1014_TAI_DIS_XX.mp4
# Extracted 72 frames from 1014_TAI_FEA_XX.mp4
# Extracted 78 frames from 1014_TAI_HAP_XX.mp4
# Extracted 83 frames from 1014_TAI_NEU_XX.mp4
# Extracted 100 frames from 1014_TAI_SAD_XX.mp4
# Extracted 97 frames from 1014_TIE_ANG_XX.mp4
# Extracted 96 frames from 1014_TIE_DIS_XX.mp4
# Extracted 88 frames from 1014_TIE_FEA_XX.mp4
# Extracted 87 frames from 1014_TIE_HAP_XX.mp4
# Extracted 72 frames from 1014_TIE_NEU_XX.mp4
# Extracted 93 frames from 1014_TIE_SAD_XX.mp4
# Extracted 89 frames from 1014_TSI_ANG_XX.mp4
# Extracted 86 frames from 1014_TSI_DIS_XX.mp4
# Extracted 77 frames from 1014_TSI_FEA_XX.mp4
# Extracted 75 frames from 1014_TSI_HAP_XX.mp4
# Extracted 76 frames from 1014_TSI_NEU_XX.mp4
# Extracted 73 frames from 1014_TSI_SAD_XX.mp4
# Extracted 91 frames from 1014_WSI_ANG_XX.mp4
# Extracted 72 frames from 1014_WSI_DIS_XX.mp4
# Extracted 78 frames from 1014_WSI_FEA_XX.mp4
# Extracted 65 frames from 1014_WSI_HAP_XX.mp4
# Extracted 70 frames from 1014_WSI_NEU_XX.mp4
# Extracted 68 frames from 1014_WSI_SAD_XX.mp4
# Extracted 67 frames from 1015_DFA_ANG_XX.mp4
# Extracted 64 frames from 1015_DFA_DIS_XX.mp4
# Extracted 61 frames from 1015_DFA_FEA_XX.mp4
# Extracted 53 frames from 1015_DFA_HAP_XX.mp4
# Extracted 53 frames from 1015_DFA_NEU_XX.mp4
# Extracted 63 frames from 1015_DFA_SAD_XX.mp4
# Extracted 66 frames from 1015_IEO_ANG_HI.mp4
# Extracted 65 frames from 1015_IEO_ANG_LO.mp4
# ...
# Extracted 78 frames from 1087_MTI_HAP_XX.mp4
# Extracted 95 frames from 1087_MTI_NEU_XX.mp4
# Extracted 80 frames from 1087_MTI_SAD_XX.mp4
# Extracted 90 frames from 1087_TAI_ANG_XX.mp4
# Extracted 70 frames from 1087_TAI_DIS_XX.mp4
# Extracted 60 frames from 1087_TAI_FEA_XX.mp4
# Extracted 59 frames from 1087_TAI_HAP_XX.mp4
# Extracted 84 frames from 1087_TAI_NEU_XX.mp4
# Extracted 74 frames from 1087_TAI_SAD_XX.mp4
# Extracted 81 frames from 1087_TIE_ANG_XX.mp4
# Extracted 88 frames from 1087_TIE_DIS_XX.mp4
# Extracted 99 frames from 1087_TIE_FEA_XX.mp4
# Extracted 87 frames from 1087_TIE_HAP_XX.mp4
# Extracted 72 frames from 1087_TIE_NEU_XX.mp4
# Extracted 71 frames from 1087_TIE_SAD_XX.mp4
# Extracted 102 frames from 1087_TSI_ANG_XX.mp4
# Extracted 74 frames from 1087_TSI_DIS_XX.mp4
# Extracted 70 frames from 1087_TSI_FEA_XX.mp4
# Extracted 82 frames from 1087_TSI_HAP_XX.mp4
# Extracted 69 frames from 1087_TSI_NEU_XX.mp4
# Extracted 79 frames from 1087_TSI_SAD_XX.mp4
# Extracted 103 frames from 1087_WSI_ANG_XX.mp4
# Extracted 102 frames from 1087_WSI_DIS_XX.mp4
# Extracted 65 frames from 1087_WSI_FEA_XX.mp4
# Extracted 58 frames from 1087_WSI_HAP_XX.mp4
# Extracted 72 frames from 1087_WSI_NEU_XX.mp4
# Extracted 95 frames from 1087_WSI_SAD_XX.mp4
# Extracted 59 frames from 1088_DFA_ANG_XX.mp4
# Extracted 68 frames from 1088_DFA_DIS_XX.mp4
# Extracted 62 frames from 1088_DFA_FEA_XX.mp4
# Extracted 62 frames from 1088_DFA_HAP_XX.mp4
# Extracted 64 frames from 1088_DFA_NEU_XX.mp4
# Extracted 86 frames from 1088_DFA_SAD_XX.mp4
# Extracted 83 frames from 1088_IEO_ANG_HI.mp4
# Extracted 68 frames from 1088_IEO_ANG_LO.mp4
# Extracted 78 frames from 1088_IEO_ANG_MD.mp4
# Extracted 73 frames from 1088_IEO_DIS_HI.mp4
# Extracted 73 frames from 1088_IEO_DIS_LO.mp4
# Extracted 60 frames from 1088_IEO_DIS_MD.mp4
# Extracted 64 frames from 1088_IEO_FEA_HI.mp4
# Extracted 64 frames from 1088_IEO_FEA_LO.mp4
# Extracted 66 frames from 1088_IEO_FEA_MD.mp4
# Extracted 65 frames from 1088_IEO_HAP_HI.mp4
# Extracted 50 frames from 1088_IEO_HAP_LO.mp4
# Extracted 64 frames from 1088_IEO_HAP_MD.mp4
# Extracted 65 frames from 1088_IEO_NEU_XX.mp4
# Extracted 75 frames from 1088_IEO_SAD_HI.mp4
# Extracted 72 frames from 1088_IEO_SAD_LO.mp4
# Extracted 84 frames from 1088_IEO_SAD_MD.mp4
# Extracted 75 frames from 1088_IOM_ANG_XX.mp4
# Extracted 76 frames from 1088_IOM_DIS_XX.mp4
# Extracted 65 frames from 1088_IOM_FEA_XX.mp4
# Extracted 52 frames from 1088_IOM_HAP_XX.mp4
# Extracted 54 frames from 1088_IOM_NEU_XX.mp4
# Extracted 69 frames from 1088_IOM_SAD_XX.mp4
# Extracted 81 frames from 1088_ITH_ANG_XX.mp4
# Extracted 101 frames from 1088_ITH_DIS_XX.mp4
# Extracted 81 frames from 1088_ITH_FEA_XX.mp4
# Extracted 69 frames from 1088_ITH_HAP_XX.mp4
# Extracted 74 frames from 1088_ITH_NEU_XX.mp4
# Extracted 97 frames from 1088_ITH_SAD_XX.mp4
# Extracted 68 frames from 1088_ITS_ANG_XX.mp4
# Extracted 57 frames from 1088_ITS_DIS_XX.mp4
# Extracted 65 frames from 1088_ITS_FEA_XX.mp4
# Extracted 64 frames from 1088_ITS_HAP_XX.mp4
# Extracted 74 frames from 1088_ITS_NEU_XX.mp4
# Extracted 105 frames from 1088_ITS_SAD_XX.mp4
# Extracted 72 frames from 1088_IWL_ANG_XX.mp4
# Extracted 94 frames from 1088_IWL_DIS_XX.mp4
# Extracted 101 frames from 1088_IWL_FEA_XX.mp4
# Extracted 65 frames from 1088_IWL_HAP_XX.mp4
# Extracted 76 frames from 1088_IWL_NEU_XX.mp4
# Extracted 93 frames from 1088_IWL_SAD_XX.mp4
# Extracted 63 frames from 1088_IWW_ANG_XX.mp4
# Extracted 87 frames from 1088_IWW_DIS_XX.mp4
# Extracted 95 frames from 1088_IWW_FEA_XX.mp4
# Extracted 59 frames from 1088_IWW_HAP_XX.mp4
# Extracted 62 frames from 1088_IWW_NEU_XX.mp4
# Extracted 83 frames from 1088_IWW_SAD_XX.mp4
# Extracted 81 frames from 1088_MTI_ANG_XX.mp4
# Extracted 88 frames from 1088_MTI_DIS_XX.mp4
# Extracted 85 frames from 1088_MTI_FEA_XX.mp4
# Extracted 85 frames from 1088_MTI_HAP_XX.mp4
# Extracted 71 frames from 1088_MTI_NEU_XX.mp4
# Extracted 86 frames from 1088_MTI_SAD_XX.mp4
# Extracted 94 frames from 1088_TAI_ANG_XX.mp4
# Extracted 86 frames from 1088_TAI_DIS_XX.mp4
# Extracted 89 frames from 1088_TAI_FEA_XX.mp4
# Extracted 73 frames from 1088_TAI_HAP_XX.mp4
# Extracted 59 frames from 1088_TAI_NEU_XX.mp4
# Extracted 77 frames from 1088_TAI_SAD_XX.mp4
# Extracted 90 frames from 1088_TIE_ANG_XX.mp4
# Extracted 90 frames from 1088_TIE_DIS_XX.mp4
# Extracted 90 frames from 1088_TIE_FEA_XX.mp4
# Extracted 82 frames from 1088_TIE_HAP_XX.mp4
# Extracted 76 frames from 1088_TIE_NEU_XX.mp4
# Extracted 80 frames from 1088_TIE_SAD_XX.mp4
# Extracted 62 frames from 1088_TSI_ANG_XX.mp4
# Extracted 72 frames from 1088_TSI_DIS_XX.mp4
# Extracted 95 frames from 1088_TSI_FEA_XX.mp4
# Extracted 76 frames from 1088_TSI_HAP_XX.mp4
# Extracted 58 frames from 1088_TSI_NEU_XX.mp4
# Extracted 71 frames from 1088_TSI_SAD_XX.mp4
# Extracted 97 frames from 1088_WSI_ANG_XX.mp4
# Extracted 60 frames from 1088_WSI_DIS_XX.mp4
# Extracted 92 frames from 1088_WSI_FEA_XX.mp4
# Extracted 71 frames from 1088_WSI_HAP_XX.mp4
# Extracted 79 frames from 1088_WSI_NEU_XX.mp4
# Extracted 79 frames from 1088_WSI_SAD_XX.mp4
# Extracted 58 frames from 1089_DFA_ANG_XX.mp4
# Extracted 80 frames from 1089_DFA_DIS_XX.mp4
# Extracted 75 frames from 1089_DFA_FEA_XX.mp4
# Extracted 74 frames from 1089_DFA_HAP_XX.mp4
# Extracted 63 frames from 1089_DFA_NEU_XX.mp4
# Extracted 66 frames from 1089_DFA_SAD_XX.mp4
# Extracted 75 frames from 1089_IEO_ANG_HI.mp4
# Extracted 61 frames from 1089_IEO_ANG_LO.mp4
# Extracted 70 frames from 1089_IEO_ANG_MD.mp4
# Extracted 92 frames from 1089_IEO_DIS_HI.mp4
# Extracted 82 frames from 1089_IEO_DIS_LO.mp4
# Extracted 67 frames from 1089_IEO_DIS_MD.mp4
# Extracted 70 frames from 1089_IEO_FEA_HI.mp4
# Extracted 81 frames from 1089_IEO_FEA_LO.mp4
# Extracted 99 frames from 1089_IEO_FEA_MD.mp4
# Extracted 69 frames from 1089_IEO_HAP_HI.mp4
# Extracted 61 frames from 1089_IEO_HAP_LO.mp4
# Extracted 66 frames from 1089_IEO_HAP_MD.mp4
# Extracted 72 frames from 1089_IEO_NEU_XX.mp4
# Extracted 70 frames from 1089_IEO_SAD_HI.mp4
# Extracted 81 frames from 1089_IEO_SAD_LO.mp4
# Extracted 84 frames from 1089_IEO_SAD_MD.mp4
# Extracted 85 frames from 1089_IOM_ANG_XX.mp4
# Extracted 93 frames from 1089_IOM_DIS_XX.mp4
# Extracted 77 frames from 1089_IOM_FEA_XX.mp4
# Extracted 82 frames from 1089_IOM_HAP_XX.mp4
# Extracted 66 frames from 1089_IOM_NEU_XX.mp4
# Extracted 61 frames from 1089_IOM_SAD_XX.mp4
# Extracted 91 frames from 1089_ITH_ANG_XX.mp4
# Extracted 119 frames from 1089_ITH_DIS_XX.mp4
# Extracted 71 frames from 1089_ITH_FEA_XX.mp4
# Extracted 65 frames from 1089_ITH_HAP_XX.mp4
# Extracted 61 frames from 1089_ITH_NEU_XX.mp4
# Extracted 77 frames from 1089_ITH_SAD_XX.mp4
# Extracted 83 frames from 1089_ITS_ANG_XX.mp4
# Extracted 87 frames from 1089_ITS_DIS_XX.mp4
# Extracted 94 frames from 1089_ITS_FEA_XX.mp4
# Extracted 79 frames from 1089_ITS_HAP_XX.mp4
# Extracted 62 frames from 1089_ITS_NEU_XX.mp4
# Extracted 83 frames from 1089_ITS_SAD_XX.mp4
# Extracted 90 frames from 1089_IWL_ANG_XX.mp4
# Extracted 112 frames from 1089_IWL_DIS_XX.mp4
# Extracted 83 frames from 1089_IWL_FEA_XX.mp4
# Extracted 69 frames from 1089_IWL_HAP_XX.mp4
# Extracted 73 frames from 1089_IWL_NEU_XX.mp4
# Extracted 85 frames from 1089_IWL_SAD_XX.mp4
# Extracted 73 frames from 1089_IWW_ANG_XX.mp4
# Extracted 95 frames from 1089_IWW_DIS_XX.mp4
# Extracted 76 frames from 1089_IWW_FEA_XX.mp4
# Extracted 64 frames from 1089_IWW_HAP_XX.mp4
# Extracted 96 frames from 1089_IWW_NEU_XX.mp4
# Extracted 85 frames from 1089_IWW_SAD_XX.mp4
# Extracted 88 frames from 1089_MTI_ANG_XX.mp4
# Extracted 136 frames from 1089_MTI_DIS_XX.mp4
# Extracted 85 frames from 1089_MTI_FEA_XX.mp4
# Extracted 74 frames from 1089_MTI_HAP_XX.mp4
# Extracted 86 frames from 1089_MTI_NEU_XX.mp4
# Extracted 85 frames from 1089_MTI_SAD_XX.mp4
# Extracted 86 frames from 1089_TAI_ANG_XX.mp4
# Extracted 111 frames from 1089_TAI_DIS_XX.mp4
# Extracted 87 frames from 1089_TAI_FEA_XX.mp4
# Extracted 74 frames from 1089_TAI_HAP_XX.mp4
# Extracted 74 frames from 1089_TAI_NEU_XX.mp4
# Extracted 96 frames from 1089_TAI_SAD_XX.mp4
# Extracted 90 frames from 1089_TIE_ANG_XX.mp4
# Extracted 120 frames from 1089_TIE_DIS_XX.mp4
# Extracted 90 frames from 1089_TIE_FEA_XX.mp4
# Extracted 90 frames from 1089_TIE_HAP_XX.mp4
# Extracted 89 frames from 1089_TIE_NEU_XX.mp4
# Extracted 96 frames from 1089_TIE_SAD_XX.mp4
# Extracted 71 frames from 1089_TSI_ANG_XX.mp4
# Extracted 90 frames from 1089_TSI_DIS_XX.mp4
# Extracted 55 frames from 1089_TSI_FEA_XX.mp4
# Extracted 70 frames from 1089_TSI_HAP_XX.mp4
# Extracted 70 frames from 1089_TSI_NEU_XX.mp4
# Extracted 75 frames from 1089_TSI_SAD_XX.mp4
# Extracted 68 frames from 1089_WSI_ANG_XX.mp4
# Extracted 122 frames from 1089_WSI_DIS_XX.mp4
# Extracted 69 frames from 1089_WSI_FEA_XX.mp4
# Extracted 66 frames from 1089_WSI_HAP_XX.mp4
# Extracted 77 frames from 1089_WSI_NEU_XX.mp4
# Extracted 80 frames from 1089_WSI_SAD_XX.mp4
# Extracted 66 frames from 1090_DFA_ANG_XX.mp4
# Extracted 74 frames from 1090_DFA_DIS_XX.mp4
# Extracted 66 frames from 1090_DFA_FEA_XX.mp4
# Extracted 57 frames from 1090_DFA_HAP_XX.mp4
# Extracted 54 frames from 1090_DFA_NEU_XX.mp4
# Extracted 56 frames from 1090_DFA_SAD_XX.mp4
# Extracted 86 frames from 1090_IEO_ANG_HI.mp4
# Extracted 77 frames from 1090_IEO_ANG_LO.mp4
# Extracted 73 frames from 1090_IEO_ANG_MD.mp4
# Extracted 56 frames from 1090_IEO_DIS_HI.mp4
# Extracted 56 frames from 1090_IEO_DIS_LO.mp4
# Extracted 79 frames from 1090_IEO_DIS_MD.mp4
# Extracted 55 frames from 1090_IEO_FEA_HI.mp4
# Extracted 50 frames from 1090_IEO_FEA_LO.mp4
# Extracted 60 frames from 1090_IEO_FEA_MD.mp4
# Extracted 60 frames from 1090_IEO_HAP_HI.mp4
# Extracted 58 frames from 1090_IEO_HAP_LO.mp4
# Extracted 57 frames from 1090_IEO_HAP_MD.mp4
# Extracted 50 frames from 1090_IEO_NEU_XX.mp4
# Extracted 54 frames from 1090_IEO_SAD_HI.mp4
# Extracted 60 frames from 1090_IEO_SAD_LO.mp4
# Extracted 60 frames from 1090_IEO_SAD_MD.mp4
# Extracted 75 frames from 1090_IOM_ANG_XX.mp4
# Extracted 82 frames from 1090_IOM_DIS_XX.mp4
# Extracted 78 frames from 1090_IOM_FEA_XX.mp4
# Extracted 74 frames from 1090_IOM_HAP_XX.mp4
# Extracted 65 frames from 1090_IOM_NEU_XX.mp4
# Extracted 81 frames from 1090_IOM_SAD_XX.mp4
# Extracted 104 frames from 1090_ITH_ANG_XX.mp4
# Extracted 107 frames from 1090_ITH_DIS_XX.mp4
# Extracted 103 frames from 1090_ITH_FEA_XX.mp4
# Extracted 64 frames from 1090_ITH_HAP_XX.mp4
# Extracted 69 frames from 1090_ITH_NEU_XX.mp4
# Extracted 80 frames from 1090_ITH_SAD_XX.mp4
# Extracted 77 frames from 1090_ITS_ANG_XX.mp4
# Extracted 86 frames from 1090_ITS_DIS_XX.mp4
# Extracted 75 frames from 1090_ITS_FEA_XX.mp4
# Extracted 88 frames from 1090_ITS_HAP_XX.mp4
# Extracted 76 frames from 1090_ITS_NEU_XX.mp4
# Extracted 88 frames from 1090_ITS_SAD_XX.mp4
# Extracted 99 frames from 1090_IWL_ANG_XX.mp4
# Extracted 98 frames from 1090_IWL_DIS_XX.mp4
# Extracted 74 frames from 1090_IWL_FEA_XX.mp4
# Extracted 78 frames from 1090_IWL_HAP_XX.mp4
# Extracted 83 frames from 1090_IWL_NEU_XX.mp4
# Extracted 77 frames from 1090_IWL_SAD_XX.mp4
# Extracted 86 frames from 1090_IWW_ANG_XX.mp4
# Extracted 68 frames from 1090_IWW_DIS_XX.mp4
# Extracted 75 frames from 1090_IWW_FEA_XX.mp4
# Extracted 66 frames from 1090_IWW_HAP_XX.mp4
# Extracted 64 frames from 1090_IWW_NEU_XX.mp4
# Extracted 86 frames from 1090_IWW_SAD_XX.mp4
# Extracted 100 frames from 1090_MTI_ANG_XX.mp4
# Extracted 114 frames from 1090_MTI_DIS_XX.mp4
# Extracted 86 frames from 1090_MTI_FEA_XX.mp4
# Extracted 84 frames from 1090_MTI_HAP_XX.mp4
# Extracted 70 frames from 1090_MTI_NEU_XX.mp4
# Extracted 82 frames from 1090_MTI_SAD_XX.mp4
# Extracted 104 frames from 1090_TAI_ANG_XX.mp4
# Extracted 91 frames from 1090_TAI_DIS_XX.mp4
# Extracted 73 frames from 1090_TAI_FEA_XX.mp4
# Extracted 72 frames from 1090_TAI_HAP_XX.mp4
# Extracted 72 frames from 1090_TAI_NEU_XX.mp4
# Extracted 75 frames from 1090_TAI_SAD_XX.mp4
# Extracted 88 frames from 1090_TIE_ANG_XX.mp4
# Extracted 120 frames from 1090_TIE_DIS_XX.mp4
# Extracted 88 frames from 1090_TIE_FEA_XX.mp4
# Extracted 74 frames from 1090_TIE_HAP_XX.mp4
# Extracted 73 frames from 1090_TIE_NEU_XX.mp4
# Extracted 115 frames from 1090_TIE_SAD_XX.mp4
# Extracted 86 frames from 1090_TSI_ANG_XX.mp4
# Extracted 98 frames from 1090_TSI_DIS_XX.mp4
# Extracted 76 frames from 1090_TSI_FEA_XX.mp4
# Extracted 77 frames from 1090_TSI_HAP_XX.mp4
# Extracted 65 frames from 1090_TSI_NEU_XX.mp4
# Extracted 77 frames from 1090_TSI_SAD_XX.mp4
# Extracted 87 frames from 1090_WSI_ANG_XX.mp4
# Extracted 89 frames from 1090_WSI_DIS_XX.mp4
# Extracted 66 frames from 1090_WSI_FEA_XX.mp4
# Extracted 69 frames from 1090_WSI_HAP_XX.mp4
# Extracted 71 frames from 1090_WSI_NEU_XX.mp4
# Extracted 95 frames from 1090_WSI_SAD_XX.mp4
# Extracted 60 frames from 1091_DFA_ANG_XX.mp4
# Extracted 80 frames from 1091_DFA_DIS_XX.mp4
# Extracted 60 frames from 1091_DFA_FEA_XX.mp4
# Extracted 60 frames from 1091_DFA_HAP_XX.mp4
# Extracted 60 frames from 1091_DFA_NEU_XX.mp4
# Extracted 60 frames from 1091_DFA_SAD_XX.mp4
# Extracted 65 frames from 1091_IEO_ANG_HI.mp4
# Extracted 65 frames from 1091_IEO_ANG_LO.mp4
# Extracted 70 frames from 1091_IEO_ANG_MD.mp4
# Extracted 85 frames from 1091_IEO_DIS_HI.mp4
# Extracted 80 frames from 1091_IEO_DIS_LO.mp4
# Extracted 75 frames from 1091_IEO_DIS_MD.mp4
# Extracted 70 frames from 1091_IEO_FEA_HI.mp4
# Extracted 75 frames from 1091_IEO_FEA_LO.mp4
# Extracted 80 frames from 1091_IEO_FEA_MD.mp4
# Extracted 60 frames from 1091_IEO_HAP_HI.mp4
# Extracted 50 frames from 1091_IEO_HAP_LO.mp4
# Extracted 80 frames from 1091_IEO_HAP_MD.mp4
# Extracted 55 frames from 1091_IEO_NEU_XX.mp4
# Extracted 60 frames from 1091_IEO_SAD_HI.mp4
# Extracted 65 frames from 1091_IEO_SAD_LO.mp4
# Extracted 70 frames from 1091_IEO_SAD_MD.mp4
# Extracted 60 frames from 1091_IOM_ANG_XX.mp4
# Extracted 80 frames from 1091_IOM_DIS_XX.mp4
# Extracted 90 frames from 1091_IOM_FEA_XX.mp4
# Extracted 75 frames from 1091_IOM_HAP_XX.mp4
# Extracted 60 frames from 1091_IOM_NEU_XX.mp4
# Extracted 70 frames from 1091_IOM_SAD_XX.mp4
# Extracted 80 frames from 1091_ITH_ANG_XX.mp4
# Extracted 90 frames from 1091_ITH_DIS_XX.mp4
# Extracted 80 frames from 1091_ITH_FEA_XX.mp4
# Extracted 80 frames from 1091_ITH_HAP_XX.mp4
# Extracted 70 frames from 1091_ITH_NEU_XX.mp4
# Extracted 90 frames from 1091_ITH_SAD_XX.mp4
# Extracted 85 frames from 1091_ITS_ANG_XX.mp4
# Extracted 80 frames from 1091_ITS_DIS_XX.mp4
# Extracted 80 frames from 1091_ITS_FEA_XX.mp4
# Extracted 85 frames from 1091_ITS_HAP_XX.mp4
# Extracted 75 frames from 1091_ITS_NEU_XX.mp4
# Extracted 78 frames from 1091_ITS_SAD_XX.mp4
# Extracted 75 frames from 1091_IWL_ANG_XX.mp4
# Extracted 90 frames from 1091_IWL_DIS_XX.mp4
# Extracted 80 frames from 1091_IWL_FEA_XX.mp4
# Extracted 80 frames from 1091_IWL_HAP_XX.mp4
# Extracted 70 frames from 1091_IWL_NEU_XX.mp4
# Extracted 75 frames from 1091_IWL_SAD_XX.mp4
# Extracted 75 frames from 1091_IWW_ANG_XX.mp4
# Extracted 90 frames from 1091_IWW_DIS_XX.mp4
# Extracted 86 frames from 1091_IWW_FEA_XX.mp4
# Extracted 90 frames from 1091_IWW_HAP_XX.mp4
# Extracted 85 frames from 1091_IWW_NEU_XX.mp4
# Extracted 75 frames from 1091_IWW_SAD_XX.mp4
# Extracted 70 frames from 1091_MTI_ANG_XX.mp4
# Extracted 90 frames from 1091_MTI_DIS_XX.mp4
# Extracted 80 frames from 1091_MTI_FEA_XX.mp4
# Extracted 85 frames from 1091_MTI_HAP_XX.mp4
# Extracted 65 frames from 1091_MTI_NEU_XX.mp4
# Extracted 75 frames from 1091_MTI_SAD_XX.mp4
# Extracted 70 frames from 1091_TAI_ANG_XX.mp4
# Extracted 80 frames from 1091_TAI_DIS_XX.mp4
# Extracted 75 frames from 1091_TAI_FEA_XX.mp4
# Extracted 70 frames from 1091_TAI_HAP_XX.mp4
# Extracted 68 frames from 1091_TAI_NEU_XX.mp4
# Extracted 65 frames from 1091_TAI_SAD_XX.mp4
# Extracted 80 frames from 1091_TIE_ANG_XX.mp4
# Extracted 113 frames from 1091_TIE_DIS_XX.mp4
# Extracted 75 frames from 1091_TIE_FEA_XX.mp4
# Extracted 85 frames from 1091_TIE_HAP_XX.mp4
# Extracted 67 frames from 1091_TIE_NEU_XX.mp4
# Extracted 100 frames from 1091_TIE_SAD_XX.mp4
# Extracted 65 frames from 1091_TSI_ANG_XX.mp4
# Extracted 80 frames from 1091_TSI_DIS_XX.mp4
# Extracted 65 frames from 1091_TSI_FEA_XX.mp4
# Extracted 75 frames from 1091_TSI_HAP_XX.mp4
# Extracted 65 frames from 1091_TSI_NEU_XX.mp4
# Extracted 80 frames from 1091_TSI_SAD_XX.mp4
# Extracted 80 frames from 1091_WSI_ANG_XX.mp4
# Extracted 75 frames from 1091_WSI_DIS_XX.mp4
# Extracted 75 frames from 1091_WSI_FEA_XX.mp4
# Extracted 65 frames from 1091_WSI_HAP_XX.mp4
# Extracted 70 frames from 1091_WSI_NEU_XX.mp4
# Extracted 75 frames from 1091_WSI_SAD_XX.mp4

# %%
class CREMADataset(Dataset):
    def __init__(self, frame_dir, transform=None):
        self.frame_dir = frame_dir
        self.transform = transform
        self.data = []

        for video_folder in os.listdir(frame_dir):
            video_path = os.path.join(frame_dir, video_folder)
            for frame_file in os.listdir(video_path):
                if frame_file.endswith(".jpg"):
                    frame_path = os.path.join(video_path, frame_file)
                    label = self.get_label_from_video(video_folder)
                    self.data.append((frame_path, label))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        frame_path, label = self.data[idx]
        image = Image.open(frame_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        return image, label

    def get_label_from_video(self, video_name):
        # Extract the emotion label from the video name (e.g., "1002_DFA_ANG_XX.mp4")
        emotion_code = video_name.split('_')[2]
        emotion_map = {"ANG": 0, "DIS": 1, "FEA": 2, "HAP": 3, "NEU": 4, "SAD": 5, "SUR": 6}
        return emotion_map.get(emotion_code, -1)  # Return -1 if emotion is not found

# %%
# Define the frame directory again in the same script
frame_dir = r"C:\Users\dell\Desktop\gradproject\AI04-Grad\datasets\CREMA-D\frames"

# Continue with your dataset and DataLoader creation
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset, DataLoader
from torchvision import transforms

# Transformations for images
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Create dataset
dataset = CREMADataset(frame_dir=frame_dir, transform=transform)

# Split indices
indices = list(range(len(dataset)))
train_indices, val_test_indices = train_test_split(indices, test_size=0.4, random_state=42)
val_indices, test_indices = train_test_split(val_test_indices, test_size=0.5, random_state=42)

# Create subsets
train_subset = Subset(dataset, train_indices)
val_subset = Subset(dataset, val_indices)
test_subset = Subset(dataset, test_indices)

# Create DataLoaders
train_loader = DataLoader(train_subset, batch_size=16, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_subset, batch_size=16, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_subset, batch_size=16, shuffle=False, num_workers=4, pin_memory=True)

# %%
def pretrained_emotion_model(model_type, num_classes, device):
    if model_type == "resnet":
        model = models.resnet50(pretrained=True)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
    elif model_type == "mobilenet":
        model = models.mobilenet_v2(pretrained=True)
        model.classifier[1] = nn.Linear(model.last_channel, num_classes)
    else:
        raise ValueError("Invalid model_type. Choose 'resnet' or 'mobilenet'.")

    return model.to(device)

# Load model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = pretrained_emotion_model("resnet", num_classes=7, device=device)
# Out:
# c:\Users\dell\anaconda3\envs\new_bert\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\dell\anaconda3\envs\new_bert\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\dell/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:50<00:00, 2.04MB/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
import torch
import os
from tqdm import tqdm

# Define the path to save checkpoints
checkpoint_dir = "./checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

# Function to save a checkpoint
def save_checkpoint(epoch, model, optimizer, val_loss, checkpoint_dir):
    checkpoint_path = os.path.join(checkpoint_dir, f"model_epoch_{epoch+1}.pth")
    torch.save({
        'epoch': epoch + 1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'val_loss': val_loss
    }, checkpoint_path)
    print(f"Checkpoint saved at {checkpoint_path}")

# Training loop with checkpoint saving
num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
        images, labels = images.to(device), labels.to(device)

        # Zero gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    # Validation
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            val_loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_accuracy = correct / total
    print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader):.4f}, Val Loss: {val_loss/len(val_loader):.4f}, Val Accuracy: {val_accuracy*100:.2f}%")

    # Save checkpoint
    save_checkpoint(epoch, model, optimizer, val_loss/len(val_loader), checkpoint_dir)
# Out:
# Epoch 1/10:   0%|          | 0/21185 [00:00<?, ?it/s]

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# %%
torch.save(model.state_dict(), "emotion_recognition_model.pth")

# %%
def predict_emotion(model, image_path, transform, device):
    model.eval()
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image)
        _, predicted = torch.max(output, 1)

    emotion_map = {0: "Angry", 1: "Disgust", 2: "Fear", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprise"}
    return emotion_map[predicted.item()]

# Example usage
image_path = "path_to_frame.jpg"  # Replace with actual frame path
predicted_emotion = predict_emotion(model, image_path, transform, device)
print(f"Predicted Emotion: {predicted_emotion}")
